# %% [markdown]
# # Imports

# %%
# !pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (0.26.1)
# Requirement already satisfied: numpy>=1.17 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (5.4.1)
# Requirement already satisfied: torch>=1.10.0 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (1.12.1)
# Requirement already satisfied: huggingface-hub in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (0.20.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: typing-extensions in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (4.6.3)
# Requirement already satisfied: filelock in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (2023.10.0)
# Requirement already satisfied: requests in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (2.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (4.64.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2022.12.7)

# %%
import numpy as np
import pandas as pd
import pickle
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/amirghavam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/amirghavam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/amirghavam/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from sklearn.metrics import accuracy_score
from keywords_extractor import KeywordsExtractor
from augmenter import TextAugmenter

# %%
KE = KeywordsExtractor(lang='en')
# Out:
# Language: English
# Loading word vectors......

# %%
data = pd.read_csv('data/sst2/sst2_1000.csv')
data = data.dropna()
contents = list(data['text'])
labels = [str(label) for label in data['label']]

# %%
# extract keywords
kws_dict = KE.global_role_kws_extraction_one_line(contents, labels, output_dir='saved_keywords',name='sst2')
kws_dict.keys()
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 13560.24it/s]
# 100%|██████████| 1799/1799 [00:09<00:00, 192.01it/s]
# 100%|██████████| 1666/1666 [00:09<00:00, 179.26it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 14754.08it/s]
# First level keys:  ['1', '0']
# Second level keys:  ['lr', 'ls', 'ccw', 'scw', 'fcw', 'iw']
# already saved at saved_keywords/global_kws_dict_sst2.pkl
# dict_keys(['global_ls', 'global_lr', 'global_roles'])

# %%
for key in kws_dict['global_roles']:
    print(f"keywords for \"{key}\":")
    for each in ['ccw','scw','fcw','iw']:
        print(f"{each}: {kws_dict['global_roles'][key][each][:10]}")
# Out:
# keywords for "1":
# ccw: ['nine', 'stuart', 'solid', 'each', 'him', 'twentyth', 'spielberg', 'selfglorification', 'scoobydoo', 'raphael']
# scw: ['three', 'third', 'second', 'to', 'nearly', 'midnight', 'the', 'of', 'half', 'than']
# fcw: ['wonderful', 'style', 'culture', 'ways', 'ingenious', 'whose', 'occasionally', 'sly', 'manner', 'amusing']
# iw: ['clever', 'tastelessness', 'elegantly', 'shrewd', 'ennui', 'director', 'callow', 'audience', 'wit', 'moments']
# keywords for "0":
# ccw: ['forgettable', 'series', 'lack', 'flat', 'before', 'combined', 'run', 'four', 'despite', 'worst']
# scw: ['score', 'half', 'minutes', 'three', 'sandra', 'third', 'i', 'joel', 'pace', 'just']
# fcw: ['familiar', 'loud', 'becomes', 'slimed', 'to', 'gags', 'opera', 'sit', 'merit', 'ego']
# iw: ['and', 'one', 'ennui', 'humor', 'work', 'most', 'world', 'independent', 'act', 'might']

# %%
# Tokenize each sentence and compile into a single list
all_words = []
for sentence in contents:
    tokens = word_tokenize(sentence)
    all_words.extend(tokens)

# Optionally, you can convert the list to a set to remove duplicates
unique_words = set(all_words)

# %%
similar_words_dict = {}
for word in unique_words:
    synonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    similar_words_dict[word] = list(synonyms)

# %%
similar_words_dict
# Out:
# {'big': ['braggy',
#   'big',
#   'handsome',
#   'crowing',
#   'bragging',
#   'self-aggrandising',
#   'giving',
#   'braggart',
#   'bighearted',
#   'swelled',
#   'adult',
#   'grown',
#   'large',
#   'heavy',
#   'fully_grown',
#   'full-grown',
#   'boastfully',
#   'self-aggrandizing',
#   'vauntingly',
#   'bounteous',
#   'gravid',
#   'great',
#   'cock-a-hoop',
#   'bountiful',
#   'with_child',
#   'bad',
#   'expectant',
#   'vainglorious',
#   'boastful',
#   'magnanimous',
#   'grownup',
#   'openhanded',
#   'prominent',
#   'freehanded',
#   'liberal',
#   'enceinte'],
#  'learn': ['find_out',
#   'acquire',
#   'learn',
#   'get_wind',
#   'get_a_line',
#   'see',
#   'read',
#   'larn',
#   'memorize',
#   'instruct',
#   'ascertain',
#   'teach',
#   'watch',
#   'determine',
#   'hear',
#   'discover',
#   'memorise',
#   'con',
#   'study',
#   'check',
#   'take',
#   'pick_up',
#   'get_word'],
#  'shared': ['divided_up',
#   'share',
#   'divvy_up',
#   'shared',
#   'apportion',
#   'partake_in',
#   'shared_out',
#   'partake',
#   'portion_out',
#   'divided',
#   'deal'],
#  'sugarman': [],
#  'penetrating': ['riddle',
#   'penetrating',
#   'incisive',
#   'diffuse',
#   'click',
#   'discriminating',
#   'piercing',
#   'penetrate',
#   'dawn',
#   'come_home',
#   'get_across',
#   'permeate',
#   'interpenetrate',
#   'keen',
#   'penetrative',
#   'infiltrate',
#   'sink_in',
#   'fall_into_place',
#   'sharp',
#   'bottom',
#   'fathom',
#   'pervade',
#   'knifelike',
#   'perforate',
#   'get_through',
#   'acute',
#   'imbue'],
#  'labored': ['tug',
#   'drive',
#   'dig',
#   'toil',
#   'strained',
#   'moil',
#   'labor',
#   'labored',
#   'labour',
#   'grind',
#   'laboured',
#   'heavy',
#   'fag',
#   'drudge',
#   'travail',
#   'push'],
#  'decorating': ['grace',
#   'embellish',
#   'ornament',
#   'decorate',
#   'beautify',
#   'adorn',
#   'dress',
#   'deck'],
#  'layered': ['superimposed', 'layered', 'layer'],
#  'solid': ['whole',
#   'solid_state',
#   'hearty',
#   'strong',
#   'self-colored',
#   'substantial',
#   'satisfying',
#   'square',
#   'solidness',
#   'upstanding',
#   'self-coloured',
#   'unanimous',
#   'solid',
#   'firm'],
#  'campaigntrail': [],
#  'denuded': ['denude', 'strip', 'denuded', 'bare', 'denudate', 'bald'],
#  'dramatically': ['dramatically'],
#  'frustrating': ['frustrate',
#   'bilk',
#   'frustrating',
#   'cross',
#   'scotch',
#   'queer',
#   'thwarting',
#   'rag',
#   'foil',
#   'bedevil',
#   'crucify',
#   'baffle',
#   'dun',
#   'torment',
#   'spoil',
#   'frustrative',
#   'thwart'],
#  'hmmm': [],
#  'alternately': ['alternately'],
#  'stereotypical': ['stereotypic',
#   'stereotyped',
#   'stereotypical',
#   'unimaginative'],
#  'manner': ['fashion', 'manner', 'personal_manner', 'mode', 'way', 'style'],
#  'hollywood': ['Hollywood'],
#  'side': ['face',
#   'side_of_meat',
#   'English',
#   'slope',
#   'incline',
#   'position',
#   'side'],
#  'rote': ['rote_learning', 'rote'],
#  'perfect': ['staring',
#   'stark',
#   'thoroughgoing',
#   'everlasting',
#   'pure',
#   'perfective_tense',
#   'gross',
#   'unadulterated',
#   'utter',
#   'sodding',
#   'perfect_tense',
#   'arrant',
#   'double-dyed',
#   'perfect',
#   'complete',
#   'consummate',
#   'hone',
#   'perfective'],
#  'entertainingly': ['entertainingly'],
#  'translation': ['version',
#   'transformation',
#   'displacement',
#   'translation',
#   'interlingual_rendition',
#   'rendering'],
#  'mess': ['peck',
#   'tidy_sum',
#   'great_deal',
#   'heap',
#   'quite_a_little',
#   'mickle',
#   'mess_up',
#   'pot',
#   'muckle',
#   'good_deal',
#   'flock',
#   'mint',
#   'mountain',
#   'mess_hall',
#   'jam',
#   'hatful',
#   'kettle_of_fish',
#   'lot',
#   'messiness',
#   'mass',
#   'wad',
#   'mess',
#   'deal',
#   'pickle',
#   'batch',
#   'passel',
#   'plenty',
#   'fix',
#   'sight',
#   'pile',
#   'raft',
#   'slew',
#   'stack',
#   'mussiness',
#   'muddle',
#   'muss',
#   'hole',
#   'spate'],
#  'escapism': ['escape', 'escapism'],
#  'newcomers': ['fledgeling',
#   'entrant',
#   'fledgling',
#   'starter',
#   'neophyte',
#   'newbie',
#   'newcomer',
#   'freshman'],
#  'used': ['put-upon',
#   'victimised',
#   'utilise',
#   'employ',
#   'apply',
#   'use',
#   'utilize',
#   'used',
#   'ill-used',
#   'victimized',
#   'secondhand',
#   'expend',
#   'practice',
#   'exploited',
#   'habituate'],
#  'power': ['business_leader',
#   'baron',
#   'might',
#   'force',
#   'ability',
#   'office',
#   'index',
#   'superpower',
#   'exponent',
#   'big_businessman',
#   'powerfulness',
#   'mogul',
#   'power',
#   'great_power',
#   'mightiness',
#   'magnate',
#   'world_power',
#   'top_executive',
#   'king',
#   'major_power',
#   'tycoon'],
#  'bludgeoning': ['bludgeon', 'club'],
#  'opera': ['opera_house', 'Opera', 'opera'],
#  'desperation': ['desperation', 'despair'],
#  'push': ['drive',
#   'force',
#   'promote',
#   'crusade',
#   'fight',
#   'get-up-and-go',
#   'energy',
#   'pushing',
#   'push_button',
#   'campaign',
#   'labor',
#   'press',
#   'push',
#   'tug',
#   'crowd',
#   'agitate',
#   'advertise',
#   'labour',
#   'bear_on',
#   'advertize',
#   'thrust',
#   'button'],
#  'ungainly': ['ungainly',
#   'gawky',
#   'clunky',
#   'unwieldy',
#   'awkward',
#   'clumsy',
#   'bunglesome'],
#  'falls': ['hang',
#   'downslope',
#   'gloam',
#   'nightfall',
#   'flow',
#   'fall_down',
#   'dip',
#   'dusk',
#   'shine',
#   'pin',
#   'go_down',
#   'downfall',
#   'fall',
#   'Fall',
#   'spill',
#   'drop',
#   'decline',
#   'gloaming',
#   'lessen',
#   'capitulation',
#   'free_fall',
#   'light',
#   'declination',
#   'strike',
#   'precipitate',
#   'twilight',
#   'come_down',
#   'declension',
#   'autumn',
#   'declivity',
#   'tumble',
#   'devolve',
#   'settle',
#   'descend',
#   'come',
#   'falls',
#   'pass',
#   'crepuscle',
#   'decrease',
#   'return',
#   'evenfall',
#   'surrender',
#   'diminish',
#   'descent',
#   'accrue',
#   'crepuscule',
#   'waterfall'],
#  'able': ['capable', 'able', 'able-bodied'],
#  'flash': ['flash_lamp',
#   'blink_of_an_eye',
#   'news_bulletin',
#   'flare',
#   'show_off',
#   'scud',
#   'New_York_minute',
#   'tatty',
#   'shoot',
#   'twinkle',
#   'flashing',
#   'tacky',
#   'winkle',
#   'flashgun',
#   'garish',
#   'gaudy',
#   'fanfare',
#   'cheap',
#   'scoot',
#   'gimcrack',
#   'ostentation',
#   'trashy',
#   'flaunt',
#   'loud',
#   'dash',
#   'flashy',
#   'wink',
#   'brassy',
#   'blink',
#   'heartbeat',
#   'newsbreak',
#   'newsflash',
#   'instant',
#   'split_second',
#   'photoflash',
#   'flash_bulb',
#   'swank',
#   'meretricious',
#   'jiffy',
#   'flash',
#   'twinkling',
#   'flashbulb',
#   'trice',
#   'dart',
#   'tawdry',
#   'ostentate'],
#  'vistas': ['panorama', 'scene', 'vista', 'prospect', 'aspect', 'view'],
#  'tattoos': ['tattoo'],
#  'opportunity': ['chance', 'opportunity'],
#  'thoughtlessly': ['unthinkingly', 'thoughtlessly', 'unthinking'],
#  'bon': [],
#  'durable': ['long-wearing',
#   'undestroyable',
#   'long-lived',
#   'perdurable',
#   'long-lasting',
#   'lasting',
#   'indestructible',
#   'durable'],
#  'contrived': ['cast',
#   'devise',
#   'contrived',
#   'stilted',
#   'plan',
#   'forge',
#   'invent',
#   'project',
#   'excogitate',
#   'artificial',
#   'design',
#   'hokey',
#   'throw',
#   'formulate',
#   'contrive'],
#  'topnotch': ['topnotch',
#   'top-notch',
#   'crack',
#   'first-rate',
#   'super',
#   'tops',
#   'ace',
#   'A-one',
#   'tiptop'],
#  'faster': ['degenerate',
#   'faster',
#   'flying',
#   'debauched',
#   'quick',
#   'immobile',
#   'fast',
#   'loyal',
#   'degraded',
#   'riotous',
#   'libertine',
#   'dissipated',
#   'dissolute',
#   'profligate',
#   'quicker',
#   'truehearted',
#   'firm'],
#  'relentlessly': ['relentlessly', 'unrelentingly'],
#  'critical': ['vital', 'critical', 'decisive'],
#  'joyless': ['joyless'],
#  'makes': ['pee-pee',
#   'defecate',
#   'take_a_shit',
#   'draw',
#   'constitute',
#   'progress_to',
#   'attain',
#   'prepare',
#   'puddle',
#   'gain',
#   'construct',
#   'crap',
#   'get',
#   'shuffling',
#   'have',
#   'earn',
#   'work',
#   'seduce',
#   'make',
#   'hold',
#   'stool',
#   'urinate',
#   'make_believe',
#   'micturate',
#   'lay_down',
#   'reach',
#   'score',
#   'realize',
#   'create',
#   'take_a_crap',
#   'nominate',
#   'cause',
#   'shuffle',
#   'make_up',
#   'take_a_leak',
#   'ready',
#   'stimulate',
#   'build',
#   'pretend',
#   'arrive_at',
#   'establish',
#   'piddle',
#   'pass_water',
#   'get_to',
#   'piss',
#   'make_water',
#   'relieve_oneself',
#   'spend_a_penny',
#   'wee-wee',
#   'hit',
#   'bring_in',
#   'form',
#   'pee',
#   'brand',
#   'pull_in',
#   'take_in',
#   'do',
#   'clear',
#   'fix',
#   'wee',
#   'induce',
#   'realise',
#   'produce',
#   'ca-ca',
#   'cook',
#   'take',
#   'give',
#   'name',
#   'shit',
#   'throw'],
#  'directly': ['straightaway',
#   'straight_off',
#   'right_away',
#   'instantly',
#   'directly',
#   'flat',
#   'straight',
#   'forthwith',
#   'like_a_shot',
#   'immediately',
#   'now',
#   'at_once',
#   'direct'],
#  'argues': ['indicate', 'reason', 'fence', 'contend', 'argue', 'debate'],
#  'dumb': ['dull',
#   'slow',
#   'dense',
#   'speechless',
#   'dim',
#   'silent',
#   'dumb',
#   'obtuse',
#   'mute'],
#  'veggies': ['veg', 'veggie', 'vegetable'],
#  'biscuit': ['biscuit', 'cooky', 'cookie'],
#  'damage': ['legal_injury',
#   'equipment_casualty',
#   'terms',
#   'damage',
#   'hurt',
#   'impairment',
#   'harm',
#   'scathe',
#   'price',
#   'wrong'],
#  'adorably': ['endearingly', 'adorably'],
#  'giving': ['pass_on',
#   'sacrifice',
#   'cave_in',
#   'big',
#   'handsome',
#   'have',
#   'giving',
#   'make',
#   'hold',
#   'bighearted',
#   'chip_in',
#   'reach',
#   'yield',
#   'founder',
#   'present',
#   'break',
#   'feed',
#   'generate',
#   'gift',
#   'commit',
#   'afford',
#   'turn_over',
#   'contribute',
#   'establish',
#   'open',
#   'dedicate',
#   'hand',
#   'consecrate',
#   'grant',
#   'pay',
#   'ease_up',
#   'fall_in',
#   'render',
#   'bounteous',
#   'impart',
#   'bountiful',
#   'move_over',
#   'apply',
#   'pass',
#   'openhanded',
#   'kick_in',
#   'give',
#   'return',
#   'freehanded',
#   'liberal',
#   'collapse',
#   'devote',
#   'give_way',
#   'throw',
#   'leave'],
#  'wrong': ['untimely',
#   'faulty',
#   'unseasonable',
#   'wrongfulness',
#   'haywire',
#   'amiss',
#   'ill-timed',
#   'damage',
#   'incorrect',
#   'improper',
#   'wrong',
#   'legal_injury',
#   'awry',
#   'incorrectly',
#   'wrongly'],
#  'rohmer': [],
#  'chuckles': ['chuckle', 'chortle', 'laugh_softly'],
#  'decent': ['nice',
#   'seemly',
#   'enough',
#   'comely',
#   'properly',
#   'decorous',
#   'comme_il_faut',
#   'decently',
#   'the_right_way',
#   'right',
#   'decent',
#   'in_good_order',
#   'becoming',
#   'adequate'],
#  'crass': ['crass'],
#  'helljaunt': [],
#  'suburban': ['suburban'],
#  'creature': ['creature',
#   'animate_being',
#   'fauna',
#   'puppet',
#   'wight',
#   'beast',
#   'brute',
#   'animal',
#   'tool'],
#  'ii': ['ii', '2', 'II', 'two', 'deuce'],
#  'eye': ['eye',
#   'centre',
#   'optic',
#   'oculus',
#   'heart',
#   'middle',
#   'eyeball',
#   'center'],
#  'family': ['menage',
#   'category',
#   'syndicate',
#   'family_line',
#   'family_unit',
#   'home',
#   'kinfolk',
#   'sept',
#   'family',
#   'kin',
#   'mob',
#   'fellowship',
#   'kinsperson',
#   'class',
#   'folk',
#   'household',
#   'crime_syndicate',
#   'phratry',
#   'kinsfolk',
#   'house'],
#  'station': ['post', 'station', 'place', 'send'],
#  'clarity': ['uncloudedness',
#   'clarity',
#   'lucidness',
#   'pellucidity',
#   'lucidity',
#   'limpidity',
#   'clearness'],
#  'decoder': ['decoder', 'decipherer'],
#  'bourgeois': ['businessperson',
#   'materialistic',
#   'conservative',
#   'bourgeois',
#   'burgher'],
#  'snaillike': [],
#  'held': ['maintain',
#   'view_as',
#   'obligate',
#   'concur',
#   'restrain',
#   'curb',
#   'admit',
#   'have',
#   'withstand',
#   'control',
#   'make',
#   'hold',
#   'defend',
#   'hold_back',
#   'halt',
#   'agree',
#   'obtain',
#   'retain',
#   'keep',
#   'harbor',
#   'reserve',
#   'keep_back',
#   'hold_up',
#   'deem',
#   'take_for',
#   'support',
#   'contain',
#   'held',
#   'bear',
#   'carry',
#   'defy',
#   'prevail',
#   'arrest',
#   'book',
#   'harbour',
#   'moderate',
#   'have_got',
#   'declare',
#   'nurse',
#   'entertain',
#   'oblige',
#   'go_for',
#   'hold_in',
#   'confine',
#   'bind',
#   'apply',
#   'accommodate',
#   'check',
#   'take_hold',
#   'give',
#   'take',
#   'concord',
#   'adjudge',
#   'sustain',
#   'guard',
#   'throw'],
#  'movies': ['movie',
#   'picture',
#   'picture_show',
#   'flick',
#   'moving-picture_show',
#   'film',
#   'pic',
#   'motion_picture',
#   'moving_picture',
#   'motion-picture_show'],
#  'leblanc': [],
#  'information': ['entropy',
#   'information',
#   'info',
#   'selective_information',
#   'data'],
#  'actory': [],
#  'flops': ['fizzle',
#   'bust',
#   'flop',
#   'founder',
#   'washout',
#   'fall_through',
#   'floating-point_operation',
#   'collapse',
#   'fall_flat',
#   'dud'],
#  'brilliance': ['blaze',
#   'glare',
#   'magnificence',
#   'grandeur',
#   'grandness',
#   'brilliance',
#   'splendor',
#   'genius',
#   'splendour'],
#  'kinky': ['offbeat',
#   'frizzly',
#   'frizzy',
#   'way-out',
#   'quirky',
#   'perverted',
#   'nappy',
#   'crisp',
#   'kinky',
#   'far-out'],
#  'nobody': ['cypher', 'nonentity', 'nobody', 'cipher'],
#  'firstrate': [],
#  'colorful': ['colorful', 'colored', 'colourful', 'coloured'],
#  'legged': ['legged'],
#  'looks': ['await',
#   'tone',
#   'count',
#   'bet',
#   'take_care',
#   'look',
#   'facial_expression',
#   'appear',
#   'flavour',
#   'aspect',
#   'reckon',
#   'calculate',
#   'face',
#   'see',
#   'seem',
#   'looking',
#   'depend',
#   'feeling',
#   'smell',
#   'front',
#   'flavor',
#   'spirit',
#   'wait',
#   'search',
#   'expression',
#   'looking_at',
#   'expect',
#   'feel',
#   'attend'],
#  'altogether': ['whole',
#   'entirely',
#   'on_the_whole',
#   'all_told',
#   'tout_ensemble',
#   'raw',
#   'totally',
#   'all',
#   'all_in_all',
#   'in_all',
#   'wholly',
#   'completely',
#   'birthday_suit',
#   'altogether'],
#  'unabashedly': ['unabashedly'],
#  'awakening': ['awakening',
#   'waken',
#   'come_alive',
#   'awake',
#   'wakening',
#   'wake',
#   'wake_up',
#   'rouse',
#   'arouse',
#   'waking_up',
#   'awaken'],
#  'christmas': ['Noel',
#   'Xmas',
#   'Christmas_Day',
#   'Dec_25',
#   'Christmastime',
#   'Yule',
#   'Christmas',
#   'Christmastide',
#   'Yuletide'],
#  'crowd': ['crew', 'crowd_together', 'crowd', 'bunch', 'herd', 'gang', 'push'],
#  'effectively': ['efficaciously', 'in_effect', 'effectively'],
#  'and': [],
#  'banal': ['timeworn',
#   'commonplace',
#   'shopworn',
#   'tired',
#   'banal',
#   'old-hat',
#   'stock',
#   'threadbare',
#   'trite',
#   'well-worn',
#   'hackneyed'],
#  'return': ['riposte',
#   'take_back',
#   'deliver',
#   'getting_even',
#   'hark_back',
#   'restitution',
#   'refund',
#   'turn_back',
#   'reappearance',
#   'coming_back',
#   'recall',
#   'fall',
#   'yield',
#   'recurrence',
#   'replication',
#   'restoration',
#   'generate',
#   'bring_back',
#   'proceeds',
#   'takings',
#   'reelect',
#   'retrovert',
#   'payoff',
#   'homecoming',
#   'give_back',
#   'render',
#   'tax_return',
#   'return_key',
#   'regaining',
#   'counter',
#   'retort',
#   'paying_back',
#   'rejoinder',
#   'come_back',
#   'devolve',
#   'repay',
#   'income_tax_return',
#   'comeback',
#   'pass',
#   'issue',
#   'take',
#   'give',
#   'return',
#   'revert',
#   'rejoin',
#   'regress'],
#  'hitch': ['jerk',
#   'hobble',
#   'duty_tour',
#   'incumbrance',
#   'snag',
#   'thumb',
#   'halt',
#   'tour_of_duty',
#   'interference',
#   'rub',
#   'stop',
#   'buck',
#   'hindrance',
#   'encumbrance',
#   'term_of_enlistment',
#   'preventive',
#   'arrest',
#   'tour',
#   'limp',
#   'hang-up',
#   'hitchhike',
#   'stay',
#   'hinderance',
#   'gimp',
#   'check',
#   'preventative',
#   'hitch',
#   'enlistment',
#   'stoppage',
#   'catch'],
#  'superficial': ['trivial', 'superficial'],
#  'children': ['nipper',
#   'minor',
#   'nestling',
#   'baby',
#   'small_fry',
#   'tiddler',
#   'youngster',
#   'fry',
#   'tyke',
#   'child',
#   'shaver',
#   'kid',
#   'tike'],
#  'whatsoever': ['whatsoever', 'whatever', 'any'],
#  'often': ['much',
#   'often',
#   'frequently',
#   'oft',
#   'oftentimes',
#   'a_great_deal',
#   'ofttimes'],
#  'pretentious': ['pretentious', 'ostentatious'],
#  'credits': ['credit_entry',
#   'acknowledgment',
#   'credits',
#   'citation',
#   'reference',
#   'mention',
#   'credit',
#   'recognition',
#   'credit_rating',
#   'quotation',
#   'cite',
#   'course_credit',
#   'accredit',
#   'deferred_payment'],
#  'girlish': ['girlish', 'schoolgirlish'],
#  'certainly': ['for_certain',
#   'certainly',
#   'sure_as_shooting',
#   'for_sure',
#   'sure_enough',
#   'surely',
#   'sure'],
#  'ritchie': [],
#  'liar': ['prevaricator', 'liar'],
#  'stanzas': ['stanza'],
#  'advised': ['rede',
#   'apprise',
#   'propose',
#   'counsel',
#   'send_word',
#   'advised',
#   'well-advised',
#   'suggest',
#   'apprize',
#   'give_notice',
#   'advise',
#   'notify'],
#  'ramblings': ['cast',
#   'range',
#   'roll',
#   'vagabond',
#   'ramble_on',
#   'ramble',
#   'jog',
#   'tramp',
#   'swan',
#   'rove',
#   'stray',
#   'drift',
#   'wander',
#   'roam'],
#  'willing': ['uncoerced',
#   'will',
#   'bequeath',
#   'unforced',
#   'volition',
#   'willing',
#   'leave'],
#  'coherent': ['ordered',
#   'logical',
#   'tenacious',
#   'consistent',
#   'coherent',
#   'lucid'],
#  'seen': ['understand',
#   'regard',
#   'find_out',
#   'run_across',
#   'figure',
#   'visualize',
#   'date',
#   'learn',
#   'take_care',
#   'project',
#   'get_wind',
#   'look',
#   'find',
#   'go_steady',
#   'control',
#   'reckon',
#   'get_a_line',
#   'visit',
#   'see',
#   'realize',
#   'picture',
#   'encounter',
#   'escort',
#   'ascertain',
#   'come_across',
#   'see_to_it',
#   'assure',
#   'watch',
#   'determine',
#   'envision',
#   'experience',
#   'hear',
#   'interpret',
#   'witness',
#   'discover',
#   'take_in',
#   'examine',
#   'visualise',
#   'realise',
#   'construe',
#   'image',
#   'check',
#   'insure',
#   'go_through',
#   'pick_up',
#   'run_into',
#   'get_word',
#   'meet',
#   'consider',
#   'ensure',
#   'fancy',
#   'go_out',
#   'view',
#   'attend',
#   'catch'],
#  'proceedings': ['go_on',
#   'carry_on',
#   'proceedings',
#   'go_forward',
#   'proceeding',
#   'keep',
#   'go',
#   'transactions',
#   'legal_proceeding',
#   'minutes',
#   'go_along',
#   'continue',
#   'move',
#   'proceed'],
#  'tricks': ['pull_a_fast_one_on',
#   'caper',
#   'play_a_joke_on',
#   'put-on',
#   'whoremonger',
#   'fob',
#   'play_tricks',
#   'play_a_trick_on',
#   'conjuration',
#   'antic',
#   'joke',
#   'magic',
#   'legerdemain',
#   'conjuring_trick',
#   'thaumaturgy',
#   'magic_trick',
#   'trick',
#   'john',
#   'prank',
#   'flim-flam',
#   'fast_one',
#   'deception',
#   'illusion',
#   'fox',
#   'whoremaster'],
#  'downright': ['sheer',
#   'out-and-out',
#   'downright',
#   'absolute',
#   'rank',
#   'right-down'],
#  'try': ['attempt',
#   'endeavor',
#   'try_on',
#   'sample',
#   'assay',
#   'judge',
#   'try',
#   'adjudicate',
#   'render',
#   'endeavour',
#   'effort',
#   'hear',
#   'prove',
#   'test',
#   'examine',
#   'essay',
#   'strain',
#   'seek',
#   'stress',
#   'taste',
#   'try_out'],
#  'cheesier': ['sleazy',
#   'crummy',
#   'cheesy',
#   'chintzy',
#   'punk',
#   'bum',
#   'tinny',
#   'cheap'],
#  'zemeckis': [],
#  'them': [],
#  'transcendence': ['superiority', 'transcendence', 'transcendency'],
#  'while': ['spell', 'while', 'piece', 'patch'],
#  'flat': ['monotonous',
#   'compressed',
#   'categoric',
#   'directly',
#   'level',
#   'plane',
#   'flavourless',
#   'insipid',
#   '2-dimensional',
#   'matte',
#   'categorical',
#   'flatbed',
#   'prostrate',
#   'monotonic',
#   'savorless',
#   'mat',
#   'savourless',
#   'flat',
#   'straight',
#   'flavorless',
#   'two-dimensional',
#   'vapid',
#   'bland',
#   'matt',
#   'apartment',
#   'unconditional',
#   'flatcar',
#   'matted',
#   'monotone',
#   'flat_tire'],
#  'deadly': ['lifelessly',
#   'venomous',
#   'deadly',
#   'virulent',
#   'baneful',
#   'pernicious',
#   'mortal',
#   'madly',
#   'insanely',
#   'deucedly',
#   'deathly',
#   'pestilent',
#   'lethal',
#   'devilishly'],
#  'both': ['both'],
#  'pack': ['compact',
#   'camp',
#   'large_number',
#   'tamp_down',
#   'inner_circle',
#   'jam',
#   'mob',
#   'gang',
#   'wad',
#   'carry',
#   'backpack',
#   'face_pack',
#   'battalion',
#   'pack',
#   'load_down',
#   'bundle',
#   'clique',
#   'coterie',
#   'pile',
#   'throng',
#   'multitude',
#   'plurality',
#   'take',
#   'ingroup',
#   'ring',
#   'tamp'],
#  'bullock': ['bullock', 'steer'],
#  'night': ['nighttime', 'dark', 'Nox', 'night', 'Night'],
#  'camerawork': [],
#  'soulful': ['soulful'],
#  'littleknown': [],
#  'traveler': ['traveller', 'traveler'],
#  'done': ['manage',
#   'get_along',
#   'answer',
#   'set',
#   'fare',
#   'make',
#   'execute',
#   'serve',
#   'arrange',
#   'practise',
#   'through',
#   'cause',
#   'coif',
#   'act',
#   'perform',
#   'exercise',
#   'suffice',
#   'do',
#   'coiffure',
#   'behave',
#   'through_with',
#   'done',
#   'come',
#   'coiffe',
#   'make_out',
#   'practice',
#   'dress'],
#  'just': ['hardly',
#   'scarce',
#   'merely',
#   'just',
#   'only',
#   'simply',
#   'but',
#   'barely',
#   'scarcely',
#   'just_now',
#   'fair',
#   'upright',
#   'good',
#   'equitable',
#   'exactly',
#   'precisely'],
#  'nonjudgmental': ['nonjudgmental'],
#  'even': ['evening',
#   'regular',
#   'eventide',
#   'still',
#   'even_out',
#   'yet',
#   'flush',
#   'fifty-fifty',
#   'eve',
#   'tied',
#   'even',
#   'level'],
#  'ring': ['phone',
#   'closed_chain',
#   'reverberate',
#   'call',
#   'halo',
#   'resound',
#   'tintinnabulation',
#   'telephone',
#   'peal',
#   'mob',
#   'anchor_ring',
#   'gang',
#   'call_up',
#   'surround',
#   'pack',
#   'band',
#   'annulus',
#   'ringing',
#   'echo',
#   'border',
#   'hoop',
#   'environ',
#   'doughnut',
#   'ring',
#   'skirt',
#   'knell'],
#  'lingerie': ['lingerie', 'intimate_apparel'],
#  'satisfies': ['fulfill',
#   'live_up_to',
#   'gratify',
#   'meet',
#   'fill',
#   'satisfy',
#   'fulfil'],
#  'gangstercrime': [],
#  'merrily': ['jubilantly',
#   'happily',
#   'merrily',
#   'gayly',
#   'blithely',
#   'mirthfully'],
#  'ought': [],
#  'bracing': ['stabilise',
#   'refreshing',
#   'perk_up',
#   'brisk',
#   'bracing',
#   'poise',
#   'energise',
#   'stabilize',
#   'arouse',
#   'stimulate',
#   'brace',
#   'fresh',
#   'steady',
#   'energize',
#   'tonic',
#   'refreshful'],
#  'dynamics': ['kinetics', 'dynamic', 'moral_force', 'dynamics'],
#  'chicago': ['Michigan',
#   'Newmarket',
#   'Windy_City',
#   'boodle',
#   'Chicago',
#   'stops'],
#  'food': ['food_for_thought',
#   'solid_food',
#   'nutrient',
#   'intellectual_nourishment',
#   'food'],
#  'anchored': ['ground', 'drop_anchor', 'anchor', 'cast_anchor'],
#  'shoot': ['inject',
#   'burgeon_forth',
#   'pip',
#   'frivol_away',
#   'tear',
#   'spud',
#   'charge',
#   'scud',
#   'fool_away',
#   'shoot',
#   'buck',
#   'snap',
#   'shoot_down',
#   'film',
#   'scoot',
#   'germinate',
#   'bourgeon',
#   'dash',
#   'fool',
#   'hit',
#   'fritter',
#   'sprout',
#   'photograph',
#   'fritter_away',
#   'take',
#   'flash',
#   'dart',
#   'pullulate',
#   'blast',
#   'dissipate'],
#  'experimental': ['data-based', 'observational', 'experimental'],
#  'wisegirls': [],
#  'ago': ['ago', 'agone'],
#  'delightful': ['delicious', 'delightful'],
#  'thin': ['slender',
#   'flimsy',
#   'fragile',
#   'lean',
#   'sparse',
#   'reduce',
#   'slight',
#   'slenderize',
#   'tenuous',
#   'slim',
#   'thinly',
#   'cut',
#   'thin_out',
#   'thin',
#   'dilute',
#   'slim_down',
#   'melt_off',
#   'lose_weight'],
#  'eyes': ['eye',
#   'optic',
#   'centre',
#   'oculus',
#   'heart',
#   'middle',
#   'eyeball',
#   'eyes',
#   'center'],
#  'antwone': [],
#  'grinds': ['pulverization',
#   'travail',
#   'donkeywork',
#   'crunch',
#   'bray',
#   'mash',
#   'swot',
#   'fag',
#   'grate',
#   'drudgery',
#   'dig',
#   'toil',
#   'labor',
#   'craunch',
#   'grind',
#   'drudge',
#   'cranch',
#   'plodding',
#   'comminute',
#   'mill',
#   'dweeb',
#   'moil',
#   'labour',
#   'nerd',
#   'pulverisation',
#   'wonk'],
#  'shrek': [],
#  'cremaster': [],
#  'actually': ['in_reality', 'actually', 'really'],
#  'precious': ['cute',
#   'precious',
#   'wanted',
#   'cherished',
#   'valued',
#   'treasured',
#   'preciously'],
#  'overladen': ['overladen', 'overloaded'],
#  'dogs': ['cad',
#   'pawl',
#   'tag',
#   'hound',
#   'tail',
#   'blackguard',
#   'heel',
#   'click',
#   'frankfurter',
#   'frank',
#   'wiener',
#   'give_chase',
#   'chase',
#   'bounder',
#   'Canis_familiaris',
#   'go_after',
#   'hotdog',
#   'dog',
#   'dog-iron',
#   'andiron',
#   'hot_dog',
#   'trail',
#   'domestic_dog',
#   'track',
#   'weenie',
#   'chase_after',
#   'wienerwurst',
#   'frump',
#   'firedog',
#   'detent'],
#  'without': [],
#  'pick': ['peck',
#   'nibble',
#   'choice',
#   'plectrum',
#   'pickaxe',
#   'woof',
#   'pickax',
#   'selection',
#   'picking',
#   'pluck',
#   'clean',
#   'break_up',
#   'piece',
#   'cream',
#   'cull',
#   'beak',
#   'plunk',
#   'filling',
#   'weft',
#   'option',
#   'blame',
#   'find_fault',
#   'plectron',
#   'pick',
#   'foot'],
#  'channeling': ['carry',
#   'transport',
#   'canalize',
#   'channelize',
#   'channelise',
#   'convey',
#   'transmit',
#   'transfer',
#   'conduct',
#   'channel',
#   'impart',
#   'canalise'],
#  'arty': ['arty'],
#  'playfully': ['playfully'],
#  'contest': ['repugn', 'contend', 'contest', 'competition'],
#  'imagemongering': [],
#  'noticeable': ['noticeable', 'detectable', 'obtrusive'],
#  'italicizes': ['italicise', 'italicize'],
#  'exhibitionism': ['immodesty', 'exhibitionism'],
#  'possibilities': ['hypothesis',
#   'opening',
#   'possibleness',
#   'theory',
#   'possibility',
#   'possible_action'],
#  'agesold': [],
#  'glow': ['radiate',
#   'gleaming',
#   'burn',
#   'freshness',
#   'luminescence',
#   'incandescence',
#   'beam',
#   'glow',
#   'gleam',
#   'shine',
#   'lambency',
#   'radiance',
#   'glowing'],
#  'oozing': ['exude',
#   'ooze',
#   'transude',
#   'oozing',
#   'seep',
#   'seeping',
#   'seepage',
#   'ooze_out',
#   'exudate',
#   'oozy'],
#  'violent': ['red',
#   'fierce',
#   'wild',
#   'trigger-happy',
#   'crimson',
#   'tearing',
#   'vehement',
#   'violent'],
#  'force': ['force_out',
#   'drive',
#   'military_unit',
#   'draw',
#   'effect',
#   'force',
#   'pull',
#   'military_force',
#   'violence',
#   'pressure',
#   'force_play',
#   'impel',
#   'military_group',
#   'ram',
#   'hale',
#   'personnel',
#   'power',
#   'push',
#   'storm',
#   'forcefulness',
#   'force-out',
#   'coerce',
#   'wedge',
#   'squeeze',
#   'thrust',
#   'strength'],
#  'cram': ['bone',
#   'jam',
#   'chock_up',
#   'grind_away',
#   'swot_up',
#   'ram',
#   'get_up',
#   'swot',
#   'mug_up',
#   'jampack',
#   'drum',
#   'bone_up',
#   'wad',
#   'cram'],
#  'dull': ['muted',
#   'ho-hum',
#   'dim',
#   'dumb',
#   'tedious',
#   'dampen',
#   'pall',
#   'irksome',
#   'dull',
#   'muffled',
#   'wearisome',
#   'tone_down',
#   'thudding',
#   'softened',
#   'sluggish',
#   'tiresome',
#   'mute',
#   'numb',
#   'leaden',
#   'blunt',
#   'slow',
#   'deadening',
#   'dense',
#   'benumb',
#   'boring',
#   'obtuse',
#   'damp',
#   'muffle'],
#  'rapidfire': [],
#  'signs': ['signaling',
#   'mark',
#   'sign_up',
#   'mansion',
#   'foretoken',
#   'augury',
#   'subscribe',
#   'sign_on',
#   'bless',
#   'sign',
#   'signal',
#   'planetary_house',
#   'ratify',
#   'contract',
#   'signboard',
#   'signalize',
#   'star_sign',
#   'signalise',
#   'polarity',
#   'sign_of_the_zodiac',
#   'preindication',
#   'house'],
#  'unruly': ['robustious',
#   'boisterous',
#   'unruly',
#   'rumbustious',
#   'indocile',
#   'rambunctious',
#   'ungovernable',
#   'uncontrollable',
#   'disobedient'],
#  'canvas': ['examine',
#   'analyse',
#   'sheet',
#   'poll',
#   'study',
#   'analyze',
#   'canvass',
#   'canvas',
#   'sail',
#   'canvas_tent'],
#  'sounding': ['voice',
#   'fathom',
#   'vocalize',
#   'go',
#   'sound',
#   'looking',
#   'sounding',
#   'vocalise'],
#  'deadon': [],
#  'kicking': ['kicking',
#   'recoil',
#   'sound_off',
#   'kvetch',
#   'quetch',
#   'plain',
#   'kick_back',
#   'complain',
#   'kick',
#   'give_up',
#   'boot'],
#  'on': ['along', 'on'],
#  'five': ['cinque',
#   'quintet',
#   'quint',
#   'v',
#   'pentad',
#   'five',
#   'Little_Phoebe',
#   'V',
#   'fin',
#   'five-spot',
#   'quintuplet',
#   'Phoebe',
#   'basketball_team',
#   '5',
#   'fivesome'],
#  'swear': ['curse',
#   'depone',
#   'depose',
#   'verify',
#   'assert',
#   'aver',
#   'swan',
#   'swear',
#   'trust',
#   'bank',
#   'affirm',
#   'avow',
#   'imprecate',
#   'rely',
#   'cuss',
#   'blaspheme'],
#  'genre': ['musical_genre',
#   'literary_genre',
#   'musical_style',
#   'genre',
#   'music_genre',
#   'writing_style'],
#  'characteristically': ['characteristically'],
#  'truly': ['sincerely',
#   'unfeignedly',
#   'rightfully',
#   'really',
#   'truly',
#   'in_truth',
#   'genuinely'],
#  'conceive': ['gestate',
#   'conceptualise',
#   'believe',
#   'conceptualize',
#   'consider',
#   'conceive',
#   'think'],
#  'convincing': ['win_over', 'convert', 'convince', 'convincing'],
#  'selfconsciously': [],
#  'equation': ['equation', 'par', 'equating', 'equivalence', 'equality'],
#  'anteing': ['ante'],
#  'blockbuster': ['blockbuster', 'smash_hit', 'megahit'],
#  'dimness': ['faintness', 'dimness', 'duskiness', 'subduedness'],
#  'hope': ['go_for',
#   'desire',
#   'trust',
#   'hope',
#   'Hope',
#   'Bob_Hope',
#   'Leslie_Townes_Hope',
#   'promise'],
#  'grow': ['acquire',
#   'arise',
#   'produce',
#   'spring_up',
#   'farm',
#   'turn',
#   'mature',
#   'get',
#   'grow',
#   'raise',
#   'maturate',
#   'rise',
#   'originate',
#   'uprise',
#   'develop'],
#  'dialogue': ['dialog', 'duologue', 'dialogue', 'talks', 'negotiation'],
#  'selfexpression': [],
#  'fact': ['fact'],
#  'storyline': ['plot_line', 'storyline'],
#  'overworked': ['exploit', 'overwork'],
#  'landing': ['landing',
#   'down',
#   'land',
#   'shore',
#   'bring_down',
#   'shoot_down',
#   'set_down',
#   'set_ashore',
#   'landing_place',
#   'put_down',
#   'bring'],
#  'captions': ['caption', 'subtitle', 'legend'],
#  'storytelling': [],
#  'match': ['equalize',
#   'match',
#   'mates',
#   'compeer',
#   'twin',
#   'agree',
#   'equal',
#   'pit',
#   'friction_match',
#   'lucifer',
#   'equate',
#   'tally',
#   'rival',
#   'fit',
#   'oppose',
#   'cope_with',
#   'mate',
#   'gibe',
#   'pair',
#   'peer',
#   'correspond',
#   'couple',
#   'check',
#   'touch',
#   'play_off',
#   'jibe',
#   'meet',
#   'equalise',
#   'catch'],
#  'actionpacked': [],
#  'eloquent': ['smooth-spoken',
#   'silver-tongued',
#   'silver',
#   'facile',
#   'eloquent',
#   'fluent'],
#  'actors': ['doer',
#   'actor',
#   'worker',
#   'histrion',
#   'player',
#   'thespian',
#   'role_player'],
#  'swung': ['dangle',
#   'swing_out',
#   'swing_over',
#   'drop',
#   'get_around',
#   'sweep',
#   'sway',
#   'swing'],
#  'wistfully': ['wistfully'],
#  'depiction': ['depiction',
#   'word_picture',
#   'picture',
#   'portraying',
#   'depicting',
#   'line_drawing',
#   'portrayal',
#   'limning',
#   'characterisation',
#   'characterization',
#   'delineation',
#   'word-painting'],
#  'premise': ['premise',
#   'introduce',
#   'premiss',
#   'assumption',
#   'precede',
#   'preface'],
#  'would': [],
#  'twelveyearold': [],
#  'angst': ['angst'],
#  'chateau': ['chateau'],
#  'newfangled': ['newfangled', 'new'],
#  'foolish': ['jerky',
#   'anserine',
#   'goosey',
#   'goosy',
#   'gooselike',
#   'foolish',
#   'dopy',
#   'dopey'],
#  'way': ['agency',
#   'fashion',
#   'right_smart',
#   'manner',
#   'mode',
#   'way_of_life',
#   'room',
#   'path',
#   'way',
#   'elbow_room',
#   'means',
#   'style',
#   'direction'],
#  'pie': ['PIE', 'pie', 'Proto-Indo_European'],
#  'promising': ['anticipate',
#   'hopeful',
#   'assure',
#   'call',
#   'prognosticate',
#   'foretell',
#   'bright',
#   'promising',
#   'forebode',
#   'promise',
#   'predict'],
#  'peep': ['chirp', 'chirrup', 'cheep', 'peep', 'peek'],
#  'urban': ['urban'],
#  'demonstrate': ['attest',
#   'certify',
#   'march',
#   'present',
#   'exhibit',
#   'shew',
#   'evidence',
#   'show',
#   'prove',
#   'demo',
#   'manifest',
#   'establish',
#   'demonstrate'],
#  'fit': ['scene',
#   'convulsion',
#   'match',
#   'primed',
#   'set',
#   'suit',
#   'outfit',
#   'burst',
#   'agree',
#   'equip',
#   'tantrum',
#   'go',
#   'tally',
#   'fit',
#   'fit_out',
#   'paroxysm',
#   'conform_to',
#   'gibe',
#   'correspond',
#   'conniption',
#   'check',
#   'accommodate',
#   'meet',
#   'jibe'],
#  'funnier': ['risible',
#   'suspect',
#   'peculiar',
#   'suspicious',
#   'amusing',
#   'odd',
#   'shady',
#   'queer',
#   'curious',
#   'fishy',
#   'comical',
#   'funny',
#   'mirthful',
#   'rum',
#   'singular',
#   'laughable',
#   'comic',
#   'rummy'],
#  'painfully': ['painfully', 'sorely', 'distressingly'],
#  'watchable': [],
#  'feelgood': [],
#  'halfway': ['middle', 'center', 'halfway', 'midway'],
#  'girls': ['little_girl',
#   'fille',
#   'lady_friend',
#   'missy',
#   'daughter',
#   'young_woman',
#   'miss',
#   'girlfriend',
#   'young_lady',
#   'girl',
#   'female_child'],
#  'gestalt': ['gestalt'],
#  'something': [],
#  'insight': ['sixth_sense',
#   'brainstorm',
#   'penetration',
#   'perceptiveness',
#   'brainwave',
#   'insight',
#   'perceptivity'],
#  'limp': ['hobble', 'gimp', 'limp', 'hitch', 'wilted'],
#  'silver': ['silver_medal',
#   'silver_gray',
#   'atomic_number_47',
#   'ash_gray',
#   'smooth-spoken',
#   'silvery',
#   'silvern',
#   'silver',
#   'Ag',
#   'silver_grey',
#   'argent',
#   'silverish',
#   'facile',
#   'silver-tongued',
#   'eloquent',
#   'fluent',
#   'flatware',
#   'ash_grey'],
#  'cut': ['trimmed',
#   'veer',
#   'tailor',
#   'cutting',
#   'undercut',
#   'rationalise',
#   'foreshorten',
#   'bring_down',
#   'snub',
#   'shortened',
#   'hack',
#   'turn_out',
#   'cold_shoulder',
#   'skip',
#   'deletion',
#   'gash',
#   'thinned',
#   'trim_down',
#   'swerve',
#   'excision',
#   'cut_of_meat',
#   'slice',
#   'cutting_off',
#   'trend',
#   'write_out',
#   'sheer',
#   'reduce',
#   'edit_out',
#   'cut_down',
#   'cut_off',
#   'gelded',
#   'thin',
#   'dilute',
#   'thin_out',
#   'stinger',
#   'weakened',
#   'turn_off',
#   'burn',
#   'slash',
#   'trim',
#   'contract',
#   'shorten',
#   'trim_back',
#   'geld',
#   'abridge',
#   'cut',
#   'prune',
#   'slue',
#   'abbreviate',
#   'edit',
#   'cut_back',
#   'swing',
#   'baseball_swing',
#   'slew',
#   'disregard',
#   'track',
#   'issue',
#   'slashed',
#   'make_out',
#   'mown',
#   'curve',
#   'ignore',
#   'emasculated',
#   'rationalize',
#   'switch_off'],
#  'labors': ['task',
#   'drive',
#   'childbed',
#   'project',
#   'Labour_Party',
#   'confinement',
#   'lying-in',
#   'trade_union_movement',
#   'labor_movement',
#   'DoL',
#   'fag',
#   'Labor',
#   'dig',
#   'toil',
#   'British_Labour_Party',
#   'labor',
#   'proletariat',
#   'Labor_Department',
#   'grind',
#   'drudge',
#   'push',
#   'tug',
#   'Department_of_Labor',
#   'parturiency',
#   'moil',
#   'labour',
#   'undertaking',
#   'Labour',
#   'travail',
#   'working_class'],
#  'advice': ['advice'],
#  'mouthpieces': ['gumshield', 'embouchure', 'mouth', 'mouthpiece'],
#  'twentyfourandunders': [],
#  'step': ['tone',
#   "stone's_throw",
#   'dance_step',
#   'footfall',
#   'footprint',
#   'ill-treat',
#   'gradation',
#   'whole_tone',
#   'measure',
#   'stride',
#   'footmark',
#   'maltreat',
#   'whole_step',
#   'footstep',
#   'stair',
#   'abuse',
#   'step',
#   'ill-use',
#   'tread',
#   'mistreat',
#   'pace'],
#  'black': ['pitch_blackness',
#   'Black_person',
#   'dim',
#   'disgraceful',
#   'Joseph_Black',
#   'melanize',
#   'smutty',
#   'melanise',
#   'blackened',
#   'calamitous',
#   'pitch-dark',
#   'Negro',
#   'blackness',
#   'Shirley_Temple_Black',
#   'disastrous',
#   'inkiness',
#   'pitch-black',
#   'Shirley_Temple',
#   'Black',
#   'fateful',
#   'blacken',
#   'contraband',
#   'inglorious',
#   'blackamoor',
#   'bootleg',
#   'opprobrious',
#   'nigrify',
#   'fatal',
#   'lightlessness',
#   'smuggled',
#   'sinister',
#   'mordant',
#   'bleak',
#   'black',
#   'black-market',
#   'dark',
#   'grim',
#   'shameful',
#   'Negroid',
#   'total_darkness',
#   'ignominious'],
#  'tries': ['attempt',
#   'endeavor',
#   'try_on',
#   'sample',
#   'assay',
#   'judge',
#   'try',
#   'adjudicate',
#   'render',
#   'endeavour',
#   'effort',
#   'hear',
#   'prove',
#   'test',
#   'examine',
#   'essay',
#   'strain',
#   'seek',
#   'stress',
#   'taste',
#   'try_out'],
#  'native': ['indigen', 'indigene', 'native', 'aboriginal', 'aborigine'],
#  'guilty': ['hangdog', 'guilty', 'shamed', 'shamefaced'],
#  'fore': ['stem', 'prow', 'fore', 'bow', 'forward'],
#  'pastiche': ['potpourri', 'pastiche', 'medley'],
#  'name': ['figure',
#   'constitute',
#   'epithet',
#   'call',
#   'key_out',
#   'refer',
#   'make',
#   'diagnose',
#   'appoint',
#   'nominate',
#   'describe',
#   'cite',
#   'distinguish',
#   'list',
#   'key',
#   'public_figure',
#   'discover',
#   'mention',
#   'identify',
#   'name',
#   'bring_up',
#   'advert',
#   'gens'],
#  'busy': ['fussy',
#   'officious',
#   'meddlesome',
#   'in_use',
#   'engaged',
#   'busybodied',
#   'busy',
#   'occupy',
#   'interfering',
#   'meddling'],
#  'history': ['chronicle', 'story', 'account', 'history'],
#  'mib': ['M', 'megabyte', 'MB', 'mebibyte', 'MiB'],
#  'cinema': ['picture_palace',
#   'movie_theater',
#   'movie_house',
#   'cinema',
#   'film',
#   'celluloid',
#   'movie_theatre'],
#  'we': [],
#  'imagine': ['guess',
#   'envisage',
#   'imagine',
#   'suppose',
#   'conceive_of',
#   'opine',
#   'reckon',
#   'think',
#   'ideate'],
#  'quickly': ['chop-chop',
#   'apace',
#   'quickly',
#   'quick',
#   'speedily',
#   'rapidly',
#   'cursorily',
#   'promptly'],
#  'this': [],
#  'subjects': ['subject_field',
#   'national',
#   'subject',
#   'content',
#   'field',
#   'case',
#   'submit',
#   'bailiwick',
#   'subjugate',
#   'theme',
#   'field_of_study',
#   'topic',
#   'subject_area',
#   'matter',
#   'discipline',
#   'study',
#   'issue',
#   'depicted_object',
#   'guinea_pig'],
#  'awarded': ['present', 'award', 'grant'],
#  'performances': ['operation',
#   'execution',
#   'carrying_out',
#   'functioning',
#   'carrying_into_action',
#   'public_presentation',
#   'performance'],
#  'imponderably': [],
#  'his': [],
#  'undeniable': ['undeniable'],
#  'ethics': ['morals',
#   'value_orientation',
#   'ethic',
#   'ethics',
#   'moral_principle',
#   'morality',
#   'moral_philosophy',
#   'ethical_code',
#   'ethical_motive',
#   'value-system'],
#  'throwntogether': [],
#  'dozing': ['snooze', 'doze', 'drowse'],
#  'terrific': ['fantastic',
#   'rattling',
#   'tremendous',
#   'wonderful',
#   'grand',
#   'howling',
#   'marvellous',
#   'terrific',
#   'terrifying',
#   'marvelous',
#   'wondrous'],
#  'little': ['short',
#   'footling',
#   'fiddling',
#   'piffling',
#   'lilliputian',
#   'little',
#   'piddling',
#   'small',
#   'petty',
#   'trivial',
#   'minuscule',
#   'slight',
#   'picayune',
#   'niggling'],
#  'impact': ['affect',
#   'bear_upon',
#   'shock',
#   'wallop',
#   'touch_on',
#   'impingement',
#   'touch',
#   'encroachment',
#   'impact',
#   'bear_on'],
#  'in': ['Hoosier_State',
#   'indium',
#   'In',
#   'Indiana',
#   'inward',
#   'inch',
#   'IN',
#   'inwards',
#   'atomic_number_49',
#   'in'],
#  'castrated': ['bowdlerise',
#   'castrated',
#   'castrate',
#   'emasculate',
#   'spay',
#   'alter',
#   'bowdlerize',
#   'shorten',
#   'neuter',
#   'expurgate',
#   'unsexed',
#   'demasculinize',
#   'demasculinise'],
#  'effective': ['in_force',
#   'effective',
#   'efficacious',
#   'efficient',
#   'in_effect',
#   'effectual',
#   'good'],
#  'sanctimony': ['sanctimoniousness', 'sanctimony'],
#  'fraction': ['divide', 'fraction'],
#  'uses': ['economic_consumption',
#   'usance',
#   'role',
#   'U.S.A.',
#   'purpose',
#   'expend',
#   'utilisation',
#   'habituate',
#   'USA',
#   'manipulation',
#   'utilise',
#   'use',
#   'United_States_of_America',
#   'use_of_goods_and_services',
#   'exercise',
#   'function',
#   'employ',
#   'United_States',
#   'US',
#   'America',
#   'consumption',
#   'employment',
#   'usage',
#   'habit',
#   'apply',
#   'utilize',
#   'enjoyment',
#   'U.S.',
#   'utilization',
#   'the_States',
#   'practice'],
#  'social': ['mixer', 'sociable', 'societal', 'social'],
#  'nothing': ['nil',
#   'goose_egg',
#   'naught',
#   'nada',
#   'zero',
#   'cypher',
#   'zippo',
#   'nix',
#   'aught',
#   'nothing',
#   'zip',
#   'cipher',
#   'null',
#   'zilch'],
#  'health': ['wellness', 'health'],
#  'circle': ['set',
#   'R-2',
#   'circuit',
#   'Mexican_valium',
#   'circulate',
#   'lap',
#   'lot',
#   'roofy',
#   'rophy',
#   'band',
#   'roach',
#   'forget_me_drug',
#   'rope',
#   'circle',
#   'dress_circle',
#   'roundabout',
#   'traffic_circle',
#   'rotary',
#   'encircle',
#   'round'],
#  'appreciate': ['treasure',
#   'apprise',
#   'revalue',
#   'value',
#   'take_account',
#   'prize',
#   'appreciate',
#   'apprize'],
#  'love': ['have_it_off',
#   'honey',
#   'get_laid',
#   'making_love',
#   'dear',
#   'sleep_together',
#   'bed',
#   'love_life',
#   'passion',
#   'get_it_on',
#   'fuck',
#   'bang',
#   'hump',
#   'enjoy',
#   'roll_in_the_hay',
#   'be_intimate',
#   'have_intercourse',
#   'dearest',
#   'lie_with',
#   'jazz',
#   'lovemaking',
#   'make_love',
#   'do_it',
#   'erotic_love',
#   'have_a_go_at_it',
#   'know',
#   'screw',
#   'love',
#   'beloved',
#   'sleep_with',
#   'bonk',
#   'sexual_love',
#   'eff',
#   'make_out',
#   'have_sex',
#   'have_it_away'],
#  'interest': ['pursuit',
#   'sake',
#   'pastime',
#   'worry',
#   'concern',
#   'involvement',
#   'interest_group',
#   'stake',
#   'interestingness',
#   'occupy',
#   'matter_to',
#   'interest'],
#  'sharp': ['crisp',
#   'penetrating',
#   'astute',
#   'incisive',
#   'discriminating',
#   'piercing',
#   'acutely',
#   'shrill',
#   'tart',
#   'keen',
#   'penetrative',
#   'abrupt',
#   'acuate',
#   'shrewd',
#   'sharp',
#   'needlelike',
#   'sharply',
#   'knifelike',
#   'precipitous',
#   'acute',
#   'sharp-worded'],
#  'somewhat': ['passably',
#   'more_or_less',
#   'somewhat',
#   'moderately',
#   'fairly',
#   'reasonably',
#   'slightly',
#   'pretty',
#   'middling',
#   'jolly'],
#  'political': ['political'],
#  'eager': ['tidal_bore', 'eagre', 'eager', 'bore', 'aegir'],
#  'ease': ['simpleness',
#   'still',
#   'alleviate',
#   'facilitate',
#   'allay',
#   'relieve',
#   'relaxation',
#   'rest',
#   'ease',
#   'repose',
#   'informality',
#   'simplicity',
#   'relief',
#   'easiness',
#   'comfort'],
#  'calls': ['phone',
#   'call',
#   'shout_out',
#   'scream',
#   'squall',
#   'outcry',
#   'yell',
#   'phone_call',
#   'claim',
#   'visit',
#   'bid',
#   'cry',
#   'telephone',
#   'vociferation',
#   'call_option',
#   'birdcall',
#   'call_off',
#   'send_for',
#   'prognosticate',
#   'foretell',
#   'birdsong',
#   'holler',
#   'call_in',
#   'call_up',
#   'address',
#   'shout',
#   'telephone_call',
#   'song',
#   'Call',
#   'margin_call',
#   'anticipate',
#   'hollo',
#   'name',
#   'forebode',
#   'ring',
#   'promise',
#   'predict'],
#  'efforts': ['crusade',
#   'drive',
#   'attempt',
#   'travail',
#   'try',
#   'endeavour',
#   'endeavor',
#   'campaign',
#   'exploit',
#   'effort',
#   'cause',
#   'movement',
#   'elbow_grease',
#   'feat',
#   'sweat',
#   'exertion'],
#  'loads': ['cargo',
#   'wads',
#   'payload',
#   'warhead',
#   'incumbrance',
#   'lots',
#   'onus',
#   'oodles',
#   'charge',
#   'stretch',
#   'stacks',
#   'burden',
#   'encumbrance',
#   'load_up',
#   'gobs',
#   'shipment',
#   'dilute',
#   'scores',
#   'rafts',
#   'lading',
#   'lade',
#   'adulterate',
#   'consignment',
#   'lashings',
#   'laden',
#   'scads',
#   'debase',
#   'tons',
#   'slews',
#   'load',
#   'piles',
#   'lode',
#   'dozens',
#   'loading',
#   'heaps',
#   'loads',
#   'freight'],
#  'homage': ['homage', 'court'],
#  'næss': [],
#  'territory': ['territorial_dominion',
#   'territory',
#   'soil',
#   'dominion',
#   'district'],
#  'expert': ['expert',
#   'technical',
#   'adept',
#   'proficient',
#   'skilful',
#   'practiced',
#   'skillful',
#   'good'],
#  'trifle': ['trifle',
#   'frivol',
#   'triviality',
#   'technicality',
#   'trivia',
#   'dally',
#   'wanton',
#   'small_beer',
#   'wanton_away',
#   'play',
#   'piddle',
#   'piddle_away'],
#  'embarrassed': ['stymie',
#   'humiliated',
#   'chagrined',
#   'embarrassed',
#   'block',
#   'obstruct',
#   'blockade',
#   'hinder',
#   'mortified',
#   'abashed',
#   'abash',
#   'stymy',
#   'embarrass'],
#  'technology': ['engineering',
#   'technology',
#   'applied_science',
#   'engineering_science'],
#  'glass': ['shabu',
#   'meth',
#   'glass',
#   'glaze',
#   'trash',
#   'looking_glass',
#   'glass_over',
#   'glass_in',
#   'Methedrine',
#   'glaze_over',
#   'spyglass',
#   'glassful',
#   'methamphetamine',
#   'field_glass',
#   'deoxyephedrine',
#   'crank',
#   'chalk',
#   'ice',
#   'chicken_feed',
#   'drinking_glass',
#   'methamphetamine_hydrochloride'],
#  'needs': ['needs',
#   'necessarily',
#   'ask',
#   'want',
#   'postulate',
#   'necessitate',
#   'penury',
#   'pauperism',
#   'demand',
#   'need',
#   'motivation',
#   'inevitably',
#   'require',
#   'involve',
#   'indigence',
#   'call_for',
#   'motive',
#   'pauperization',
#   'take',
#   'of_necessity'],
#  'sprung': ['leap',
#   'jump',
#   'recoil',
#   'reverberate',
#   'ricochet',
#   'spring',
#   'take_form',
#   'bounce',
#   'resile',
#   'rebound',
#   'form',
#   'bound',
#   'take_a_hop',
#   'take_shape'],
#  'silbersteins': [],
#  'knowing': ['have_it_off',
#   'get_laid',
#   'wise_to',
#   'knowing',
#   'sleep_together',
#   'bed',
#   'cognise',
#   'recognise',
#   'well-read',
#   'get_it_on',
#   'fuck',
#   'bang',
#   'cognize',
#   'hump',
#   'roll_in_the_hay',
#   'be_intimate',
#   'have_intercourse',
#   'lie_with',
#   'jazz',
#   'live',
#   'make_love',
#   'do_it',
#   'experience',
#   'knowledgeable',
#   'have_a_go_at_it',
#   'know',
#   'screw',
#   'love',
#   'wise',
#   'sleep_with',
#   'bonk',
#   'lettered',
#   'well-educated',
#   'eff',
#   'make_out',
#   'intentional',
#   'have_sex',
#   'recognize',
#   'acknowledge',
#   'have_it_away',
#   'learned'],
#  'video': ['picture',
#   'telecasting',
#   'TV',
#   'television',
#   'video_recording',
#   'video'],
#  'or': ['Beaver_State',
#   'operating_theater',
#   'operating_theatre',
#   'operating_room',
#   'OR',
#   'Oregon',
#   'surgery'],
#  'goodnaturedly': [],
#  'wistful': ['pensive', 'wistful'],
#  'piercing': ['lancinate',
#   'lancinating',
#   'discriminating',
#   'piercing',
#   'knifelike',
#   'cutting',
#   'pierce',
#   'stabbing',
#   'penetrating',
#   'keen',
#   'penetrative',
#   'incisive',
#   'thrust',
#   'acute',
#   'sharp'],
#  'rewarding': ['rewarding',
#   'pay_back',
#   'repay',
#   'honour',
#   'honor',
#   'reinforce',
#   'reward'],
#  'script': ['hand', 'handwriting', 'playscript', 'script', 'book'],
#  'originality': ['originality'],
#  'notsofunny': [],
#  'raphael': ['Raphael', 'Raffaello_Santi', 'Raffaello_Sanzio'],
#  'resolutely': ['resolutely', 'decisively'],
#  'questionable': ['confutative', 'questionable', 'confutable', 'refutable'],
#  'box': ['boxful', 'package', 'box_seat', 'corner', 'boxwood', 'box', 'loge'],
#  'reason': ['conclude',
#   'reasonableness',
#   'grounds',
#   'reason_out',
#   'intellect',
#   'cause',
#   'understanding',
#   'rationality',
#   'argue',
#   'reason',
#   'ground'],
#  'diverges': ['diverge', 'depart', 'vary', 'deviate'],
#  'every': ['every'],
#  'persona': ['persona',
#   'theatrical_role',
#   'image',
#   'part',
#   'role',
#   'character'],
#  'lugosi': ['Lugosi', 'Bela_Lugosi', 'Bela_Ferenc_Blasko'],
#  'repeated': ['recur',
#   'reprise',
#   'reprize',
#   'reduplicate',
#   'retell',
#   'double',
#   'repeat',
#   'ingeminate',
#   'perennial',
#   'reiterate',
#   'recurrent',
#   'restate',
#   'repeated',
#   'echo',
#   'duplicate',
#   'replicate',
#   'iterate',
#   'take_over',
#   'recapitulate'],
#  'movement': ['crusade',
#   'drive',
#   'apparent_motion',
#   'trend',
#   'motion',
#   'social_movement',
#   'bowel_movement',
#   'motility',
#   'campaign',
#   'cause',
#   'effort',
#   'apparent_movement',
#   'front',
#   'bm',
#   'movement',
#   'drift',
#   'move'],
#  'aesthetic': ['artistic',
#   'esthetic',
#   'aesthetical',
#   'esthetical',
#   'aesthetic'],
#  'ugh': [],
#  'pretends': ['affect',
#   'guess',
#   'venture',
#   'sham',
#   'hazard',
#   'feign',
#   'make',
#   'profess',
#   'pretend',
#   'dissemble',
#   'act',
#   'make-believe',
#   'make_believe'],
#  'ca': ['atomic_number_20',
#   'calcium',
#   'California',
#   'Ca',
#   'Golden_State',
#   'CA',
#   'Calif.'],
#  'wish': ['regard',
#   'care',
#   'wish_well',
#   'want',
#   'compliments',
#   'bid',
#   'wish',
#   'like',
#   'indirect_request',
#   'wishing'],
#  'tendentious': ['tendentious', 'tendencious'],
#  'freedom': ['exemption', 'freedom'],
#  'duds': ['threads',
#   'flop',
#   'washout',
#   'togs',
#   'turkey',
#   'bomb',
#   'misfire',
#   'dud',
#   'duds'],
#  'dive': ['dive',
#   'honkytonk',
#   'nosedive',
#   'plunk',
#   'nose_dive',
#   'plunge',
#   'diva',
#   'prima_donna',
#   'diving'],
#  'boys': ['boy', 'son', 'male_child'],
#  'revelations': ['divine_revelation',
#   'Book_of_Revelation',
#   'disclosure',
#   'Apocalypse',
#   'revelation',
#   'revealing',
#   'Revelation',
#   'Revelation_of_Saint_John_the_Divine'],
#  'message': ['message', 'subject_matter', 'substance', 'content'],
#  'amusing': ['risible',
#   'amusing',
#   'divert',
#   'amusive',
#   'amuse',
#   'disport',
#   'comical',
#   'funny',
#   'mirthful',
#   'diverting',
#   'laughable',
#   'comic'],
#  'star': ['maven',
#   'star',
#   'ace',
#   'leading',
#   'genius',
#   'hotshot',
#   'asterisk',
#   'virtuoso',
#   'superstar',
#   'lead',
#   'whizz',
#   'stellar',
#   'adept',
#   'mavin',
#   'principal',
#   'starring',
#   'wizard',
#   'whiz',
#   'headliner',
#   'prima',
#   'sensation',
#   'star_topology',
#   'champion',
#   'wiz'],
#  'forced': ['drive',
#   'draw',
#   'constrained',
#   'pull',
#   'wedge',
#   'ram',
#   'storm',
#   'strained',
#   'hale',
#   'forced',
#   'coerce',
#   'pressure',
#   'force',
#   'squeeze',
#   'thrust',
#   'impel',
#   'push'],
#  'messenger': ['messenger', 'courier'],
#  'selfawareness': [],
#  'crisp': ['wrinkle',
#   'crisp',
#   'crispy',
#   'ruckle',
#   'Saratoga_chip',
#   'crease',
#   'nippy',
#   'frizzly',
#   'curt',
#   'nipping',
#   'laconic',
#   'snappy',
#   'kinky',
#   'frosty',
#   'scrunch',
#   'sharp',
#   'crinkle',
#   'frizzy',
#   'crispen',
#   'nappy',
#   'chip',
#   'scrunch_up',
#   'toast',
#   'terse',
#   'potato_chip'],
#  'believability': ['credibility', 'believability', 'credibleness'],
#  'binoche': [],
#  'mugging': ['mug', 'mugging'],
#  'mean': ['stand_for',
#   'mean_value',
#   'have_in_mind',
#   'intend',
#   'mean',
#   'mingy',
#   'entail',
#   'bastardly',
#   'signify',
#   'think_of',
#   'meanspirited',
#   'base',
#   'average',
#   'tight',
#   'imply',
#   'think',
#   'hateful',
#   'beggarly',
#   'miserly'],
#  'myth': ['myth'],
#  'sheer': ['veer',
#   'cobwebby',
#   'swerve',
#   'unmixed',
#   'trend',
#   'sheer',
#   'downright',
#   'absolute',
#   'plain',
#   'gauze-like',
#   'gossamer',
#   'right-down',
#   'see-through',
#   'diaphanous',
#   'filmy',
#   'unmingled',
#   'out-and-out',
#   'perpendicularly',
#   'gauzy',
#   'cut',
#   'slue',
#   'rank',
#   'transparent',
#   'vaporous',
#   'vapourous',
#   'bluff',
#   'slew',
#   'curve',
#   'bold'],
#  'boy': ['boy', 'son', 'male_child'],
#  'inoffensive': ['euphemistic', 'unoffending', 'inoffensive'],
#  'meditation': ['speculation', 'meditation'],
#  'siegel': [],
#  'darker': ['dismal',
#   'obscure',
#   'moody',
#   'sullen',
#   'saturnine',
#   'drab',
#   'dour',
#   'disconsolate',
#   'drear',
#   'glowering',
#   'sour',
#   'non-white',
#   'dreary',
#   'colored',
#   'glum',
#   'sinister',
#   'benighted',
#   'dark-skinned',
#   'black',
#   'dark',
#   'grim',
#   'gloomy',
#   'morose',
#   'blue',
#   'dingy',
#   'sorry',
#   'coloured'],
#  'absorbing': ['draw',
# ...
#   'ill-scented',
#   'clog'],
#  'lots': ['peck',
#   'tidy_sum',
#   'draw',
#   'wads',
#   'great_deal',
#   'heap',
#   'quite_a_little',
#   'set',
#   'lots',
#   'mickle',
#   'pot',
#   'oodles',
#   'muckle',
#   'good_deal',
#   'flock',
#   'stacks',
#   'mint',
#   'fortune',
#   'much',
#   'mountain',
#   'dispense',
#   'hatful',
#   'dole_out',
#   'bunch',
#   'gobs',
#   'administer',
#   'shell_out',
#   'a_great_deal',
#   'distribute',
#   'a_lot',
#   'destiny',
#   'scores',
#   'parcel_out',
#   'rafts',
#   'lot',
#   'mass',
#   'wad',
#   'mess',
#   'deal',
#   'Lot',
#   'deal_out',
#   'very_much',
#   'batch',
#   'passel',
#   'lashings',
#   'mete_out',
#   'plenty',
#   'scads',
#   'band',
#   'circumstances',
#   'tons',
#   'slews',
#   'portion',
#   'circle',
#   'allot',
#   'piles',
#   'sight',
#   'pile',
#   'raft',
#   'slew',
#   'stack',
#   'caboodle',
#   'luck',
#   'dozens',
#   'dish_out',
#   'fate',
#   'heaps',
#   'loads',
#   'spate',
#   'a_good_deal'],
#  'raise': ['elicit',
#   'ascent',
#   'heave',
#   'farm',
#   'conjure_up',
#   'provoke',
#   'enhance',
#   'kick_upstairs',
#   'raise',
#   'acclivity',
#   'upgrade',
#   'parent',
#   'promote',
#   'put_up',
#   'recruit',
#   'call_down',
#   'put_forward',
#   'get_up',
#   'kindle',
#   'advance',
#   'wage_hike',
#   'leaven',
#   'climb',
#   'salary_increase',
#   'fire',
#   'call_forth',
#   'set_up',
#   'rear',
#   'enkindle',
#   'stir',
#   'upraise',
#   'invoke',
#   'rise',
#   'hike',
#   'erect',
#   'prove',
#   'conjure',
#   'resurrect',
#   'wage_increase',
#   'heighten',
#   'produce',
#   'lift',
#   'nurture',
#   'evoke',
#   'grow',
#   'arouse',
#   'bring_up',
#   'levy',
#   'elevate'],
#  'already': ['already'],
#  'almost': ['about',
#   'almost',
#   'near',
#   'most',
#   'nigh',
#   'well-nigh',
#   'virtually',
#   'nearly'],
#  'oldfashioned': [],
#  'yes': ['yes'],
#  'confusing': ['obscure',
#   'flurry',
#   'obnubilate',
#   'confusing',
#   'confuse',
#   'perplexing',
#   'befuddle',
#   'bedevil',
#   'disconcert',
#   'jumble',
#   'mix_up',
#   'confound',
#   'put_off',
#   'discombobulate',
#   'puzzling',
#   'fox',
#   'blur',
#   'throw',
#   'fuddle'],
#  'death': ['decease',
#   'end',
#   'demise',
#   'death',
#   'dying',
#   'Death',
#   'last',
#   'expiry',
#   'destruction'],
#  'american': ['American', 'American_language', 'American_English'],
#  'top': ['crest',
#   'height',
#   'spinning_top',
#   'teetotum',
#   'tip',
#   'top_of_the_inning',
#   'lead',
#   'whirligig',
#   'top_off',
#   'top_side',
#   'peak',
#   'transcend',
#   'upper_side',
#   'top',
#   'elevation',
#   'summit',
#   'superlative',
#   'meridian',
#   'pinnacle',
#   'exceed',
#   'tiptop',
#   'round_top',
#   'crown',
#   'upside',
#   'circus_tent',
#   'clear',
#   'big_top',
#   'acme',
#   'go_past',
#   'pass',
#   'cover',
#   'overstep',
#   'pinch',
#   'top_out'],
#  'campy': ['campy', 'camp'],
#  'outrageous': ['exorbitant',
#   'hideous',
#   'usurious',
#   'horrid',
#   'steep',
#   'unconscionable',
#   'extortionate',
#   'outrageous',
#   'horrific'],
#  'haunting': ['ghost',
#   'frequent',
#   'haunting',
#   'stalk',
#   'persistent',
#   'obsess',
#   'haunt'],
#  'utter': ['give_tongue_to',
#   'dead',
#   'everlasting',
#   'pure',
#   'complete',
#   'gross',
#   'let_out',
#   'staring',
#   'speak',
#   'stark',
#   'let_loose',
#   'unadulterated',
#   'emit',
#   'arrant',
#   'double-dyed',
#   'perfect',
#   'talk',
#   'utter',
#   'verbalise',
#   'thoroughgoing',
#   'sodding',
#   'consummate',
#   'mouth',
#   'express',
#   'verbalize'],
#  'also': ['as_well', 'likewise', 'besides', 'too', 'also'],
#  'theater': ['field',
#   'theater_of_operations',
#   'dramaturgy',
#   'theatre_of_operations',
#   'field_of_operations',
#   'dramatics',
#   'theatre',
#   'house',
#   'dramatic_art',
#   'theater'],
#  'usually': ['commonly', 'usually', 'unremarkably', 'normally', 'ordinarily'],
#  'ravishing': ['transport',
#   'dishonour',
#   'enrapture',
#   'dishonor',
#   'violate',
#   'rape',
#   'ravishing',
#   'enthral',
#   'outrage',
#   'delight',
#   'ravish',
#   'assault',
#   'enthrall',
#   'enchant'],
#  'edifying': ['edify', 'enlightening', 'enlighten', 'edifying'],
#  'marivaux': [],
#  'independent': ['freelance',
#   'main',
#   'mugwump',
#   'fencesitter',
#   'self-employed_person',
#   'free-lance',
#   'independent',
#   'sovereign',
#   'self-governing',
#   'free_lance',
#   'autonomous',
#   'freelancer'],
#  'party': ['political_party', 'company', 'party'],
#  'audacious': ['dauntless',
#   'daring',
#   'venturous',
#   'unfearing',
#   'intrepid',
#   'hardy',
#   'barefaced',
#   'brassy',
#   'audacious',
#   'insolent',
#   'brave',
#   'brazen-faced',
#   'bald-faced',
#   'venturesome',
#   'fearless',
#   'bodacious',
#   'brazen'],
#  'unfortunately': ['unluckily', 'unfortunately', 'regrettably', 'alas'],
#  'parable': ['fable', 'apologue', 'parable', 'allegory'],
#  'reunion': ['reunification', 'reunion'],
#  'largely': ['largely', 'for_the_most_part', 'mostly'],
#  'abuse': ['misuse',
#   'pervert',
#   'ill-treatment',
#   'abuse',
#   'maltreat',
#   'ill-use',
#   'step',
#   'clapperclaw',
#   'ill-usage',
#   'maltreatment',
#   'insult',
#   'revilement',
#   'shout',
#   'blackguard',
#   'vilification',
#   'mistreat',
#   'contumely',
#   'ill-treat'],
#  'relatively': ['relatively', 'comparatively'],
#  'whatif': [],
#  'because': [],
#  'responsible': ['creditworthy', 'responsible_for', 'responsible'],
#  'tooconscientious': [],
#  'last': ['conclusion',
#   'live_on',
#   'utmost',
#   'lastly',
#   'close',
#   'final_stage',
#   'stopping_point',
#   'end',
#   'go',
#   'death',
#   'hold_up',
#   'terminal',
#   'finally',
#   'endure',
#   'finale',
#   'final',
#   'last-place',
#   "cobbler's_last",
#   'in_conclusion',
#   'live',
#   'concluding',
#   'lowest',
#   'finis',
#   "shoemaker's_last",
#   'hold_out',
#   'net',
#   'survive',
#   'last',
#   'finish'],
#  'borscht': ['borsht', 'borsh', 'borshch', 'borsch', 'bortsch', 'borscht'],
#  'demented': ['unhinged',
#   'sick',
#   'brainsick',
#   'unbalanced',
#   'mad',
#   'disturbed',
#   'crazy',
#   'demented'],
#  'manage': ['manage',
#   'care',
#   'make_do',
#   'cope',
#   'get_by',
#   'wield',
#   'grapple',
#   'superintend',
#   'handle',
#   'bring_off',
#   'supervise',
#   'wangle',
#   'negociate',
#   'deal',
#   'oversee',
#   'pull_off',
#   'finagle',
#   'do',
#   'carry_off',
#   'make_out',
#   'contend'],
#  'wonderful': ['fantastic',
#   'rattling',
#   'tremendous',
#   'wonderful',
#   'grand',
#   'howling',
#   'marvellous',
#   'terrific',
#   'marvelous',
#   'wondrous'],
#  'fans': ['winnow', 'buff', 'lover', 'rooter', 'devotee', 'sports_fan', 'fan'],
#  'onto': [],
#  'writerproducerdirector': [],
#  'confident': ['sure-footed',
#   'surefooted',
#   'positive',
#   'confident',
#   'convinced'],
#  'door': ['door', 'room_access', 'doorway', 'threshold'],
#  'serve': ['dish',
#   'dish_up',
#   'function',
#   'help',
#   'wait_on',
#   'assist',
#   'swear_out',
#   'answer',
#   'serve_up',
#   'dish_out',
#   'process',
#   'suffice',
#   'service',
#   'attend_to',
#   'serve',
#   'serve_well',
#   'attend',
#   'do'],
#  'saved': ['save_up',
#   'economize',
#   'make_unnecessary',
#   'deliver',
#   'pull_through',
#   'protected',
#   'lay_aside',
#   'redeem',
#   'hold_open',
#   'economise',
#   'saved',
#   'keep',
#   'relieve',
#   'salvage',
#   'spare',
#   'bring_through',
#   'carry_through',
#   'preserve',
#   'keep_open',
#   'write',
#   'salve',
#   'save'],
#  'prophet': ['prophet', 'vaticinator', 'prophesier', 'oracle', 'seer'],
#  'dreams': ['dreaming',
#   'daydream',
#   'stargaze',
#   'pipe_dream',
#   'ambition',
#   'aspiration',
#   'dream',
#   'woolgather'],
#  'filmgoing': [],
#  'vital': ['life-sustaining', 'critical', 'vital', 'full_of_life', 'lively'],
#  'carey': [],
#  'use': ['economic_consumption',
#   'usance',
#   'role',
#   'purpose',
#   'expend',
#   'utilisation',
#   'habituate',
#   'manipulation',
#   'utilise',
#   'use',
#   'use_of_goods_and_services',
#   'exercise',
#   'function',
#   'employ',
#   'consumption',
#   'employment',
#   'usage',
#   'habit',
#   'apply',
#   'utilize',
#   'enjoyment',
#   'utilization',
#   'practice'],
#  'these': [],
#  'heritage': ['inheritance', 'heritage'],
#  'act': ['human_activity',
#   'work',
#   'dissemble',
#   'playact',
#   'enactment',
#   'number',
#   'act_as',
#   'act',
#   'play',
#   'pretend',
#   'turn',
#   'routine',
#   'roleplay',
#   'do',
#   'human_action',
#   'deed',
#   'behave',
#   'bit',
#   'represent',
#   'move'],
#  'civil': ['civil', 'polite', 'civic'],
#  'informative': ['enlightening',
#   'illuminating',
#   'instructive',
#   'informative',
#   'informatory'],
#  'mixture': ['admixture',
#   'mixed_bag',
#   'mix',
#   'intermixture',
#   'salmagundi',
#   'commixture',
#   'concoction',
#   'mixture',
#   'mixing',
#   'smorgasbord',
#   'assortment',
#   'miscellany',
#   'miscellanea',
#   'potpourri',
#   'variety',
#   'motley'],
#  'graceless': ['ungraceful',
#   'unpolished',
#   'unpleasing',
#   'graceless',
#   'gauche'],
#  'familiar': ['familiar_spirit',
#   'conversant',
#   'intimate',
#   'associate',
#   'fellow',
#   'companion',
#   'comrade',
#   'familiar'],
#  'particular': ['particular_proposition',
#   'fussy',
#   'peculiar',
#   'special',
#   'especial',
#   'exceptional',
#   'picky',
#   'finical',
#   'detail',
#   'finicky',
#   'specific',
#   'item',
#   'particular'],
#  'pilot': ['original',
#   'navigate',
#   'fender',
#   'pilot_film',
#   'pilot_burner',
#   'cowcatcher',
#   'fly',
#   'pilot',
#   'aviate',
#   'airplane_pilot',
#   'archetype',
#   'pilot_light',
#   'buffer',
#   'pilot_program'],
#  'doingitfor': [],
#  'anarchist': ['anarchist', 'syndicalist', 'nihilist'],
#  'disintegrating': ['decay', 'disintegrate', 'decompose'],
#  'boasts': ['shoot_a_line',
#   'tout',
#   'bluster',
#   'gas',
#   'blow',
#   'sport',
#   'gasconade',
#   'jactitation',
#   'boasting',
#   'self-praise',
#   'swash',
#   'brag',
#   'feature',
#   'vaunt',
#   'boast'],
#  'goofy': ['cockamamy',
#   'cockamamie',
#   'whacky',
#   'silly',
#   'sappy',
#   'goofy',
#   'Goofy',
#   'zany',
#   'wacky'],
#  'judd': [],
#  'world': ['macrocosm',
#   'domain',
#   'creation',
#   'humankind',
#   'humans',
#   'global',
#   'worldly_concern',
#   'globe',
#   'world-wide',
#   'worldwide',
#   'planetary',
#   'earthly_concern',
#   'cosmos',
#   'man',
#   'existence',
#   'universe',
#   'earth',
#   'populace',
#   'Earth',
#   'human_beings',
#   'human_race',
#   'reality',
#   'mankind',
#   'public',
#   'world',
#   'humanity'],
#  'women': ['cleaning_lady',
#   'womanhood',
#   'cleaning_woman',
#   'woman',
#   'fair_sex',
#   'char',
#   'adult_female',
#   'charwoman'],
#  'recommendation': ['good_word', 'testimonial', 'passport', 'recommendation'],
#  'avoids': ['forefend',
#   'deflect',
#   'obviate',
#   'keep_off',
#   'quash',
#   'fend_off',
#   'ward_off',
#   'void',
#   'annul',
#   'forfend',
#   'stave_off',
#   'head_off',
#   'nullify',
#   'avoid',
#   'debar',
#   'invalidate',
#   'avert'],
#  'sci': [],
#  'edge': ['sharpness',
#   'butt',
#   'edge',
#   'march',
#   'butt_on',
#   'inch',
#   'butt_against',
#   'boundary',
#   'bound',
#   'adjoin',
#   'abut',
#   'border'],
#  'potent': ['potent', 'powerful', 'stiff', 'strong', 'virile'],
#  'importance': ['importance', 'grandness'],
#  'partnership': ['partnership'],
#  'somehow': ['in_some_way',
#   'in_some_manner',
#   'somehow',
#   'someways',
#   'someway'],
#  'fingers': ["finger's_breadth",
#   'thumb',
#   'digit',
#   'feel',
#   'fingerbreadth',
#   'finger'],
#  'amounts': ['amount',
#   'add_up',
#   'come',
#   'measure',
#   'quantity',
#   'total',
#   'sum_of_money',
#   'amount_of_money',
#   'number',
#   'sum'],
#  'margarita': ['margarita'],
#  'our': [],
#  'shine': ['glow',
#   'shine',
#   'radiate',
#   'fall',
#   'glitter',
#   'strike',
#   'smoothen',
#   'radiancy',
#   'refulgency',
#   'glisten',
#   'beam',
#   'gleam',
#   'reflect',
#   'effulgence',
#   'glint',
#   'smooth',
#   'refulgence',
#   'polish',
#   'radiance'],
#  'pot': ['peck',
#   'tidy_sum',
#   'corporation',
#   'great_deal',
#   'potbelly',
#   'Mary_Jane',
#   'sess',
#   'heap',
#   'quite_a_little',
#   'mickle',
#   'pot',
#   'jackpot',
#   'muckle',
#   'good_deal',
#   'flock',
#   'smoke',
#   'stool',
#   'mint',
#   'dope',
#   'can',
#   'locoweed',
#   'mountain',
#   'kitty',
#   'hatful',
#   'flowerpot',
#   'potful',
#   'potty',
#   'green_goddess',
#   'throne',
#   'lot',
#   'mass',
#   'commode',
#   'mess',
#   'deal',
#   'wad',
#   'potentiometer',
#   'gage',
#   'skunk',
#   'batch',
#   'passel',
#   'weed',
#   'plenty',
#   'tummy',
#   'sens',
#   'crapper',
#   'toilet',
#   'bay_window',
#   'sight',
#   'pile',
#   'raft',
#   'slew',
#   'stack',
#   'grass',
#   'spate'],
#  'bore': ['deliver',
#   'accept',
#   'stomach',
#   'drill',
#   'calibre',
#   'eagre',
#   'have',
#   'turn_out',
#   'bore',
#   'hold',
#   'give_birth',
#   'aegir',
#   'put_up',
#   'suffer',
#   'yield',
#   'have_a_bun_in_the_oven',
#   'stick_out',
#   'dullard',
#   'wear',
#   'conduct',
#   'digest',
#   'gauge',
#   'support',
#   'contain',
#   'endure',
#   'bear',
#   'carry',
#   'caliber',
#   'gestate',
#   'tolerate',
#   'pay',
#   'drill_hole',
#   'assume',
#   'acquit',
#   'birth',
#   'tire',
#   'behave',
#   'tidal_bore',
#   'bore-hole',
#   'stand',
#   'comport',
#   'eager',
#   'expect',
#   'deport',
#   'take_over',
#   'brook',
#   'abide'],
#  'unseemly': ['untoward',
#   'indecorous',
#   'indecent',
#   'uncomely',
#   'unseemly',
#   'unbecoming'],
#  'did': ['manage',
#   'get_along',
#   'answer',
#   'set',
#   'fare',
#   'make',
#   'execute',
#   'serve',
#   'arrange',
#   'practise',
#   'cause',
#   'coif',
#   'act',
#   'perform',
#   'exercise',
#   'suffice',
#   'do',
#   'coiffure',
#   'behave',
#   'come',
#   'coiffe',
#   'make_out',
#   'practice',
#   'dress'],
#  'succeeds': ['follow',
#   'come_through',
#   'come_after',
#   'win',
#   'bring_home_the_bacon',
#   'succeed',
#   'deliver_the_goods'],
#  'openness': ['receptiveness', 'receptivity', 'openness', 'nakedness'],
#  'face': ['typeface',
#   'look',
#   'grimace',
#   'facial_expression',
#   'aspect',
#   'face',
#   'case',
#   'present',
#   'fount',
#   'side',
#   'brass',
#   'human_face',
#   'confront',
#   'front',
#   'font',
#   'boldness',
#   'expression',
#   'face_up',
#   'cheek',
#   'nerve'],
#  'punctuation': ['punctuation_mark', 'punctuation'],
#  'showcase': ['case', 'showcase', 'show_window', 'display_case', 'vitrine'],
#  'enthusiasm': ['ebullience', 'exuberance', 'enthusiasm'],
#  'ambiguities': ['equivocalness', 'ambiguity'],
#  'break': ['break-dance',
#   'split',
#   'snap_off',
#   'come_apart',
#   'ruin',
#   'let_out',
#   'burst',
#   'bring_out',
#   'bust',
#   'wear',
#   'infract',
#   'respite',
#   'let_on',
#   'offend',
#   'fail',
#   'rupture',
#   'split_up',
#   'violate',
#   'wear_out',
#   'fall_in',
#   'bankrupt',
#   'happy_chance',
#   'soften',
#   'better',
#   'interrupt',
#   'kick_downstairs',
#   'breakout',
#   'expose',
#   'recrudesce',
#   'break_of_serve',
#   'recess',
#   'get_out',
#   'stop',
#   'founder',
#   'get_around',
#   'suspension',
#   'transgress',
#   'break_out',
#   'crack',
#   'conk_out',
#   'rift',
#   'reveal',
#   'part',
#   'break_down',
#   'discover',
#   'time_out',
#   'interruption',
#   'faulting',
#   'give',
#   'break_dance',
#   'break_off',
#   'intermit',
#   'gap',
#   'go_against',
#   'disclose',
#   'falling_out',
#   'dampen',
#   'severance',
#   'unwrap',
#   'break_up',
#   'pause',
#   'break',
#   'divulge',
#   'disruption',
#   'breakage',
#   'good_luck',
#   'demote',
#   'intermission',
#   'go_bad',
#   'breaking',
#   'erupt',
#   'relegate',
#   'fault',
#   'gaolbreak',
#   'fall_apart',
#   'open_frame',
#   'collapse',
#   'prisonbreak',
#   'give_way',
#   'weaken',
#   'damp',
#   'smash',
#   'cave_in',
#   'give_out',
#   'breach',
#   'give_away',
#   'go',
#   'develop',
#   'shift',
#   'geological_fault',
#   'bump',
#   'prison-breaking',
#   'fracture',
#   'jailbreak',
#   'die',
#   'check',
#   'discontinue',
#   'break_in',
#   'separate',
#   'break_away'],
#  'elegance': ['elegance'],
#  'stinks': ['malodor',
#   'malodour',
#   'fetor',
#   'stink',
#   'mephitis',
#   'stench',
#   'foetor',
#   'reek'],
#  'adventurous': ['adventurous', 'adventuresome'],
#  'talk': ['talk_of_the_town',
#   'blab',
#   'let_the_cat_out_of_the_bag',
#   'sing',
#   'public_lecture',
#   'speak',
#   'spill',
#   'lecture',
#   'spill_the_beans',
#   'talk',
#   'utter',
#   'verbalise',
#   'blab_out',
#   'babble',
#   'tattle',
#   'mouth',
#   'talking',
#   'peach',
#   'verbalize',
#   'babble_out'],
#  'promised': ['anticipate',
#   'assure',
#   'call',
#   'prognosticate',
#   'foretell',
#   'forebode',
#   'promise',
#   'predict'],
#  'hand': ['hand',
#   'handwriting',
#   'reach',
#   'hired_hand',
#   'pass_on',
#   'script',
#   'manus',
#   'mitt',
#   'hired_man',
#   'pass',
#   'paw',
#   'give',
#   'helping_hand',
#   'turn_over',
#   'bridge_player',
#   'deal'],
#  'desperate': ['desperate', 'despairing', 'dire', 'heroic', 'do-or-die'],
#  'romance': ['woo',
#   'dally',
#   'romanticism',
#   'philander',
#   'chat_up',
#   'flirt',
#   'Latinian_language',
#   'Romance_language',
#   'mash',
#   'Latin',
#   'court',
#   'solicit',
#   'coquet',
#   'love_affair',
#   'romance',
#   'love_story',
#   'butterfly',
#   'coquette',
#   'Romance'],
#  ...}

# %%
with open('weights/en_similars_dict.pkl', 'wb') as f:
    pickle.dump(similar_words_dict, f)

# %%
TA = TextAugmenter(lang='en')
# Out:
# Language: English

# %% [markdown]
# # Random

# %%
contents[0]
# Out:
# 'klein  charming in comedies like american pie and deadon in election  '

# %%
sentence = contents[0]
p = 0.1
print(' '.join(TA.aug_by_deletion(text=sentence,p=p,mode='random')))
print(' '.join(TA.aug_by_replacement(text=sentence,p=p,mode='random')))
print(' '.join(TA.aug_by_insertion(text=sentence,p=p,mode='random')))
print(' '.join(TA.aug_by_swap(text=sentence,p=p,mode='random')))
# Out:
# klein charming in comedies like american pie and election
# Felix_Klein charming in comedies like american pie and deadon in election
# klein American charming in comedies like american pie and deadon in election
# election charming in comedies like american pie and deadon in klein

# %% [markdown]
# # Selective

# %%
print(' '.join(TA.aug_by_deletion(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_replacement(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_insertion(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_swap(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_selection(text=sentence, selected_words=['comedy','election'])))
# Out:
# klein charming in comedies like american pie and deadon in
# klein charming in comedies like american pie and deadon in election
# klein charming in comedies like american pie and election deadon in election
# klein charming in comedies election american pie and deadon in like
# election

# %%
# read saved keywords
name = 'sst2'
global_kws_dict_path = f'saved_keywords/global_kws_dict_{name}.pkl'
with open(global_kws_dict_path, 'rb') as f:
    global_kws_dict = pickle.load(f)

# %%
global_kws_dict
# Out:
# {'1': {'lr': ['love',
#    'wonderful',
#    'style',
#    'powerful',
#    'wise',
#    'whose',
#    'ways',
#    'touching',
#    'solid',
#    'power',
#    'lot',
#    'sweet',
#    'summer',
#    'satisfying',
#    'pleasure',
#    'nine',
#    'man',
#    'imaginative',
#    'history',
#    'him',
#    'fare',
#    'culture',
#    'considerable',
#    'cinema',
#    'good',
#    'worthy',
#    'watchable',
#    'warmth',
#    'unexpected',
#    'surprisingly',
#    'stuart',
#    'saving',
#    'proves',
#    'occasionally',
#    'occasional',
#    'modern',
#    'manages',
#    'lovely',
#    'looks',
#    'laughs',
#    'inventive',
#    'ingenious',
#    'horrifying',
#    'honest',
#    'giving',
#    'gentle',
#    'find',
#    'fantastic',
#    'especially',
#    'enjoyable',
#    'cinematic',
#    'chance',
#    'capable',
#    'brings',
#    'atmosphere',
#    'amusing',
#    'fun',
#    'yet',
#    'yesterday',
#    'yarn',
#    'wow',
#    'works',
#    'wispy',
#    'whether',
#    'weighty',
#    'vivid',
#    'vibrant',
#    'version',
#    'verbal',
#    'unique',
#    'undeniable',
#    'twentyth',
#    'true',
#    'themselves',
#    'terrifying',
#    'tender',
#    'televised',
#    'talented',
#    'sympathetic',
#    'sweetness',
#    'surprising',
#    'succeeds',
#    'study',
#    'struggling',
#    'strange',
#    'status',
#    'star',
#    'stand',
#    'splendid',
#    'spirit',
#    'spielberg',
#    'sophisticated',
#    'smartly',
#    'sly',
#    'selfglorification',
#    'seat',
#    'season',
#    'sea',
#    'scottish',
#    'scoobydoo',
#    'sally',
#    'sad',
#    'roles',
#    'ripping',
#    'rewards',
#    'results',
#    'resonant',
#    'reruns',
#    'rendered',
#    'refreshingly',
#    'read',
#    'raphael',
#    'pure',
#    'provides',
#    'profound',
#    'pop',
#    'political',
#    'pleasant',
#    'players',
#    'pitchperfect',
#    'photographed',
#    'philadelphia',
#    'perfectly',
#    'paradiso',
#    'observation',
#    'mythic',
#    'moving',
#    'moved',
#    'morality',
#    'minor',
#    'mind',
#    'memorable',
#    'meditation',
#    'masterpiece',
#    'masterfully',
#    'masterful',
#    'manner',
#    'magic',
#    'lives',
#    'lively',
#    'layers',
#    'largerthanlife',
#    'lane',
#    'laidback',
#    'kwan',
#    'knowing',
#    'keeping',
#    'jolt',
#    'jesse',
#    'jaunt',
#    'involved',
#    'intimate',
#    'interest',
#    'inspired',
#    'influenced',
#    'imagination',
#    'images',
#    'human',
#    'honestly',
#    'hilarious',
#    'heartfelt',
#    'heart',
#    'gutwrenching',
#    'grew',
#    'gracefully',
#    'goodly',
#    'glides',
#    'gestalt',
#    'genres',
#    'gasp',
#    'gas',
#    'fulfilling',
#    'fresh',
#    'frequently',
#    'france',
#    'follow',
#    'fisher',
#    'fiascos',
#    'female',
#    'feelgood',
#    'feat',
#    'fascination',
#    'eye',
#    'exhilarating',
#    'era',
#    'entertainment',
#    'entertaining',
#    'engaged',
#    'emperor',
#    'elegance',
#    'eightynine',
#    'economical',
#    'earnest',
#    'each',
#    'directly',
#    'deserves',
#    'deportment',
#    'depiction',
#    'delicately',
#    'deeply',
#    'dazzling',
#    'creative',
#    'creates',
#    'crack',
#    'conceptual',
#    'compelling',
#    'committed',
#    'comedies',
#    'club',
#    'class',
#    'clarity',
#    'chord',
#    'check',
#    'charm',
#    'certainly',
#    'bracing',
#    'bombastic',
#    'beloved',
#    'believable',
#    'beings',
#    'beat',
#    'awarded',
#    'astonishing',
#    'artistic',
#    'anyone',
#    'antwone',
#    'adventure',
#    'accomplished',
#    'absorbing',
#    'absolutely',
#    'one',
#    'most',
#    'and',
#    'funny',
#    'well',
#    'humor',
#    'while',
#    'family',
#    'drama',
#    'zwick',
#    'younger',
#    'yearnings',
#    'yearning',
#    'wrought',
#    'writerdirectors',
#    'wound',
#    'worthwhile',
#    'worldlywise',
#    'woodman',
#    'wonderfully',
#    'won',
#    'woman',
#    'wo',
#    'wizened',
#    'witty',
#    'wistfully',
#    'wistful',
#    'wish',
#    'wisegirls',
#    'winking',
#    'window',
#    'windinthehair',
#    'wind',
#    'win',
#    'willing',
#    'wildly',
#    'why',
#    'white',
#    'whimsy',
#    'whatif',
#    'welsh',
#    'wellintentioned',
#    'welldeveloped',
#    'wellbehaved',
#    'wellbalanced',
#    'weirdly',
#    'weird',
#    'weepy',
#    'watts',
#    'wasp',
#    'washington',
#    'warrior',
#    'wanting',
#    'vulnerability',
#    'voices',
#    'vividly',
#    'vital',
#    'visually',
#    'vistas',
#    'visceral',
#    'vintage',
#    'view',
#    'verve',
#    'versus',
#    'versatile',
#    'verdict',
#    'venice',
#    'veggies',
#    'vanity',
#    'usual',
#    'urge',
#    'urban',
#    'ups',
#    'upping',
#    'uplifting',
#    'unseemly',
#    'unruly',
#    'universal',
#    'uniquely',
#    'unhinged',
#    'unhibited',
#    'unexpectedly',
#    'understands',
#    'understand',
#    'underbelly',
#    'under',
#    'unadulterated',
#    'unabashedly',
#    'type',
#    'twin',
#    'twelveyearold',
#    'truths',
#    'truffaut',
#    'truecrime',
#    'triumphs',
#    'trilogy',
#    'tremendous',
#    'treat',
#    'traveler',
#    'trap',
#    'transition',
#    'transcends',
#    'transcendence',
#    'tranquil',
#    'traditional',
#    'tradition',
#    'towering',
#    'topnotch',
#    'top',
#    'titular',
#    'tiny',
#    'timeconsuming',
#    'ticking',
#    'thumbs',
#    'throughout',
#    'threed',
#    'thoughtful',
#    'thirtythree',
#    'thanks',
#    'thankfully',
#    'technology',
#    'technical',
#    'tattoos',
#    'tasty',
#    'taste',
#    'talk',
#    'talents',
#    't',
#    'swung',
#    'swooning',
#    'swim',
#    'sweatypalmed',
#    'swallow',
#    'suspenseful',
#    'suspended',
#    'surprises',
#    'surefire',
#    'supremely',
#    'sundrenched',
#    'suits',
#    'suggest',
#    'sugar',
#    'succeeded',
#    'succeed',
#    'suburban',
#    'subtly',
#    'subtlety',
#    'subtle',
#    'subsequent',
#    'subculture',
#    'stylists',
#    'stylishly',
#    'stylish',
#    'stunning',
#    'struggles',
#    'strike',
#    'strength',
#    'strangely',
#    'straight',
#    'storyline',
#    'stoked',
#    'stitch',
#    'stirs',
#    'stirring',
#    'stimulating',
#    'stillinestimable',
#    'stickiness',
#    'stevens',
#    'steven',
#    'stepmom',
#    'step',
#    'stays',
#    'startling',
#    'starting',
#    'start',
#    'stars',
#    'stanzas',
#    'stanley',
#    'standard',
#    'stage',
#    'square',
#    'spy',
#    'sprung',
#    'spoton',
#    'sportsmen',
#    'spooky',
#    'spirits',
#    'spikes',
#    'spike',
#    'spiffy',
#    'spiderman',
#    'spell',
#    'specimen',
#    'speaks',
#    'spaces',
#    'sounding',
#    'souls',
#    'soulful',
#    'sorrow',
#    'sonny',
#    'songs',
#    'somehow',
#    'solutions',
#    'solidly',
#    'soderbergh',
#    'sobering',
#    'sneering',
#    'smiles',
#    'slightly',
#    'sleeper',
#    'skins',
#    'skilled',
#    'siren',
#    'sincerity',
#    'sincerely',
#    'sincere',
#    'since',
#    'simplistic',
#    'significance',
#    'siegel',
#    'side',
#    'sibling',
#    'showdown',
#    'showcases',
#    'shockingly',
#    'shiner',
#    'shine',
#    'sharply',
#    'sharp',
#    'shared',
#    'share',
#    'shafer',
#    'seventys',
#    'sets',
#    'setpieces',
#    'servants',
#    'sequences',
#    'sentiments',
#    'sentimentality',
#    'sensitivity',
#    'sensitive',
#    'sensational',
#    'selfexpression',
#    'secretly',
#    'seamy',
#    'scripting',
#    'scotland',
#    'scoring',
#    'scope',
#    'sci',
#    'schtick',
#    'scenario',
#    'scariest',
#    'saw',
#    'saucy',
#    'satisfies',
#    'sardonic',
#    'sarandon',
#    'sand',
#    'sanctimoniousness',
#    'salton',
#    'saga',
#    'sade',
#    'sabotage',
#    'ryan',
#    'russian',
#    'routines',
#    'romoli',
#    'roman',
#    'rohmer',
#    'rocky',
#    'rocks',
#    'roars',
#    'rivals',
#    'rising',
#    'rises',
#    'riproaring',
#    'ripening',
#    'ride',
#    'rewarding',
#    'revolutionary',
#    'revenge',
#    'revelations',
#    'reveals',
#    'revealing',
#    'reunion',
#    'retooled',
#    'retains',
#    'result',
#    'respectable',
#    'resourceful',
#    'resistance',
#    'represents',
#    'reminiscent',
#    'remarkable',
#    'remaining',
#    'relegated',
#    'relatively',
#    'reinvention',
#    'reggio',
#    'refreshed',
#    'reflected',
#    'reconciliation',
#    'recommendation',
#    'rebel',
#    'reassuring',
#    'reasonable',
#    'reap',
#    'realistic',
#    'readymade',
#    'ravishing',
#    'ravaging',
#    'rarity',
#    'rapidfire',
#    'rap',
#    'ranks',
#    'range',
#    'ramifications',
#    'rae',
#    'race',
#    'quiet',
#    'questions',
#    'qatsi',
#    'pursuing',
#    'purists',
#    'purely',
#    'punctuation',
#    'punch',
#    'puff',
#    'prowildlife',
#    'prove',
#    'proud',
#    'proposal',
#    'prophet',
#    'project',
#    'producer',
#    'process',
#    'problem',
#    'private',
#    'pristine',
#    'principles',
#    'princess',
#    'prime',
#    'pretension',
#    'press',
#    'president',
#    'presentation',
#    'presence',
#    'prefer',
#    'precisely',
#    'potential',
#    'potent',
#    'positive',
#    'portrait',
#    'popcorn',
#    'politically',
#    'police',
#    'polanski',
#    'poetry',
#    'playwriting',
#    'playlist',
#    'playfully',
#    'pipeline',
#    'pill',
#    'piercing',
#    'pie',
#    'picked',
#    'pianist',
#    'philosophical',
#    'philippe',
#    'philip',
#    'phantom',
#    'petter',
#    'pertinent',
#    'persuasive',
#    'perspective',
#    'performed',
#    'perfect',
#    'penetrating',
#    'peels',
#    'peek',
#    'peaks',
#    'path',
#    'partnership',
#    'partisans',
#    'parody',
#    'parents',
#    'parable',
#    'par',
#    'paper',
#    'paintings',
#    'outrageousness',
#    'outing',
#    'others',
#    'originality',
#    'orbit',
#    'optimism',
#    'opportunities',
#    'openness',
#    'opening',
#    'oozing',
#    'oncamera',
#    'oliver',
#    'offbeat',
#    'odd',
#    'occupational',
#    'næss',
#    'nutty',
#    'nurtured',
#    'numerous',
#    'number',
#    'nuance',
#    'novel',
#    'novak',
#    'note',
#    'notable',
#    'nostalgia',
#    'nononsense',
#    'nonjudgmental',
#    'nonexploitive',
#    'nomination',
#    'noir',
#    'noble',
#    'ninth',
#    'ninetythree',
#    'nijinsky',
#    'nickelodeonesque',
#    'nicely',
#    'newfangled',
#    'newcomers',
#    'net',
#    'needs',
#    'necessarily',
#    'neat',
#    'nearimpossible',
#    'navigate',
#    'naughty',
#    'natured',
#    'naturally',
#    'natural',
#    'native',
#    'nail',
#    'na',
#    'myth',
#    'must',
#    'mtv',
#    'movements',
#    'movement',
#    'move',
#    'motion',
#    'morvern',
#    'morrison',
#    'mood',
#    'modest',
#    'moderately',
#    'models',
#    'mob',
#    'mixture',
#    'mix',
#    'missive',
#    'miracle',
#    'mindbending',
#    'midwest',
#    'mib',
#    'metaphors',
#    'mesmerizing',
#    'mesmerised',
#    'merrily',
#    'menace',
#    'memorial',
#    'melodramatic',
#    'melodrama',
#    'mel',
#    'meddles',
#    'meaningful',
#    'maxim',
#    'maturity',
#    'mature',
#    'matters',
#    'mattered',
#    'matron',
#    'match',
#    'mariah',
#    'manage',
#    'mamet',
#    'magical',
#    'machine',
#    'lovingly',
#    'loves',
#    'loved',
#    'lothario',
#    'local',
#    'loaded',
#    'living',
#    'livestyle',
#    'littleknown',
#    'literate',
#    'lips',
#    'lingers',
#    'lingerie',
#    'lines',
#    'lilo',
#    'liked',
#    'lighthearted',
#    'light',
#    'lifechanging',
#    'lie',
#    'liberating',
#    'liar',
#    'levity',
#    'let',
#    'leonine',
#    'lend',
#    'legend',
#    'leave',
#    'learn',
#    'layered',
#    'laughoutloud',
#    'laughed',
#    'laughable',
#    'laugh',
#    'largestever',
#    'larger',
#    'large',
#    'lanes',
#    'lady',
#    'lad',
#    'klein',
#    'kinky',
#    'king',
#    'kineticallycharged',
#    'kidman',
#    'kiddie',
#    'kicking',
#    'kibbitzes',
#    'keeps',
#    'keen',
#    'jumpinyourseat',
#    'juliette',
#    'joys',
#    'jesus',
#    'jazzy',
#    'jake',
#    'jaded',
#    'jack',
#    'j',
#    'introspective',
#    'intriguing',
#    'intrigue',
#    'intoxication',
#    'intimacy',
#    'interpretation',
#    'intermittently',
#    'intentions',
#    'intense',
#    'intact',
#    'instructive',
#    'instincts',
#    'inspiring',
#    'insightfully',
#    'inquisitiveness',
#    'inoffensive',
#    'innocent',
#    'inherent',
#    'inhabit',
#    'infused',
#    'infuse',
#    'informative',
#    'information',
#    'infectious',
#    'individual',
#    'indecent',
#    'increasingly',
#    'impressive',
#    'impressionable',
#    'impossible',
#    'importance',
#    'impenetrable',
#    'immaculate',
#    'imaginable',
#    'illusion',
#    'ii',
#    'ignored',
#    'igby',
#    'iconography',
#    'iconoclastic',
#    'ian',
#    'hysteria',
#    'hybrid',
#    'huston',
#    'huskies',
#    'humming',
#    'humanly',
#    'hugescreen',
#    'huge',
#    'house',
#    'host',
#    'horrendously',
#    'hope',
#    'homage',
#    'holm',
#    'holiday',
#    'holden',
#    'hits',
#    'hitman',
#    'hitch',
#    'hip',
#    'highlighted',
#    'highconcept',
#    'heroine',
#    'hermetic',
#    'heritage',
#    'helping',
#    'helljaunt',
#    'hellbent',
#    'held',
#    'heights',
#    'heck',
#    'heaven',
#    'heartbreaking',
#    'heard',
#    'hear',
#    'head',
#    'haunting',
#    'harmless',
#    'hardwon',
#    'hanks',
#    'halfway',
#    'halfbad',
#    'gyllenhaal',
#    'gut',
#    'guffaw',
#    'grueling',
#    'growth',
#    'grow',
#    'group',
#    'grounded',
#    'gritty',
#    'gripping',
#    'greatest',
#    'grateful',
#    'graces',
#    'grace',
#    'goofball',
#    'goodness',
#    'goodnaturedly',
#    'gon',
#    'golf',
#    'golden',
#    'godfrey',
#    'goddammit',
#    'goals',
#    'gluing',
#    'glow',
#    'globe',
#    'glitter',
#    'glimpse',
#    'glass',
#    'gives',
#    'given',
#    'girlmeetsgirl',
#    'giggle',
#    'gifts',
#    'gifted',
#    'gianni',
#    'gets',
#    'genuine',
#    'gangster',
#    'games',
#    'gallic',
#    'fused',
#    'further',
#    'funniest',
#    'funloving',
#    'fruitful',
#    'frissons',
#    'friendships',
#    'friendship',
#    'frida',
#    'freshness',
#    'frenchproduced',
#    'french',
#    'freedom',
#    'franklin',
#    'frank',
#    'frames',
#    'frailty',
#    'fragile',
#    'forward',
#    'form',
#    'forget',
#    'fore',
#    'force',
#    'food',
#    'fluidity',
#    'fluid',
#    'flowery',
#    'flow',
#    'flourish',
#    'flawless',
#    'flatout',
#    'flashes',
#    'flash',
#    'flamboyant',
#    'fixating',
#    'fit',
#    'firstclass',
#    'finelooking',
#    'fine',
#    'finally',
#    'filmmaker',
#    'filmgoing',
#    'filmed',
#    'fights',
#    'fight',
#    'fiftyseven',
#    'fi',
#    'festival',
#    'fessenden',
#    'felt',
#    'features',
#    'favor',
#    'fat',
#    'fastmoving',
#    'fashion',
#    'fascinating',
#    'fantasy',
#    'fantasized',
#    'fanboy',
#    'fanatics',
#    'familyoriented',
#    'false',
#    'falling',
#    'fall',
#    'faith',
#    'fact',
#    'eyre',
#    'extraordinarily',
#    'extra',
#    'expressiveness',
#    'expressing',
#    'exploring',
#    'explores',
#    'explore',
#    'experimental',
#    'expectations',
#    'expectation',
#    'exists',
#    'existential',
#    'existed',
#    'executed',
#    'exceptional',
#    'exceedingly',
#    'examination',
#    'evil',
#    'evenings',
#    'ethnic',
#    'ethics',
#    'ethical',
#    'established',
#    'essentially',
#    'escapist',
#    'errors',
#    'eric',
#    'equal',
#    'enthusiasm',
#    'enthralling',
#    'enthrall',
#    'ensemble',
#    'enjoys',
#    ...],
#   'ls': ['three',
#    'nine',
#    'third',
#    'two',
#    'second',
#    'starting',
#    'midnight',
#    'nearly',
#    'b',
#    'half',
#    'first',
#    'than',
#    'each',
#    'less',
#    'stuart',
#    'remaining',
#    'on',
#    'date',
#    'ninth',
#    'in',
#    'zwick',
#    'writerdirectors',
#    'worldlywise',
#    'wisegirls',
#    'windinthehair',
#    'whatif',
#    'wellintentioned',
#    'welldeveloped',
#    'wellbehaved',
#    'wellbalanced',
#    'unhibited',
#    'twohourandfifteenminute',
#    'twentytwoyearold',
#    'twentyth',
#    'twelveyearold',
#    'truffaut',
#    'truecrime',
#    'to',
#    'threed',
#    'thirtythree',
#    'the',
#    'sweatypalmed',
#    'stillinestimable',
#    'spoton',
#    'spiritcrushing',
#    'spielberg',
#    'sorvino',
#    'soderbergh',
#    'siegel',
#    'shafer',
#    'seventys',
#    'selfsatisfied',
#    'selfglorification',
#    'selfexpression',
#    'scoobydoo',
#    'sarandon',
#    'salton',
#    'sade',
#    'romoli',
#    'rohmer',
#    'reggio',
#    'raphael',
#    'qatsi',
#    'prowildlife',
#    'polanski',
#    'pitchperfect',
#    'petter',
#    'partyhearty',
#    'paradiso',
#    'oncamera',
#    'of',
#    'næss',
#    'nonexploitive',
#    'ninetythree',
#    'nijinsky',
#    'nickelodeonesque',
#    'nearimpossible',
#    'morvern',
#    'mib',
#    'mesmerised',
#    'mamet',
#    'livestyle',
#    'laughoutloud',
#    'largestever',
#    'largerthanlife',
#    'kineticallycharged',
#    'kibbitzes',
#    'jumpinyourseat',
#    'juliette',
#    'igby',
#    'huston',
#    'hugescreen',
#    'highconcept',
#    'helljaunt',
#    'hardwon',
#    'halfbad',
#    'gyllenhaal',
#    'godfrey',
#    'girlmeetsgirl',
#    'gianni',
#    'frida',
#    'frenchproduced',
#    'finelooking',
#    'fiftyseven',
#    'fessenden',
#    'fastmoving',
#    'familyoriented',
#    'eyre',
#    'eightynine',
#    'eightyeight',
#    'eighteenyearold',
#    'duvall',
#    'deadon',
#    'cremaster',
#    'connectthedots',
#    'comingofage',
#    'coen',
#    'cockettes',
#    'churchwary',
#    'chabrol',
#    'campaigntrail',
#    'callar',
#    'binoche',
#    'balto',
#    'aweinspiring',
#    'auteuil',
#    'assayas',
#    'antwone',
#    'and',
#    'a',
#    'ends',
#    'final',
#    'extra',
#    'versus',
#    'last',
#    'effective',
#    'ii',
#    'set',
#    'one',
#    'halfway',
#    'every',
#    'at',
#    'j',
#    'completion',
#    'held',
#    'top',
#    'since',
#    'goes',
#    'will',
#    'jesse',
#    'equal',
#    'between',
#    'square',
#    'for',
#    'takes',
#    'just',
#    'which',
#    'least',
#    'ages',
#    'subsequent',
#    'modest',
#    'hugh',
#    'almost',
#    'sandra',
#    'alone',
#    'start',
#    'another',
#    'go',
#    'short',
#    'from',
#    'slightly',
#    'showdown',
#    'allen',
#    's',
#    'dropped',
#    'then',
#    'novak',
#    'only',
#    'mature',
#    'ryan',
#    'twin',
#    'more',
#    'stevens',
#    'mark',
#    'win',
#    'take',
#    'philadelphia',
#    'sleeper',
#    'by',
#    'net',
#    'over',
#    'worth',
#    'else',
#    'after',
#    'wo',
#    'blockbuster',
#    'special',
#    'or',
#    'through',
#    'reasonable',
#    'beat',
#    'status',
#    'ca',
#    'daniel',
#    'stays',
#    'anywhere',
#    'france',
#    'accumulated',
#    'all',
#    'would',
#    'cut',
#    'hits',
#    'beats',
#    'won',
#    'sets',
#    'off',
#    'this',
#    'mtv',
#    'same',
#    'full',
#    'opening',
#    'oliver',
#    'it',
#    'barry',
#    'eric',
#    'going',
#    'value',
#    'hold',
#    'respectable',
#    'an',
#    'jake',
#    'up',
#    'stunning',
#    'gets',
#    'number',
#    'i',
#    'stanley',
#    'realistic',
#    'betting',
#    'high',
#    'target',
#    'cost',
#    'adults',
#    'dual',
#    'moved',
#    'action',
#    'thriller',
#    'both',
#    'moderately',
#    'step',
#    'hours',
#    'tom',
#    'probably',
#    'due',
#    'sensational',
#    'rises',
#    'missing',
#    'day',
#    'class',
#    'concerned',
#    'born',
#    'balance',
#    'long',
#    'fantasy',
#    'back',
#    'share',
#    'season',
#    'him',
#    'amounts',
#    'prime',
#    'par',
#    'ups',
#    'anything',
#    'joel',
#    'golden',
#    'mariah',
#    'arc',
#    'chicago',
#    'feeling',
#    'mixture',
#    'end',
#    'range',
#    'carey',
#    'carries',
#    'bold',
#    'giving',
#    'huge',
#    'saturday',
#    'essentially',
#    'feat',
#    'chance',
#    'original',
#    'sonny',
#    't',
#    'minutes',
#    'decent',
#    'robert',
#    'its',
#    'comprise',
#    'little',
#    'emerges',
#    'bourne',
#    'solidly',
#    'shot',
#    'clock',
#    'get',
#    'time',
#    'care',
#    'be',
#    'nt',
#    'black',
#    'russian',
#    'solid',
#    'recommendation',
#    'awarded',
#    'around',
#    'usually',
#    'interest',
#    'right',
#    'epic',
#    'meaningful',
#    'under',
#    'games',
#    'was',
#    'apart',
#    'hybrid',
#    'change',
#    'actual',
#    'sure',
#    'choose',
#    'popcorn',
#    'definitive',
#    'without',
#    'down',
#    'standard',
#    'saving',
#    'race',
#    'forget',
#    'fall',
#    'committed',
#    'hollywood',
#    'match',
#    'pace',
#    'blue',
#    'ever',
#    'something',
#    'play',
#    'felt',
#    'suspended',
#    'leave',
#    'carl',
#    'pie',
#    'kiddie',
#    'no',
#    'should',
#    'magical',
#    'far',
#    'bon',
#    'turns',
#    'budget',
#    'arguably',
#    'themselves',
#    'nothing',
#    'new',
#    'is',
#    'much',
#    'consistently',
#    'younger',
#    'most',
#    'intrigue',
#    'falling',
#    'must',
#    'host',
#    'upping',
#    'flatout',
#    'baffling',
#    'eats',
#    'transition',
#    'spectacular',
#    'disney',
#    'with',
#    'could',
#    'aboveaverage',
#    'contribution',
#    'getting',
#    'deserves',
#    'maturity',
#    'fine',
#    'washington',
#    'heck',
#    'goodness',
#    'morrison',
#    'any',
#    'consume',
#    'straight',
#    'american',
#    'fare',
#    'littleknown',
#    'anyone',
#    'information',
#    'watts',
#    'larger',
#    'proposal',
#    'type',
#    'sci',
#    'wildly',
#    'ride',
#    'actionpacked',
#    'length',
#    'emotionally',
#    'televised',
#    'eat',
#    'territory',
#    'out',
#    'welsh',
#    'when',
#    'dark',
#    'watch',
#    'astonishing',
#    'assets',
#    'big',
#    'mr',
#    'achieving',
#    'diverges',
#    'crack',
#    'heist',
#    'proposes',
#    'confident',
#    'complications',
#    'sequence',
#    'willing',
#    'drastic',
#    'let',
#    'impressive',
#    'roars',
#    'phantom',
#    'delivery',
#    'hitch',
#    'comes',
#    'worthy',
#    'absolutely',
#    'feel',
#    'dazzling',
#    'force',
#    'philosophical',
#    'night',
#    'hip',
#    'philip',
#    'strike',
#    'wound',
#    'saga',
#    'king',
#    'gon',
#    'follow',
#    'curious',
#    'they',
#    'producer',
#    'applying',
#    'questions',
#    'positive',
#    'fluid',
#    'potent',
#    'cheese',
#    'gas',
#    'them',
#    'wow',
#    'can',
#    'scariest',
#    'battle',
#    'candidate',
#    'flawless',
#    'drama',
#    'performance',
#    'convincing',
#    'effort',
#    'pipeline',
#    'surefire',
#    'you',
#    'rarity',
#    'significance',
#    'doubts',
#    'peaks',
#    'forced',
#    'bar',
#    'mattered',
#    'spy',
#    'french',
#    'ripping',
#    'scotland',
#    'decade',
#    'berry',
#    'got',
#    'startling',
#    'fixating',
#    'stand',
#    'love',
#    'players',
#    'minor',
#    'scoring',
#    'sand',
#    'ranks',
#    'world',
#    'move',
#    'your',
#    'station',
#    'jesus',
#    'emerge',
#    'shine',
#    'picked',
#    'masterpiece',
#    'balk',
#    'me',
#    'succeeds',
#    'face',
#    'actually',
#    'power',
#    'think',
#    'dance',
#    'laughable',
#    'domestic',
#    'sentimental',
#    'as',
#    'better',
#    'white',
#    'puff',
#    'fight',
#    'feature',
#    'scary',
#    'wrong',
#    'touching',
#    'wanting',
#    'matters',
#    'spikes',
#    'kidman',
#    'come',
#    'he',
#    'prison',
#    'outing',
#    'goddammit',
#    'star',
#    'rare',
#    'venice',
#    'beloved',
#    'relatively',
#    'job',
#    'veggies',
#    'jack',
#    'golf',
#    'path',
#    'evenings',
#    'large',
#    'while',
#    'male',
#    'achieves',
#    'given',
#    'based',
#    'spiderman',
#    'my',
#    'frames',
#    'franklin',
#    'mel',
#    'universal',
#    'considerable',
#    'watchable',
#    'fun',
#    'na',
#    'mix',
#    'acceptable',
#    'exceptional',
#    'roman',
#    'guy',
#    'accuracy',
#    'intoxication',
#    'expectation',
#    'wise',
#    'lanes',
#    'helping',
#    'raised',
#    'tremendous',
#    'throughout',
#    'hundred',
#    'space',
#    'finally',
#    'score',
#    'performances',
#    'allows',
#    'but',
#    'recent',
#    'into',
#    'pure',
#    'confusing',
#    'further',
#    'dread',
#    'what',
#    'talent',
#    'credits',
#    'attempted',
#    'even',
#    'anteing',
#    'prove',
#    'dramatically',
#    'reasonably',
#    'japanese',
#    'itself',
#    'so',
#    'rivals',
#    'team',
#    'perfect',
#    'directly',
#    'individual',
#    'that',
#    'miracle',
#    'holm',
#    'rising',
#    'philippe',
#    'tiny',
#    'still',
#    'grueling',
#    'not',
#    'sibling',
#    'capable',
#    'being',
#    'depth',
#    'ticking',
#    'audacious',
#    'arrive',
#    'career',
#    'emotional',
#    'steven',
#    'swim',
#    'sugar',
#    'gifts',
#    'beings',
#    'thousand',
#    'firstclass',
#    'talk',
#    'gut',
#    'cleaving',
#    'whole',
#    'goodly',
#    'trouble',
#    'pop',
#    'heart',
#    'found',
#    'pretty',
#    'detailed',
#    'sharply',
#    'though',
#    'food',
#    'ramifications',
#    'assassin',
#    'about',
#    'project',
#    'spike',
#    'unexpectedly',
#    'potential',
#    'represents',
#    'ian',
#    'making',
#    'struggling',
#    'crowdpleasing',
#    'paper',
#    'errors',
#    'relegated',
#    'classic',
#    'differences',
#    'intact',
#    'bow',
#    'crimes',
#    'believing',
#    'orbit',
#    'loved',
#    'holiday',
#    'their',
#    'best',
#    'problem',
#    'satisfying',
#    'learn',
#    'breathtaking',
#    'equally',
#    'executed',
#    'harmless',
#    'stirring',
#    'effectively',
#    'small',
#    'surprising',
#    'established',
#    'punch',
#    'expectations',
#    'forward',
#    'reconciliation',
#    'affecting',
#    'myth',
#    'those',
#    'work',
#    'suspenseful',
#    'gritty',
#    'shockingly',
#    'surprisingly',
#    'light',
#    'frank',
#    'confidence',
#    'talking',
#    'projects',
#    'stores',
#    'cannon',
#    'memorable',
#    'pill',
#    'anyplace',
#    'try',
#    'prefer',
#    'struggles',
#    'tribute',
#    'depression',
#    'digital',
#    'craft',
#    'story',
#    'absorbing',
#    'form',
#    'female',
#    'intriguing',
#    'storytelling',
#    'trap',
#    'sweet',
#    'his',
#    'ante',
#    'complex',
#    'collection',
#    'enough',
#    'magic',
#    'ravaging',
#    'dangerous',
#    'honestly',
#    'stirs',
#    'loaded',
#    'motion',
#    'looks',
#    'experimental',
#    'bad',
#    'counts',
#    'revenge',
#    'entertainment',
#    'imaginable',
#    'movies',
#    'compromise',
#    'makers',
#    'edition',
#    'impossible',
#    'nobody',
#    'rap',
#    'club',
#    'girlfriend',
#    'here',
#    'lingerie',
#    'greatest',
#    'watching',
#    'tough',
#    'commentary',
#    'history',
#    'killed',
#    'do',
#    'needs',
#    'seat',
#    'acute',
#    'laugh',
#    'globe',
#    'city',
#    'lines',
#    'pianist',
#    'give',
#    'scenario',
#    'unexpected',
#    'ultimately',
#    'grew',
#    'newcomers',
#    'reap',
#    'lane',
#    'hard',
#    'terrifying',
#    'because',
#    'don',
#    'read',
#    'movie',
#    'native',
#    'feelgood',
#    'plot',
#    'proves',
#    'liar',
#    'bons',
#    'attention',
#    'mythic',
#    'saw',
#    'results',
#    'lot',
#    'word',
#    'false',
#    'kwan',
#    'horror',
#    'congrats',
#    'jolt',
#    'check',
#    'able',
#    'stars',
#    'goals',
#    'shows',
#    'honest',
#    'punctuation',
#    'has',
#    'local',
#    'yarn',
#    'riproaring',
#    'klein',
#    'flow',
#    'treat',
#    'good',
#    'election',
#    'cautionary',
#    'bicentennial',
#    'claude',
#    'turn',
#    'grounded',
#    'gutwrenching',
#    'reruns',
#    'heights',
#    'swallow',
#    'however',
#    'animated',
#    'flick',
#    'become',
#    'opportunities',
#    'perspective',
#    'offer',
#    'loves',
#    'memory',
#    'drugs',
#    'enthralling',
#    'canvas',
#    'numerous',
#    'purely',
#    'want',
#    'definition',
#    'carrying',
#    'trilogy',
#    'rich',
#    'kid',
#    'happened',
#    'see',
#    'grow',
#    'retains',
#    'fanboy',
#    'credibility',
#    'surprises',
#    'involving',
#    'may',
#    'did',
#    'window',
#    'sequences',
#    'hand',
#    'approach',
#    'glass',
#    'exists',
#    'study',
#    'alien',
#    'darker',
#    'easily',
#    'remarkable',
#    'attempt',
#    'we',
#    'definitely',
#    'avoids',
#    'fake',
#    'seen',
#    'affirming',
#    'fans',
#    'man',
#    'usual',
#    'some',
#    'thanks',
#    'angst',
#    'vintage',
#    'hysteria',
#    'clutch',
#    'awful',
#    'tender',
#    'private',
#    'does',
#    've',
#    'legend',
#    'way',
#    'well',
#    'daring',
#    'interesting',
#    'maxim',
#    'likable',
#    'changing',
#    'yet',
#    'growth',
#    'transcends',
#    'spooky',
#    'bringing',
#    'sea',
#    'adventure',
#    'inside',
#    'pale',
#    'precisely',
#    'swooning',
#    'cute',
#    'were',
#    'her',
#    'note',
#    'fantasized',
#    'specimen',
#    'make',
#    'inspiring',
#    'politically',
#    'kicking',
#    'chord',
#    'laidback',
#    'storyline',
#    'across',
#    'lilo',
#    'intermittently',
#    'speaks',
#    'believable',
#    'swung',
#    'times',
#    'never',
#    'lee',
#    'teen',
#    'video',
#    'stimulating',
#    'vulnerability',
#    'frightening',
#    'summer',
#    'courageous',
#    'innocent',
#    'done',
#    'seems',
#    'succeed',
#    'routine',
#    'too',
#    'perfectly',
#    'holden',
#    'version',
#    'impenetrable',
#    'awed',
#    'gluing',
#    'there',
#    'enjoyment',
#    'favor',
#    'boy',
#    'sides',
#    'psychological',
#    'memorial',
#    'collide',
#    'amazing',
#    'war',
#    'grace',
#    'quiet',
#    'result',
#    'revelations',
#    'certainly',
#    'enjoyed',
#    'brutally',
#    'versatile',
#    'escapist',
#    'nail',
#    'machine',
#    'moving',
#    'earnest',
#    'women',
#    'genres',
#    'strong',
#    'find',
#    'oscar',
#    'moral',
#    'captivating',
#    'book',
#    'role',
#    'knowing',
#    'if',
#    'wish',
#    'sportsmen',
#    'overly',
#    'largely',
#    'attractive',
#    'artist',
#    'talented',
#    'infused',
#    'uplifting',
#    'odd',
#    'lifechanging',
#    'accomplished',
#    'revealing',
#    'liked',
#    'heartbreaking',
#    'discovery',
#    'ambiguities',
#    'smiles',
#    'screen',
#    ...],
#   'ccw': ['nine',
#    'stuart',
#    'solid',
#    'each',
#    'him',
#    'twentyth',
#    'spielberg',
#    'selfglorification',
#    'scoobydoo',
#    'raphael',
#    'pitchperfect',
#    'paradiso',
#    'largerthanlife',
#    'eightynine',
#    'antwone',
#    'starting',
#    'one',
#    'fare',
#    'b',
#    'jesse',
#    'and',
#    'giving',
#    'chance',
#    'saving',
#    'philadelphia',
#    'remaining',
#    'date',
#    'ninth',
#    'beat',
#    'status',
#    'zwick',
#    'writerdirectors',
#    'worldlywise',
#    'wisegirls',
#    'windinthehair',
#    'whatif',
#    'wellintentioned',
#    'welldeveloped',
#    'wellbehaved',
#    'wellbalanced',
#    'unhibited',
#    'twelveyearold',
#    'truffaut',
#    'truecrime',
#    'threed',
#    'thirtythree',
#    'sweatypalmed',
#    'stillinestimable',
#    'spoton',
#    'soderbergh',
#    'siegel',
#    'shafer',
#    'seventys',
#    'selfexpression',
#    'sarandon',
#    'salton',
#    'sade',
#    'romoli',
#    'rohmer',
#    'reggio',
#    'qatsi',
#    'prowildlife',
#    'polanski',
#    'petter',
#    'oncamera',
#    'næss',
#    'nonexploitive',
#    'ninetythree',
#    'nijinsky',
#    'nickelodeonesque',
#    'nearimpossible',
#    'morvern',
#    'mib',
#    'mesmerised',
#    'mamet',
#    'livestyle',
#    'laughoutloud',
#    'largestever',
#    'kineticallycharged',
#    'kibbitzes',
#    'jumpinyourseat',
#    'juliette',
#    'igby',
#    'huston',
#    'hugescreen',
#    'highconcept',
#    'helljaunt',
#    'hardwon',
#    'halfbad',
#    'gyllenhaal',
#    'godfrey',
#    'girlmeetsgirl',
#    'gianni',
#    'frida',
#    'frenchproduced',
#    'finelooking',
#    'fiftyseven',
#    'fessenden',
#    'fastmoving',
#    'familyoriented',
#    'eyre',
#    'eightyeight',
#    'duvall',
#    'deadon',
#    'cremaster',
#    'connectthedots',
#    'comingofage',
#    'coen',
#    'cockettes',
#    'churchwary',
#    'chabrol',
#    'campaigntrail',
#    'callar',
#    'binoche',
#    'balto',
#    'aweinspiring',
#    'auteuil',
#    'france',
#    'extra',
#    'versus',
#    'worthy',
#    'ii',
#    'moved',
#    'halfway',
#    'class',
#    'j',
#    'season',
#    'completion',
#    'held',
#    'feat',
#    'top',
#    'since',
#    'equal',
#    'square',
#    'awarded',
#    'interest',
#    'ages',
#    'subsequent',
#    'committed',
#    'modest',
#    'alone',
#    'start',
#    'themselves',
#    'slightly',
#    'showdown',
#    'allen',
#    'dropped',
#    'novak',
#    'mature',
#    'ryan',
#    'twin',
#    'deserves',
#    'stevens',
#    'win',
#    'sleeper',
#    'anyone',
#    'net',
#    'televised',
#    'wo',
#    'astonishing',
#    'crack',
#    'most',
#    'absolutely',
#    'reasonable',
#    'dazzling',
#    'daniel',
#    'stays',
#    'anywhere',
#    'accumulated',
#    'hits',
#    'beats',
#    'won',
#    'sets',
#    'mtv',
#    'opening',
#    'oliver',
#    'barry',
#    'eric',
#    'respectable',
#    'jake',
#    'stunning',
#    'gets',
#    'number',
#    'stanley',
#    'realistic',
#    'betting',
#    'cost',
#    'dual',
#    'moderately',
#    'step',
#    'due',
#    'sensational',
#    'rises',
#    'concerned',
#    'born',
#    'fantasy',
#    'share',
#    'prime',
#    'par',
#    'ups',
#    'golden',
#    'mariah',
#    'arc',
#    'chicago',
#    'mixture',
#    'end',
#    'range',
#    'carey',
#    'carries',
#    'bold',
#    'huge',
#    'essentially',
#    'sonny',
#    't',
#    'comprise',
#    'emerges',
#    'bourne',
#    'solidly',
#    'clock',
#    'russian',
#    'recommendation',
#    'meaningful',
#    'under',
#    'games',
#    'apart',
#    'hybrid',
#    'change',
#    'actual',
#    'popcorn',
#    'definitive',
#    'standard',
#    'race',
#    'forget',
#    'fall',
#    'match',
#    'felt',
#    'suspended',
#    'leave',
#    'carl',
#    'pie',
#    'kiddie',
#    'magical',
#    'bon',
#    'arguably',
#    'consistently',
#    'younger',
#    'intrigue',
#    'falling',
#    'must',
#    'host',
#    'upping',
#    'flatout',
#    'baffling',
#    'eats',
#    'transition',
#    'disney',
#    'aboveaverage',
#    'contribution',
#    'maturity',
#    'fine',
#    'washington',
#    'heck',
#    'goodness',
#    'morrison',
#    'consume',
#    'straight',
#    'littleknown',
#    'information',
#    'watts',
#    'larger',
#    'proposal',
#    'type',
#    'sci',
#    'wildly',
#    'ride',
#    'actionpacked',
#    'eat',
#    'welsh',
#    'assets',
#    'achieving',
#    'diverges',
#    'confident',
#    'complications',
#    'willing',
#    'drastic',
#    'let',
#    'impressive',
#    'roars',
#    'phantom',
#    'delivery',
#    'hitch',
#    'force',
#    'philosophical',
#    'hip',
#    'philip',
#    'strike',
#    'wound'],
#   'scw': ['three',
#    'third',
#    'second',
#    'to',
#    'nearly',
#    'midnight',
#    'the',
#    'of',
#    'half',
#    'than',
#    'on',
#    'less',
#    'a',
#    'twohourandfifteenminute',
#    'twentytwoyearold',
#    'spiritcrushing',
#    'selfsatisfied',
#    'partyhearty',
#    'eighteenyearold',
#    'assayas',
#    'ends',
#    'final',
#    'sorvino',
#    'at',
#    'last',
#    'every',
#    'effective',
#    'set',
#    's',
#    'for',
#    'will',
#    'goes',
#    'between',
#    'which',
#    'takes',
#    'least',
#    'just',
#    'another',
#    'go',
#    'almost',
#    'short',
#    'from',
#    'hugh',
#    'sandra',
#    'more',
#    'or',
#    'take',
#    'mark',
#    'over',
#    'through',
#    'else',
#    'after',
#    'all',
#    'special',
#    'it',
#    'by',
#    'would',
#    'blockbuster',
#    'off',
#    'same',
#    'cut',
#    'going',
#    'value',
#    'hold',
#    'high',
#    'full',
#    'both',
#    'this',
#    'nt',
#    'target',
#    'hours',
#    'back',
#    'long',
#    'an',
#    'thriller',
#    'is',
#    'probably',
#    'tom',
#    'action',
#    'balance',
#    'be',
#    'day',
#    'amounts',
#    'missing',
#    'feeling',
#    'joel',
#    'anything',
#    'get',
#    'minutes',
#    'saturday',
#    'much',
#    'decent',
#    'robert',
#    'care',
#    'little',
#    'no',
#    'shot',
#    'nothing',
#    'hollywood',
#    'was',
#    'time',
#    'right',
#    'black',
#    'original',
#    'around',
#    'usually',
#    'down',
#    'sure',
#    'choose',
#    'something',
#    'epic',
#    'pace',
#    'blue',
#    'play',
#    'far',
#    'turns',
#    'budget',
#    'ever',
#    'should',
#    'getting',
#    'out',
#    'when',
#    'any',
#    'spectacular',
#    'length',
#    'could',
#    'territory',
#    'comes',
#    'mr',
#    'feel',
#    'heist',
#    'proposes',
#    'sequence',
#    'big',
#    'dark',
#    'night',
#    'watch'],
#   'fcw': ['wonderful',
#    'style',
#    'culture',
#    'ways',
#    'ingenious',
#    'whose',
#    'occasionally',
#    'sly',
#    'manner',
#    'amusing',
#    'modern',
#    'cinema',
#    'imaginative',
#    'pleasure',
#    'intimate',
#    'cleverness',
#    'warmth',
#    'inquisitiveness',
#    'fore',
#    'countercultural',
#    'setpieces',
#    'inventive',
#    'bourgeois',
#    'occasional',
#    'lovely',
#    'engaged',
#    'nurtured',
#    'era',
#    'depiction',
#    'involved',
#    'pretension',
#    'manages',
#    'sophisticated',
#    'sardonic',
#    'nononsense',
#    'keen',
#    'darkly',
#    'iconoclastic',
#    'atmosphere',
#    'gentle',
#    'presence',
#    'adorably',
#    'political',
#    'behold',
#    'delicately',
#    'blithe',
#    'truths',
#    'influenced',
#    'sanctimoniousness',
#    'winking',
#    'iconography',
#    'sincerity',
#    'lady',
#    'dynamism',
#    'newfangled',
#    'humor',
#    'inherent',
#    'midwest',
#    'underbelly',
#    'taste',
#    'spirit',
#    'amoral',
#    'comically',
#    'lovingly',
#    'elegance',
#    'mind',
#    'lively',
#    'costuming',
#    'gestalt',
#    'charm',
#    'commend',
#    'cultural',
#    'charms',
#    'wizened',
#    'eye',
#    'neat',
#    'topnotch',
#    'photographed',
#    'bombastic',
#    'leonine',
#    'hermetic',
#    'inhabit',
#    'wistfully',
#    'wispy',
#    'astringent',
#    'heartfelt',
#    'deportment',
#    'human',
#    'layers',
#    'splendid',
#    'antiwar',
#    'artistic',
#    'meditation',
#    'subculture',
#    'adolescent',
#    'documentarian',
#    'refreshingly',
#    'works',
#    'existential',
#    'parody',
#    'joys',
#    'thankfully',
#    'masterfully',
#    'smartly',
#    'insightfully',
#    'meddles',
#    'spell',
#    'convinces',
#    'souls',
#    'lad',
#    'vanity',
#    'huskies',
#    'cleverly',
#    'subtle',
#    'voices',
#    'lives',
#    'fiascos',
#    'fused',
#    'entertaining',
#    'strangely',
#    'vistas',
#    'subtly',
#    'background',
#    'unique',
#    'bristles',
#    'sweetness',
#    'whimsy',
#    'freshness',
#    'yearnings',
#    'traveler',
#    'frissons',
#    'wrought',
#    'intimacy',
#    'readymade',
#    'images',
#    'clichés',
#    'resonant',
#    'glimpse',
#    'hilarious',
#    'sneering',
#    'pleasant',
#    'titular',
#    'eerie',
#    'unhinged',
#    'eloquent',
#    'piercing',
#    'observation',
#    'stanzas',
#    'stylishly',
#    'offbeat',
#    'dynamics',
#    'charming',
#    'immaculate',
#    'creative',
#    'urban',
#    'resourceful',
#    'strange',
#    'anarchist',
#    'conceptual',
#    'matron',
#    'stylish',
#    'gallic',
#    'yearning',
#    'sensitivity',
#    'vibrant',
#    'uniquely',
#    'inspired',
#    'others',
#    'undeniable',
#    'brilliance',
#    'wonderfully',
#    'camerawork',
#    'lend',
#    'filmed',
#    'merrily',
#    'attuned',
#    'cheery',
#    'openness',
#    'bravery',
#    'sabotage',
#    'servants',
#    'movements',
#    'songs',
#    'characteristically',
#    'playwriting',
#    'subtlety',
#    'scripting',
#    'verve',
#    'fact',
#    'stylists',
#    'wasp',
#    'family',
#    'humanly',
#    'edifying',
#    'schtick',
#    'ripening',
#    'drumming',
#    'partisans',
#    'parable',
#    'desolate',
#    'sounding',
#    'filmgoing',
#    'spirits',
#    'ditsy',
#    'ecological',
#    'exploring',
#    'visually',
#    'fluidity',
#    'metaphors',
#    'examination',
#    'ensemble',
#    'colorful',
#    'natured',
#    'flamboyant',
#    'guffaw',
#    'charismatic',
#    'witty',
#    'president',
#    'cheerfully',
#    'demonstrates',
#    'woodman',
#    'outrageousness',
#    'nuance',
#    'missive',
#    'instructive',
#    'camera',
#    'pursuing',
#    'flowery',
#    'compulsively',
#    'dismissed',
#    'captivatingly',
#    'layered',
#    'poetry',
#    'stickiness',
#    'hear',
#    'abundant',
#    'campy',
#    'contrivances',
#    'sincere',
#    'routines',
#    'pertinent',
#    'noble',
#    'anniversary',
#    'encounters',
#    'ravishing',
#    'conceive',
#    'necessarily',
#    'beautifully',
#    'suggest',
#    'head',
#    'revolutionary',
#    'informative',
#    'grateful',
#    'calibrated',
#    'argues',
#    'degree',
#    'increasingly',
#    'characteristic',
#    'filmmaker',
#    'associated',
#    'enthusiasm',
#    'unruly',
#    'encountering',
#    'frailty',
#    'fruitful',
#    'distinct',
#    'friendships',
#    'buoyant',
#    'intentions',
#    'weirdly',
#    'reinvention',
#    'secretly',
#    'penetrating',
#    'noir',
#    'ethical',
#    'levity',
#    'lothario',
#    'funloving',
#    'brooks',
#    'clooney',
#    'bighearted',
#    'press',
#    'biting',
#    'tranquil',
#    'combines',
#    'melodramatic',
#    'sincerely',
#    'laughed',
#    'animations',
#    'technology',
#    'movement',
#    'illusion',
#    'suits',
#    'melodrama',
#    'appreciates',
#    'reassuring',
#    'diaries',
#    'expressiveness',
#    'awakening',
#    'dimension',
#    'reflected',
#    'importance',
#    'introspective',
#    'tattoos',
#    'sprung',
#    'tradition',
#    'crafted',
#    'corniest',
#    'unabashedly',
#    'oozing',
#    'appreciate',
#    'wistful',
#    'reunion',
#    'jaded',
#    'existed',
#    'literate',
#    'originality',
#    'stage',
#    'seamy',
#    'showcases',
#    'genuine',
#    'diverse',
#    'chuckles',
#    'menace',
#    'classy',
#    'delightful',
#    'transcendence',
#    'lips',
#    'technical',
#    'festival',
#    'appealing',
#    'case',
#    'spiffy',
#    'purists',
#    'glitter',
#    'unadulterated',
#    'stitch',
#    'novel',
#    'rewarding',
#    'naughty',
#    'vital',
#    'brothers',
#    'urge',
#    'gangster',
#    'brimming',
#    'sentiments',
#    'prophet',
#    'timeconsuming',
#    'desperation',
#    'gifted',
#    'exceedingly',
#    'deft',
#    'horrendously',
#    'expressing',
#    'comfort',
#    'fascinating',
#    'portrait',
#    'navigate',
#    'ethics',
#    'cartoonish',
#    'enjoys',
#    'creature',
#    'highlighted',
#    'refreshed',
#    'parents',
#    'keeps',
#    'solutions',
#    'denuded',
#    'infuse',
#    'triumphs',
#    'unseemly',
#    'chimes',
#    'sorrow',
#    'documenting'],
#   'iw': ['clever',
#    'tastelessness',
#    'elegantly',
#    'shrewd',
#    'ennui',
#    'director',
#    'callow',
#    'audience',
#    'wit',
#    'moments',
#    'such',
#    'kind',
#    'identity',
#    'hackneyed',
#    'crass',
#    'worked',
#    'utter',
#    'seem',
#    'act',
#    'indulgent',
#    'particularly',
#    'naturalistic',
#    'filmmakers',
#    'tragedy',
#    'screenplay',
#    'like',
#    'intelligent',
#    'dreams',
#    'bullock',
#    'insight',
#    'past',
#    'often',
#    'art',
#    'tragic',
#    'edge',
#    'moment',
#    'saccharine',
#    'comic',
#    'acting',
#    'told',
#    'sound',
#    'visual',
#    'concept',
#    'scene',
#    'exaggerated',
#    'intelligence',
#    'scenes',
#    'particular',
#    'charisma',
#    'suggests',
#    'actress',
#    'always',
#    'eyes',
#    'audiences',
#    'direction',
#    'narrative',
#    'real',
#    'mindless',
#    'smart',
#    'murder',
#    'quirky',
#    'mistress',
#    'excellent',
#    'endearing',
#    'addition']},
#  '0': {'lr': ['tv',
#    'lack',
#    'years',
#    'series',
#    'before',
#    'worst',
#    'tone',
#    'run',
#    'purpose',
#    'predictable',
#    'pacing',
#    'loud',
#    'forgettable',
#    'flat',
#    'feels',
#    'familiar',
#    'falls',
#    'effects',
#    'despite',
#    'bland',
#    'too',
#    'to',
#    'wilde',
#    'wasted',
#    'vampire',
#    'uneven',
#    'trying',
#    'title',
#    'tired',
#    'stupid',
#    'soap',
#    'sit',
#    'shallow',
#    'room',
#    'putting',
#    'promising',
#    'possible',
#    'plodding',
#    'opera',
#    'onto',
#    'need',
#    'merit',
#    'limp',
#    'imagine',
#    'having',
#    'hate',
#    'gags',
#    'four',
#    'formulaic',
#    'edited',
#    'dumb',
#    'crazy',
#    'contrived',
#    'commercial',
#    'combined',
#    'bore',
#    'bit',
#    'avoid',
#    'year',
#    'worse',
#    'within',
#    'whatsoever',
#    'whatever',
#    'waste',
#    'violent',
#    'unpleasant',
#    'unfunny',
#    'typical',
#    'tries',
#    'tricks',
#    'trash',
#    'total',
#    'toilethumor',
#    'terror',
#    'terrible',
#    'swan',
#    'subjects',
#    'starts',
#    'squarely',
#    'speedy',
#    'sort',
#    'snore',
#    'slip',
#    'slimed',
#    'slapstick',
#    'situations',
#    'situation',
#    'simpleminded',
#    'similar',
#    'silly',
#    'several',
#    'sequel',
#    'selfconscious',
#    'rowling',
#    'responsible',
#    'resonance',
#    'remake',
#    'relentlessly',
#    'recycled',
#    'reality',
#    'raw',
#    'quirks',
#    'promisingly',
#    'possibilities',
#    'poorly',
#    'pieces',
#    'phony',
#    'period',
#    'pack',
#    'obscure',
#    'numbers',
#    'name',
#    'murphy',
#    'morning',
#    'money',
#    'misconceived',
#    'mess',
#    'merely',
#    'meat',
#    'meandering',
#    'martha',
#    'low',
#    'loose',
#    'listless',
#    'letdown',
#    'landing',
#    'know',
#    'jokes',
#    'joke',
#    'irritating',
#    'incoherence',
#    'important',
#    'ideas',
#    'humorless',
#    'hotels',
#    'home',
#    'hollow',
#    'highly',
#    'heroes',
#    'heavyhanded',
#    'hastily',
#    'hartley',
#    'harry',
#    'had',
#    'girls',
#    'funnier',
#    'five',
#    'firstrate',
#    'finds',
#    'few',
#    'eight',
#    'ego',
#    'efforts',
#    'editing',
#    'ears',
#    'duds',
#    'dubbed',
#    'drew',
#    'drag',
#    'dough',
#    'dive',
#    'disaster',
#    'difficult',
#    'damage',
#    'confused',
#    'clumsy',
#    'close',
#    'cheap',
#    'bother',
#    'boring',
#    'becomes',
#    'badly',
#    'artificial',
#    'appears',
#    'animation',
#    'already',
#    'again',
#    'adaptation',
#    'abuse',
#    'absurdity',
#    'abandon',
#    'as',
#    'your',
#    'bad',
#    'the',
#    'of',
#    'that',
#    'into',
#    'special',
#    'hours',
#    'on',
#    'zemeckis',
#    'yourself',
#    'york',
#    'yielded',
#    'yes',
#    'yelling',
#    'yard',
#    'writerproducerdirector',
#    'writerdirector',
#    'wrists',
#    'wrap',
#    'wore',
#    'wobbly',
#    'willingness',
#    'wholly',
#    'where',
#    'western',
#    'wellacted',
#    'week',
#    'wedgie',
#    'wearisome',
#    'waterlogged',
#    'water',
#    'wasting',
#    'warn',
#    'warmovie',
#    'warmed',
#    'wall',
#    'walk',
#    'waiting',
#    'waited',
#    'wait',
#    'vu',
#    'visions',
#    'villainess',
#    'viewing',
#    'viewer',
#    'victim',
#    'vehicle',
#    'various',
#    'vaporize',
#    'vacuous',
#    'vacant',
#    'usher',
#    'used',
#    'use',
#    'unwieldy',
#    'unusual',
#    'unsurprising',
#    'unnecessary',
#    'unnamed',
#    'unleashes',
#    'ungainly',
#    'unfulfilling',
#    'unfortunately',
#    'unfortunate',
#    'unfocused',
#    'unfaithful',
#    'underrehearsed',
#    'underestimated',
#    'undercuts',
#    'unconvincing',
#    'uncommitted',
#    'uncinematic',
#    'unbelievable',
#    'ultimate',
#    'uglylooking',
#    'ugly',
#    'ugliness',
#    'ugh',
#    'twentyfourandunders',
#    'tvmovie',
#    'tvinsider',
#    'trite',
#    'tripe',
#    'trifle',
#    'tried',
#    'treatment',
#    'treading',
#    'translation',
#    'trace',
#    'tornatore',
#    'topical',
#    'tool',
#    'tooconscientious',
#    'tommy',
#    'tiresome',
#    'tiniest',
#    'timing',
#    'ticket',
#    'throwntogether',
#    'threehour',
#    'thoughtlessly',
#    'thirtys',
#    'thirdperson',
#    'thin',
#    'thematic',
#    'thecash',
#    'theater',
#    'text',
#    'test',
#    'terribly',
#    'tenyear',
#    'tendentious',
#    'telling',
#    'teensleaze',
#    'teendriven',
#    'tedious',
#    'techgeeks',
#    'tearing',
#    'tear',
#    'taxicab',
#    'tart',
#    'targeted',
#    'taking',
#    'tactics',
#    'synergistic',
#    'sympathy',
#    'swordandsorcery',
#    'swill',
#    'swear',
#    'sustain',
#    'survive',
#    'surrounding',
#    'surprise',
#    'supposed',
#    'superior',
#    'superficial',
#    'summercamp',
#    'sugarman',
#    'suffers',
#    'sudden',
#    'successor',
#    'substitutable',
#    'subplots',
#    'subject',
#    'styles',
#    'stupefying',
#    'stuffy',
#    'stuff',
#    'structure',
#    'stronger',
#    'strained',
#    'straddles',
#    'stories',
#    'stopandstart',
#    'stomach',
#    'stolid',
#    'stinks',
#    'stilted',
#    'stifles',
#    'stewart',
#    'stereotypical',
#    'stereotype',
#    'stealing',
#    'startled',
#    'starring',
#    'stare',
#    'standoffish',
#    'stalking',
#    'stains',
#    'stagy',
#    'squint',
#    'squeeze',
#    'spousal',
#    'sport',
#    'spookiness',
#    'spoof',
#    'spliced',
#    'spiritual',
#    'spend',
#    'spectacularly',
#    'span',
#    'soundtrack',
#    'sorority',
#    'soontobeforgettable',
#    'soon',
#    'someone',
#    'soliloquies',
#    'snow',
#    'snl',
#    'sneaky',
#    'snaillike',
#    'smugly',
#    'smacks',
#    'sluggish',
#    'sloppily',
#    'slomo',
#    'slice',
#    'slc',
#    'slapping',
#    'slapped',
#    'slack',
#    'skill',
#    'sketchy',
#    'sketchiest',
#    'sixtys',
#    'sitcom',
#    'sinks',
#    'singleminded',
#    'simpering',
#    'silver',
#    'sillified',
#    'silbersteins',
#    'signs',
#    'signpost',
#    'sign',
#    'sight',
#    'sidewalks',
#    'shtick',
#    'shrek',
#    'showcase',
#    'show',
#    'shoot',
#    'ship',
#    'she',
#    'sharing',
#    'shame',
#    'sexy',
#    'sex',
#    'setups',
#    'serviceability',
#    'serve',
#    'serious',
#    'serials',
#    'sequels',
#    'sentiment',
#    'sentence',
#    'send',
#    'seller',
#    'selfindulgent',
#    'selfimportant',
#    'selfconsciously',
#    'selfcongratulation',
#    'selfawareness',
#    'segment',
#    'seemed',
#    'section',
#    'secrets',
#    'secret',
#    'search',
#    'scrutiny',
#    'scripts',
#    'screening',
#    'scifi',
#    'scientific',
#    'school',
#    'scalds',
#    'saying',
#    'saved',
#    'satire',
#    'sanctimony',
#    'said',
#    'sadly',
#    'sabotaged',
#    'running',
#    'rubbo',
#    'round',
#    'rote',
#    'rooting',
#    'romanticcomedy',
#    'romanek',
#    'roberto',
#    'road',
#    'ritchie',
#    'ripoff',
#    'ridiculous',
#    'rhythms',
#    'rhythm',
#    'rhetoric',
#    'rewritten',
#    'return',
#    'retread',
#    'retooling',
#    'rest',
#    'resolutely',
#    'resentment',
#    'rescue',
#    'reputation',
#    'repulsive',
#    'reportedly',
#    'repetitive',
#    'repeated',
#    'rent',
#    'remotely',
#    'remember',
#    'relic',
#    'relationship',
#    'reign',
#    'regrets',
#    'reeks',
#    'redundancy',
#    'redundancies',
#    'recovering',
#    'reason',
#    'reams',
#    'rank',
#    'ramblings',
#    'rambling',
#    'rally',
#    'raise',
#    'quickly',
#    'questionable',
#    'quest',
#    'pushes',
#    'push',
#    'purposes',
#    'punk',
#    'pump',
#    'pulse',
#    'pulpy',
#    'pulled',
#    'puddle',
#    'proving',
#    'proved',
#    'protestors',
#    'promised',
#    'prom',
#    'progression',
#    'program',
#    'product',
#    'producers',
#    'produce',
#    'proceeds',
#    'proceedings',
#    'problems',
#    'prince',
#    'primitive',
#    'pretentious',
#    'pretends',
#    'presented',
#    'prejudice',
#    'precredit',
#    'precious',
#    'potter',
#    'potentially',
#    'pot',
#    'possibly',
#    'posing',
#    'pore',
#    'poor',
#    'pool',
#    'pomposity',
#    'politics',
#    'pointless',
#    'plotting',
#    'plotted',
#    'playstation',
#    'playdoh',
#    'plans',
#    'pitfalls',
#    'pink',
#    'pilot',
#    'piece',
#    'pick',
#    'phoneyfeeling',
# ...
#    'elsewhere',
#    'ungainly',
#    'hole',
#    'styles',
#    'pulled',
#    'hated',
#    'reallife',
#    'needless',
#    'comprehend',
#    'responsible',
#    'more',
#    'spliced',
#    'moralistic',
#    'inevitable',
#    'year',
#    'edge',
#    'blood',
#    'childlike',
#    'actually',
#    'some',
#    'stare',
#    'unnecessary',
#    'set',
#    'neither',
#    'hamfisted',
#    'handy',
#    'graceless',
#    'mistaken',
#    'downbeat',
#    'poorly',
#    'synergistic',
#    'commiserating',
#    'everyone',
#    'lacks',
#    'girl',
#    'quite',
#    'better',
#    'exhibitionism',
#    'begins',
#    'stalking',
#    'guy',
#    'backdrops',
#    'potter',
#    'various',
#    'oldfashioned',
#    'covered',
#    'seller',
#    'interesting',
#    'vampire',
#    'relentlessly',
#    'italian',
#    'old',
#    'plot',
#    'promising',
#    'sign',
#    'soap',
#    'watching',
#    'strong',
#    'deaths',
#    'going',
#    'terror',
#    'cares',
#    'slice',
#    'cloaks',
#    'impact',
#    'need',
#    'than',
#    'very',
#    'you',
#    'argentine',
#    'recycled',
#    'overly',
#    'clunky',
#    'vacant',
#    'proved',
#    'chan',
#    'earlier',
#    'secret',
#    'effort',
#    'station',
#    'best',
#    'dupe',
#    'sight',
#    'choke',
#    'late',
#    'face',
#    'casting',
#    'happened',
#    'daytime',
#    'inadvertent',
#    'potentially',
#    'endearing',
#    'within',
#    'viewer',
#    'filmmaking',
#    'ill',
#    'imitation',
#    'pump',
#    'critiquing',
#    'bludgeoning',
#    'pot',
#    'marvelous',
#    'glib',
#    'hold',
#    'hallucinogenic',
#    'them',
#    'pore',
#    'such',
#    'had',
#    'leaky',
#    'complete',
#    'reason',
#    'believability',
#    'fire',
#    'swear',
#    'simply',
#    'sheer',
#    'believe',
#    'obnoxious',
#    'romance',
#    'sudden',
#    'death',
#    'send',
#    'although',
#    'insult',
#    'inside',
#    'contrived',
#    'unpleasant',
#    'nobody',
#    'assassin',
#    'what',
#    'along',
#    'special',
#    'great',
#    'storytelling',
#    'cheesiest',
#    'well',
#    'beach',
#    'action',
#    'incessant',
#    'resonance',
#    'lump',
#    'bland',
#    'bitter',
#    'possibilities',
#    'villainess',
#    'repulsive',
#    'standoffish',
#    'sides',
#    'instantly',
#    'empathy',
#    'otherwise',
#    'retooling',
#    'phones',
#    'uncinematic',
#    'reign',
#    'determined',
#    'adaptation',
#    'close',
#    'they',
#    'entirely',
#    'highways',
#    'unfortunately',
#    'produce',
#    'banal',
#    'care',
#    'many',
#    'tripe',
#    'ticket',
#    'bits',
#    'brooding',
#    'kiss',
#    'however',
#    'equally',
#    'picture',
#    'come',
#    'accent',
#    'stale',
#    'pick',
#    'never',
#    'here',
#    'college',
#    'charisma',
#    'bright',
#    'heist',
#    'straddles',
#    'abuse',
#    'duplicate',
#    'quirky',
#    'his',
#    'expense',
#    'hackneyed',
#    'joke',
#    'together',
#    'cue',
#    'afterschool',
#    'featuring',
#    'pushes',
#    'goofy',
#    'allows',
#    'rest',
#    'setups',
#    'adopt',
#    'prom',
#    'babies',
#    'week',
#    'sure',
#    'dismiss',
#    'body',
#    'saying',
#    'motifs',
#    'foolish',
#    'us',
#    'particularly',
#    'push',
#    'apparent',
#    'irritating',
#    'subjects',
#    'punk',
#    'there',
#    'memory',
#    'mankind',
#    'emulates',
#    'often',
#    'junk',
#    'moral',
#    'any',
#    'are',
#    'drugs',
#    'creeping',
#    'landing',
#    'insurance',
#    'fails',
#    'exploit',
#    'ducts',
#    'exasperated',
#    'wasting',
#    'life',
#    'delivered',
#    'decay',
#    'made',
#    'business',
#    'phony',
#    'tear',
#    'maudlin',
#    'meat',
#    'unfortunate',
#    'simpering',
#    'supposed',
#    'behavior',
#    'begin',
#    'canadian',
#    'attract',
#    'mistress',
#    'naturalistic',
#    'hundred',
#    'sustain',
#    'real',
#    'crass',
#    'badly',
#    'entire',
#    'hollow',
#    'historical',
#    'cliches',
#    'rhythms',
#    'dreams',
#    'team',
#    'stuff',
#    'your',
#    'tale',
#    'murderer',
#    'thrills',
#    'possible',
#    'stories',
#    'interplay',
#    'soliloquies',
#    'teens',
#    'contest',
#    'quirks',
#    'longwinded',
#    'girlish',
#    'squeeze',
#    'mugging',
#    'analysis',
#    'screen',
#    'captions',
#    'choose',
#    'can',
#    'humanity',
#    'smart',
#    'big',
#    'deliver',
#    'involving',
#    'myself',
#    'taxicab',
#    'chemistry',
#    'go',
#    'brutally',
#    'broad',
#    'arbitrarily',
#    'emotionally',
#    'durable',
#    'ones',
#    'tricks',
#    'actress',
#    'much',
#    'sketchiest',
#    'else',
#    'redundancies',
#    'wrists',
#    'own',
#    'command',
#    'promised',
#    'painfully',
#    'egregious',
#    'stilted',
#    'stores',
#    'finds',
#    'indication',
#    'particular',
#    'ingredients',
#    'rich',
#    'baked',
#    'even',
#    'stagy',
#    'dealing',
#    'dragonfly',
#    'eyes',
#    'crush',
#    'precious',
#    'imagine',
#    'turns',
#    'passion',
#    'tiniest',
#    'truth',
#    'flaw',
#    'formulaic',
#    'grinds',
#    'stereotypical',
#    'realism',
#    'survive',
#    'soundtrack',
#    'goes',
#    'pretends',
#    'fun',
#    'frustration',
#    'damage',
#    'reeks',
#    'rent',
#    'energy',
#    'acid',
#    'western',
#    'hand',
#    'he',
#    'ring',
#    'performances',
#    'segment',
#    'likable',
#    'pastiche',
#    ...],
#   'ccw': ['forgettable',
#    'series',
#    'lack',
#    'flat',
#    'before',
#    'combined',
#    'run',
#    'four',
#    'despite',
#    'worst',
#    'limp',
#    'effects',
#    'stupid',
#    'total',
#    'predictable',
#    'shallow',
#    'wilde',
#    'bit',
#    'eight',
#    'drew',
#    'too',
#    'murphy',
#    'crazy',
#    'wasted',
#    'low',
#    'hate',
#    'five',
#    'home',
#    'tired',
#    'dumb',
#    'plodding',
#    'onto',
#    'commercial',
#    'trying',
#    'starts',
#    'martha',
#    'tries',
#    'listless',
#    'period',
#    'simpleminded',
#    'bother',
#    'harry',
#    'terrible',
#    'ac',
#    'jk',
#    'duds',
#    'hoffman',
#    'similar',
#    'know',
#    'silly',
#    'whatsoever',
#    'defeated',
#    'confused',
#    'promisingly',
#    'loose',
#    'numbers',
#    'violent',
#    'bad',
#    'raw',
#    'foul',
#    'fahrenheit',
#    'typical',
#    'boring',
#    'ugh',
#    'situations',
#    'yielded',
#    'cheap',
#    'worse',
#    'editing',
#    'snl',
#    'artificial',
#    'shrek',
#    'deja',
#    'amy',
#    'hewitt',
#    'olivier',
#    'tommy',
#    'ivan',
#    'hal',
#    'm',
#    'hopkins',
#    'sluggish',
#    'roberto',
#    'yard',
#    'inconsistent',
#    'playstation',
#    'mira',
#    'bottom',
#    'matthew',
#    'uncommitted',
#    'unbelievable',
#    'eddie',
#    'line',
#    'except',
#    'kills',
#    'loss',
#    'span',
#    'questionable',
#    'yes',
#    'muy',
#    'mitch',
#    'madonna',
#    'jfk',
#    'stifles',
#    'mild',
#    'edward',
#    'pointless',
#    'stewart',
#    'insultingly',
#    'misfire',
#    'ms',
#    'ritchie',
#    'enigma',
#    'credit',
#    'edit',
#    'hey',
#    'disappointingly',
#    'loco',
#    'christmas',
#    'left',
#    'elizabeth',
#    'lots',
#    'on',
#    'insignificant',
#    'flop',
#    'ending',
#    'irrelevant',
#    'wait',
#    'vu',
#    'desperate',
#    'scalds',
#    'poor',
#    'cold',
#    'inexcusable',
#    'bounces',
#    'hmmm',
#    'lost',
#    'fax',
#    'davis',
#    'lame',
#    'unconvincing',
#    'john',
#    'mostly',
#    'activate',
#    'round',
#    'shoot',
#    'equation',
#    'harsh',
#    'ugly',
#    'serviceability',
#    'stinks',
#    'strained',
#    'blanks',
#    'regrets',
#    'near',
#    'unfulfilling',
#    'labored',
#    'sinks',
#    'criticizing',
#    'return',
#    'hero',
#    'fraction',
#    'guess',
#    'rally',
#    'judd',
#    'away',
#    'rooting',
#    'mean',
#    'sneaky',
#    'blame',
#    'knock',
#    'beyond',
#    'freezers',
#    'intentionally',
#    'eleven',
#    'london',
#    'remember',
#    'conspiracy',
#    'wore',
#    'lousy',
#    'ai',
#    'frustrating',
#    'waited',
#    'quest',
#    'dirty',
#    'elicit',
#    'ridiculous',
#    'inconsequential',
#    'awfully',
#    'faltering',
#    'flops',
#    'longest',
#    'glimmer',
#    'grounding',
#    'moron',
#    'disjointed',
#    'clue',
#    'nights',
#    'treatment',
#    'stupefying',
#    'unleashes',
#    'insulting',
#    'hammers',
#    'stealing',
#    'guilty',
#    'either',
#    'agent',
#    'exception',
#    'followed',
#    'recovering',
#    'collateral',
#    'disgusting',
#    'suffers',
#    'dey',
#    'crossed',
#    'awkwardly',
#    'nuts',
#    'bound',
#    'mildly',
#    'repeated',
#    'instead',
#    'murky',
#    'wobbly',
#    'cliche',
#    'deadly',
#    'onehour',
#    'arbitrary',
#    'defined',
#    'incredibly',
#    'hour',
#    'amok',
#    'denial',
#    'cell',
#    'warmed',
#    'endings',
#    'terribly',
#    'york',
#    'overused',
#    'hurley',
#    'sketchy',
#    'oprah',
#    'depressing',
#    'waiting',
#    'endurance',
#    'tried',
#    'ordinary',
#    'exactly',
#    'clash',
#    'section',
#    'deserve',
#    'wearisome',
#    'equations',
#    'pink',
#    'sympathy',
#    'box',
#    'road',
#    'hurry',
#    'failure',
#    'phone',
#    'matrix',
#    'vehicle',
#    'easy',
#    'water',
#    'loads',
#    'resolutely',
#    'hours',
#    'devoid',
#    'repetitive',
#    'messenger',
#    'misery',
#    'noticeable',
#    'purposes',
#    'gamut',
#    'faster',
#    'snow',
#    'franchise',
#    'rank',
#    'enjoy',
#    'lick',
#    'passe',
#    'biscuit',
#    'meanspirited',
#    'arty',
#    'underestimated',
#    'crossroads',
#    'cliché',
#    'grab',
#    'ignore',
#    'break',
#    'awe',
#    'beneath',
#    'overlong'],
#   'scw': ['score',
#    'half',
#    'minutes',
#    'three',
#    'sandra',
#    'third',
#    'i',
#    'joel',
#    'pace',
#    'just',
#    'two',
#    'final',
#    'robert',
#    'only',
#    'saturday',
#    'got',
#    'from',
#    'down',
#    'missing',
#    'in',
#    'shot',
#    'balance',
#    'pathetic',
#    'decent',
#    'target',
#    'first',
#    'hugh',
#    'while',
#    'midnight',
#    'sequence',
#    'spectacular',
#    'mark',
#    'cute',
#    'rare',
#    'then',
#    'up',
#    'almost',
#    'play',
#    'without',
#    'tom',
#    'blue',
#    'with',
#    'about',
#    'pale',
#    'excellent',
#    'last',
#    'full',
#    'good',
#    'ca',
#    'little',
#    'mr',
#    'really',
#    'lee',
#    'crimes',
#    'fans',
#    'keep',
#    'attempt',
#    'oscar',
#    'pretty',
#    'offer',
#    'night',
#    'think',
#    'look',
#    'looking',
#    'their',
#    'scary',
#    'trouble',
#    'career',
#    'offers',
#    'dark',
#    'prison',
#    'largely',
#    'anything',
#    'cut',
#    'performance',
#    've',
#    'far',
#    'sentimental',
#    'seen',
#    'right',
#    'girlfriend',
#    'usually',
#    'american',
#    'word',
#    'murder',
#    'uses',
#    'wrong',
#    'watch',
#    'over',
#    'killed',
#    'somewhat',
#    'across',
#    'length',
#    'words',
#    'cinematography',
#    'thriller',
#    'found',
#    'term'],
#   'fcw': ['familiar',
#    'loud',
#    'becomes',
#    'slimed',
#    'to',
#    'gags',
#    'opera',
#    'sit',
#    'merit',
#    'ego',
#    'hasbeen',
#    'pomposity',
#    'booths',
#    'appears',
#    'hastily',
#    'highly',
#    'pieces',
#    'money',
#    'reality',
#    'name',
#    'that',
#    'forces',
#    'names',
#    'absurdity',
#    'already',
#    'assembled',
#    'country',
#    'dubbed',
#    'sort',
#    'bravado',
#    'famed',
#    'toilethumor',
#    'rowling',
#    'hartley',
#    'firstrate',
#    'snore',
#    'swill',
#    'perhaps',
#    'ideas',
#    'selfconscious',
#    'funnier',
#    'material',
#    'efforts',
#    'important',
#    'ears',
#    'overbearing',
#    'compendium',
#    'former',
#    'ought',
#    'busy',
#    'reputation',
#    'unnamed',
#    'gentlemen',
#    'chatter',
#    'sanctimony',
#    'chamber',
#    'forcefully',
#    'mouthpieces',
#    'as',
#    'legendary',
#    'cadavers',
#    'elements',
#    'brash',
#    'soon',
#    'parking',
#    'ambition',
#    'party',
#    'concoctions',
#    'disintegrates',
#    'disintegrating',
#    'serve',
#    'protestors',
#    'approached',
#    'the',
#    'of',
#    'wedgie',
#    'shtick',
#    'national',
#    'unwieldy',
#    'breasts',
#    'decorating',
#    'ship',
#    'appointed',
#    'law',
#    'boardwalk',
#    'fellow',
#    'satire',
#    'reams',
#    'demented',
#    'anticipation',
#    'ambitious',
#    'program',
#    'list',
#    'bears',
#    'buzz',
#    'guide',
#    'irreparable',
#    'spend',
#    'contraption',
#    'events',
#    'antifeminist',
#    'intrusive',
#    'labors',
#    'hokum',
#    'indoctrinated',
#    'anger',
#    'distracting',
#    'comedian',
#    'where',
#    'thoughtlessly',
#    'possibly',
#    'biopic',
#    'she',
#    'episode',
#    'caper',
#    'channeling',
#    'heavyweights',
#    'impulse',
#    'abiding',
#    'signpost',
#    'subplots',
#    'imagery',
#    'theater',
#    'engage',
#    'endeavors',
#    'ease',
#    'presented',
#    'agenda',
#    'said',
#    'scripts',
#    'frightfest',
#    'resentment',
#    'ugliness',
#    'handle',
#    'harm',
#    'cocktail',
#    'stains',
#    'tendentious',
#    'pulpy',
#    'sentiment',
#    'intervention',
#    'stuffy',
#    'dentist',
#    'aesthetic',
#    'sitcom',
#    'brain',
#    'successor',
#    'piece',
#    'parrots',
#    'happens',
#    'remotely',
#    'zemeckis',
#    'writerproducerdirector',
#    'writerdirector',
#    'wellacted',
#    'warmovie',
#    'underrehearsed',
#    'uglylooking',
#    'twentyfourandunders',
#    'tvmovie',
#    'tvinsider',
#    'tornatore',
#    'tooconscientious',
#    'throwntogether',
#    'thirtys',
#    'thirdperson',
#    'thecash',
#    'tenyear',
#    'teensleaze',
#    'teendriven',
#    'techgeeks',
#    'swordandsorcery',
#    'summercamp',
#    'sugarman',
#    'stopandstart',
#    'soontobeforgettable',
#    'snaillike',
#    'slomo',
#    'slc',
#    'sixtys',
#    'sillified',
#    'silbersteins',
#    'selfindulgent',
#    'selfimportant',
#    'selfconsciously',
#    'selfcongratulation',
#    'selfawareness',
#    'rubbo',
#    'romanticcomedy',
#    'romanek',
#    'precredit',
#    'playdoh',
#    'phoneyfeeling',
#    'periodperfect',
#    'pasolini',
#    'overlyfamiliar',
#    'outbadact',
#    'nowcliched',
#    'notsofunny',
#    'nosurprise',
#    'ninetyfiveminute',
#    'newagey',
#    'marivaux',
#    'lugosi',
#    'lowerclass',
#    'lipnonsynching',
#    'liman',
#    'lifeatarm',
#    'leblanc',
#    'kathie',
#    'italicizes',
#    'industrialmodel',
#    'imponderably',
#    'imagemongering',
#    'illfitting',
#    'hatinhand',
#    'halfstep',
#    'halfbaked',
#    'halfassed',
#    'godard',
#    'gifford',
#    'gangstercrime',
#    'fourthrate',
#    'fortys',
#    'fortyeight',
#    'fiftyone',
#    'fiftyfive',
#    'eightyearold',
#    'eastwood',
#    'dumbeddown',
#    'doublepistoled',
#    'doingitfor',
#    'deniro',
#    'deathdefying',
#    'cellophanepop',
#    'caddyshack',
#    'bythenumbers',
#    'bruckheimeresque',
#    'benigni',
#    'barrymore',
#    'barnburningly',
#    'ballisticpyrotechnic',
#    'anticatholic',
#    'agesold',
#    'narcissism',
#    'advised',
#    'stolid',
#    'invention',
#    'company',
#    'ramblings',
#    'improvised',
#    'producers',
#    'person',
#    'scientific',
#    'drivel',
#    'coherent',
#    'hardsell',
#    'castrated',
#    'treading',
#    'noisy',
#    'spiritual',
#    'thematic',
#    'devolves',
#    'conquer',
#    'choices',
#    'cathartic',
#    'structure',
#    'authentic',
#    'message',
#    'performing',
#    'secrets',
#    'overplayed',
#    'heed',
#    'artifice',
#    'overworked',
#    'grand',
#    'kitsch',
#    'sadly',
#    'usher',
#    'details',
#    'cheesier',
#    'spoof',
#    'desire',
#    'accompanied',
#    'ladies',
#    'dates',
#    'proceedings',
#    'innovation',
#    'demographic',
#    'prejudice',
#    'pitfalls',
#    'tearing',
#    'exploitation',
#    'ensues',
#    'proceeds',
#    'lionize',
#    'lectured'],
#   'iw': ['and',
#    'one',
#    'ennui',
#    'humor',
#    'work',
#    'most',
#    'world',
#    'independent',
#    'act',
#    'might',
#    'films',
#    'identity',
#    'drama',
#    'music',
#    'shrewd',
#    'once',
#    'who',
#    'ever',
#    'thoroughly',
#    'space',
#    'persona',
#    'undoubtedly',
#    'has',
#    'intelligence',
#    'scenes',
#    'elegantly',
#    'scene',
#    'may',
#    'an',
#    'part',
#    'working',
#    'this',
#    'new',
#    'engaging',
#    'directed',
#    'acting',
#    'shows',
#    'should',
#    'insight',
#    'premise',
#    'seems',
#    'done',
#    'attention',
#    'direction',
#    'also',
#    'was',
#    'makers',
#    'narrative',
#    'actors',
#    'could',
#    'family',
#    'itself',
#    'written',
#    'belly',
#    'created',
#    'young',
#    'sorvino',
#    'cast',
#    'documentary',
#    'addition',
#    'visual',
#    'reasonably',
#    'truly',
#    'suggests',
#    'her',
#    'male',
#    'intelligent',
#    'quality',
#    'by',
#    'makes',
#    'callow',
#    'twohourandfifteenminute',
#    'twentytwoyearold',
#    'spiritcrushing',
#    'selfsatisfied',
#    'partyhearty',
#    'eighteenyearold',
#    'assayas',
#    'our',
#    'worked',
#    'help',
#    'filmmakers',
#    'raised',
#    'movie',
#    'easily',
#    'kong',
#    'grant',
#    'comic',
#    'bible',
#    'make',
#    'budget',
#    'performers',
#    'tragic',
#    'audience',
#    'directors',
#    'approach',
#    'take',
#    'saccharine',
#    'women',
#    'tribute',
#    'structured',
#    'wit',
#    'comedy']}}

# %%
punc_list = [w for w in ',.，。!?！？;；、']

# %%
for key in global_kws_dict:
    print(key)
# Out:
# 1
# 0

# %%
for key in global_kws_dict:
    print(key)
    kws = global_kws_dict[key]
    print(' '.join(TA.aug_by_deletion(sentence, p, 'selective', print_info=True,
                    selected_words=kws['scw']+kws['fcw']+kws['iw'])))  # except ccw
    print(' '.join(TA.aug_by_replacement(sentence, p, 'selective', print_info=True,
                    selected_words=kws['scw']+kws['fcw']+kws['iw'])))  # except ccw
    print(' '.join(TA.aug_by_insertion(sentence, p, 'selective', print_info=True,
                    selected_words=kws['ccw']+kws['scw']+kws['iw'])))  # except ccw
    print(' '.join(TA.aug_by_selection(sentence, print_info=True,
                        selected_words=kws['ccw']+punc_list)))
# Out:
# 1
# deletion info: ['charming']
# klein in comedies like american pie and deadon in election
# replacement info: [('charming', 'wizardly')]
# klein wizardly in comedies like american pie and deadon in election
# insertion info: [('pie', 'PIE')]
# klein charming in comedies like american pie and deadon in PIE election
# selection info: pie
# selection info: and
# selection info: deadon
# pie and deadon
# 0
# deletion info: ['in']
# klein charming comedies like american pie and deadon in election
# replacement info: [('american', 'American')]
# klein charming in comedies like American pie and deadon in election
# insertion info: [('in', 'inch')]
# klein inch charming in comedies like american pie and deadon in election
