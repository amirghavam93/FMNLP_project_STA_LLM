# %% [markdown]
# # Imports

# %%
# !pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (0.26.1)
# Requirement already satisfied: numpy>=1.17 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (5.4.1)
# Requirement already satisfied: torch>=1.10.0 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (1.12.1)
# Requirement already satisfied: huggingface-hub in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (0.20.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from accelerate) (0.4.2)
# Requirement already satisfied: typing-extensions in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.10.0->accelerate) (4.6.3)
# Requirement already satisfied: filelock in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (2023.10.0)
# Requirement already satisfied: requests in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (2.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub->accelerate) (4.64.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/amirghavam/opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub->accelerate) (2022.12.7)

# %%
import numpy as np
import pandas as pd
import pickle
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/amirghavam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/amirghavam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/amirghavam/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from sklearn.metrics import accuracy_score
from keywords_extractor import KeywordsExtractor
from augmenter import TextAugmenter
import math

# %%
KE = KeywordsExtractor(lang='en')
# Out:
# Language: English
# Loading word vectors......

# %%
data = pd.read_csv('data/newsgroups/newsgroups_1000.csv')
data = data.dropna()
contents = list(data['text'])
labels = [str(label) for label in data['label']]

# %%
# extract keywords
kws_dict = KE.global_role_kws_extraction_one_line(contents, labels, output_dir='saved_keywords',name='newsgroups')
kws_dict.keys()
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 1368.84it/s]
# 100%|██████████| 2688/2688 [03:57<00:00, 11.33it/s]
# 100%|██████████| 2839/2839 [03:53<00:00, 12.18it/s]
# 100%|██████████| 4206/4206 [05:44<00:00, 12.21it/s]
# 100%|██████████| 2517/2517 [03:32<00:00, 11.84it/s]
# 100%|██████████| 2637/2637 [03:49<00:00, 11.50it/s]
# 100%|██████████| 3906/3906 [05:10<00:00, 12.56it/s]
# 100%|██████████| 3082/3082 [04:19<00:00, 11.85it/s]
# 100%|██████████| 2384/2384 [03:18<00:00, 12.02it/s]
# 100%|██████████| 3899/3899 [05:01<00:00, 12.95it/s]
# 100%|██████████| 2475/2475 [03:25<00:00, 12.04it/s]
# 100%|██████████| 3363/3363 [04:39<00:00, 12.02it/s]
# 100%|██████████| 3175/3175 [04:11<00:00, 12.64it/s]
# 100%|██████████| 2598/2598 [03:22<00:00, 12.81it/s]
# 100%|██████████| 2779/2779 [03:33<00:00, 13.00it/s]
# 100%|██████████| 3215/3215 [04:55<00:00, 10.86it/s]
# 100%|██████████| 3745/3745 [05:18<00:00, 11.78it/s]
# 100%|██████████| 5172/5172 [06:37<00:00, 13.01it/s]
# 100%|██████████| 3513/3513 [05:23<00:00, 10.84it/s]
# 100%|██████████| 1948/1948 [02:44<00:00, 11.87it/s]
# 100%|██████████| 3549/3549 [04:27<00:00, 13.26it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 1189.75it/s]
# First level keys:  ['rec.sport.hockey', 'rec.sport.baseball', 'talk.politics.mideast', 'comp.sys.ibm.pc.hardware', 'misc.forsale', 'sci.med', 'sci.electronics', 'comp.sys.mac.hardware', 'talk.politics.guns', 'rec.motorcycles', 'rec.autos', 'sci.crypt', 'talk.religion.misc', 'alt.atheism', 'comp.os.ms-windows.misc', 'sci.space', 'talk.politics.misc', 'comp.windows.x', 'comp.graphics', 'soc.religion.christian']
# Second level keys:  ['lr', 'ls', 'ccw', 'scw', 'fcw', 'iw']
# already saved at saved_keywords/global_kws_dict_newsgroups.pkl
# dict_keys(['global_ls', 'global_lr', 'global_roles'])

# %%
for key in kws_dict['global_roles']:
    print(f"keywords for \"{key}\":")
    for each in ['ccw','scw','fcw','iw']:
        print(f"{each}: {kws_dict['global_roles'][key][each][:10]}")
# Out:
# keywords for "rec.sport.hockey":
# ccw: ['olchowy', 'golchowyalchemychemutorontoca', 'terresterial', 'stplistsca', 'smythe', 'recsporthockey', 'lindros', 'dchhabrastplistsca', 'wfan', 'weedville']
# scw: ['a', 'and', 'nntppostinghost', 'twentytwo', 'oneone', 'xnewsreader', 'thirtythree', 'twentyseven', 'thirtyfour', 'twentyeight']
# fcw: ['nhl', 'pens', 'playoff', 'flyers', 'leafs', 'penguins', 'islanders', 'norris', 'canadiens', 'maple']
# iw: ['i', 'thanx', 'ltd', 'distribution', 'ken', 'w', 'lee', 'na', 'bob', 'jim']
# keywords for "rec.sport.baseball":
# ccw: ['alomar', 'tedwardcscornelledu', 'threeb', 'slg', 'sandberg', 'carew', 'yount', 'wetteland', 'vbthirtylafibmlafayetteedu', 'vbthirty']
# scw: ['a', 'twentytwo', 'thirtythree', 'of', 'fiftysix', 'eightyfour', 'thirtyone', 'thirtysix', 'seventythree', 'eightythree']
# fcw: ['pitching', 'cubs', 'phillies', 'rbis', 'dl', 'rbi', 'obp', 'hitters', 'dodgers', 'clemens']
# iw: ['k', 'apr', 'email', 'w', 'lee', 'stephen', 'ma', 'x', 'anderson', 'keywords']
# keywords for "talk.politics.mideast":
# ccw: ['serdar', 'argic', 'serazumauucp', 'sahak', 'ohanus', 'melkonian', 'livni', 'jakebonyonebonycom', 'israels', 'appressian']
# scw: ['nntppostinghost', 'the', 'to', 'and', 'oneone', 'fiftysix', 'fiftyfive', 'thirtyone', 'articleid', 'thirtysix']
# fcw: ['israeli', 'arab', 'arabs', 'villages', 'palestinians', 'gaza', 'occupation', 'israel', 'elias', 'proline']
# iw: ['i', 'k', 'email', 'distribution', 'wife', 'sweden', 'ken', 'usa', 'mother', 'ps']
# keywords for "comp.sys.ibm.pc.hardware":
# ccw: ['adaptec', 'irq', 'sixteenmb', 'sixteenbit', 'localbus', 'irqs', 'comtwo', 'comone', 'universite', 'twentymbs']
# scw: ['to', 'of', 'the', 'a', 'replyto', 'twentythree', 'thirtythree', 'twentyseven', 'thirtyfour', 'thirtyfive']
# fcw: ['orchid', 'vlb', 'spins', 'controller', 'reynolds', 'card', 'ks', 'analyst', 'cruces', 'asynchronous']
# iw: ['writes', 'urbana', 'twentysix', 'christian', 'na', 'w', 'usa', 'x', 'bob', 'etc']
# keywords for "misc.forsale":
# ccw: ['vhf', 'ultbgwiscritedu', 'uhf', 'foursale', 'fortyzero', 'fivetwentyfive', 'amfm', 'adaptor', 'zoronenecnpurdueedu', 'zeos']
# scw: ['a', 'to', 'the', 'of', 'replyto', 'ninetythree', 'twentythree', 'oneone', 'xnewsreader', 'ninetytwo']
# fcw: ['obo', 'forsale', 'accessories', 'cassette', 'cincinnati', 'cod', 'email', 'wj', 'bo', 'rit']
# iw: ['i', 'writes', 'k', 'md', 'ltd', 'apr', 'wife', 'yous', 'twentysix', 'jim']
# keywords for "sci.med":
# ccw: ['nthreejxp', 'gebcspittedu', 'gebcadredslpittedu', 'pittnineteen', 'mitchum', 'ninetysixtwo', 'kmcspittedu', 'windbellcorecom', 'wellconserved', 'wcsbeauccscarletonca']
# scw: ['nntppostinghost', 'a', 'ninetythree', 'xnewsreader', 'thirtythree', 'thirtyseven', 'thirtytwo', 'fortytwo', 'oneone', 'inreplyto']
# fcw: ['chastity', 'intellect', 'genes', 'allergic', 'dna', 'syndrome', 'seizures', 'taste', 'disorder', 'ert']
# iw: ['email', 'jr', 'apr', 'yous', 'bc', 'jim', 'usa', 'twentysix', 'keywords', 'lee']
# keywords for "sci.electronics":
# ccw: ['whitmore', 'whitcarsonyouwashingtonedu', 'wtmuhuraneoucomedu', 'vanderbymprgatemprca', 'vanderbyl', 'tryndoch', 'swalkerutseduau', 'seventysevenswalkermanfifty', 'seightyseven', 'pwm']
# scw: ['replyto', 'ninetythree', 'twentyfour', 'twentytwo', 'twentyseven', 'thirtytwo', 'twentyeight', 'eightysix', 'fiftyfive', 'inreplyto']
# fcw: ['volt', 'volts', 'ohm', 'amps', 'motors', 'transformer', 'ohms', 'dehydrator', 'emi', 'dehydrators']
# iw: ['writes', 'md', 'ltd', 'i', 'apr', 'christian', 'mike', 'author', 'jim', 'w']
# keywords for "comp.sys.mac.hardware":
# ccw: ['centris', 'csix', 'iisi', 'iici', 'vram', 'macuser', 'zodncubecom', 'zod', 'xxxmessageid', 'wagga']
# scw: ['of', 'and', 'replyto', 'to', 'nntppostinghost', 'twentytwo', 'twentythree', 'ninetythree', 'twentynine', 'oneone']
# fcw: ['powerbook', 'apple', 'mac', 'pram', 'terminators', 'ferch', 'lc', 'printers', 'sis', 'def']
# iw: ['md', 'writes', 'lee', 'jim', 'bob', 'ps', 'ma', 'x', 'keywords', 'hello']
# keywords for "talk.politics.guns":
# ccw: ['kratz', 'thirtysevenuicvmuicedu', 'nra', 'rkba', 'hambidgebmscom', 'dividian', 'batffbi', 'batf', 'parsli', 'fokes']
# scw: ['twentytwo', 'twentythree', 'oneone', 'thirtyseven', 'fiftysix', 'eightysix', 'thirtysix', 'sixtyone', 'ninetynine', 'fortyeight']
# fcw: ['firearms', 'handgun', 'waco', 'firearm', 'ranch', 'pistol', 'weaver', 'rifle', 'bd', 'handguns']
# iw: ['k', 'email', 'apr', 'urbana', 'twentysix', 'wed', 'mike', 'stephen', 'na', 'hi']
# keywords for "rec.motorcycles":
# ccw: ['egreeneastsuncom', 'countersteering', 'countersteeringfaq', 'behanna', 'zxeleven', 'xzfive', 'wbgfestivaledacuk', 'vmax', 'txdesdthreecomcom', 'sturdevant']
# scw: ['to', 'of', 'ninetythree', 'articleid', 'twentythree', 'thirtytwo', 'oneone', 'xnewsreader', 'twentyeight', 'fortyone']
# fcw: ['bike', 'bikes', 'yamaha', 'dod', 'ama', 'cruncher', 'quist', 'motorcycle', 'lad', 'mjs']
# iw: ['apr', 'ltd', 'email', 'twentysix', 'lee', 'bob', 'ps', 'stephen', 'ma', 'john']
# keywords for "rec.autos":
# ccw: ['recautos', 'warningplease', 'callison', 'callisonuokmaxecnuoknoredu', 'wratunisqluucp', 'vsix', 'twentywfifty', 'twentyfivek', 'triuniversity', 'triumf']
# scw: ['of', 'replyto', 'thirtytwo', 'fortythree', 'thirtyfive', 'thirtyseven', 'oneone', 'twentyfour', 'fortytwo', 'thirtyeight']
# fcw: ['car', 'sho', 'subaru', 'gs', 'sporty', 'vw', 'mustang', 'transmissions', 'integra', 'bugs']
# iw: ['apr', 'twentysix', 'yous', 'email', 'urbana', 'bc', 'jim', 'mike', 'na', 'ps']
# keywords for "sci.crypt":
# ccw: ['scicrypt', 'qas', 'templeton', 'strnlghtnetcomcom', 'stevebaccessdigexcom', 'sternlight', 'rsa', 'ripem', 'ninetysixthree', 'keyescrow']
# scw: ['and', 'ninetythree', 'twentyfour', 'replyto', 'articleid', 'thirtythree', 'thirtyfive', 'twentyeight', 'thirtyseven', 'fortyfour']
# fcw: ['clipper', 'encryption', 'encrypted', 'crypto', 'cryptography', 'escrow', 'encrypt', 'carr', 'passwords', 'morrison']
# iw: ['k', 'apr', 'email', 'allan', 'w', 'jim', 'mike', 'ken', 'mother', 'x']
# keywords for "talk.religion.misc":
# ccw: ['mleepostroyalroadsca', 'twentyninetwentythree', 'thirtythreemnemosynecsduedu', 'talkabortion', 'roycrbdcwsncorg', 'prolifer', 'ninetythreeaprfifteenten', 'kevinrotagmiorg', 'kcochrannyxcsduedu', 'fortyfivezawutarlgutaedu']
# scw: ['and', 'ninetythree', 'twentyfour', 'twentythree', 'replyto', 'oneone', 'thirtyone', 'thirtyfour', 'thirtyfive', 'nntppostinghost']
# fcw: ['sermon', 'christian', 'darcy', 'slimy', 'christianity', 'remeber', 'homophobes', 'creationism', 'cor', 'mormons']
# iw: ['apr', 'email', 'md', 'yous', 'w', 'na', 'etc', 'keywords', 'twentyone', 'ken']
# keywords for "alt.atheism":
# ccw: ['keithccocaltechedu', 'livesey', 'bobbeviceicotekcom', 'beauchaine', 'snmsix', 'rosenau', 'ninetyfourultbiscritedu', 'mozumder', 'liveseysolntzewpdsgicom', 'benedikt']
# scw: ['replyto', 'nntppostinghost', 'articleid', 'thirtyone', 'twentyfour', 'thirtyseven', 'fortyfour', 'fiftysix', 'seventyfive', 'thirtysix']
# fcw: ['schneider', 'sn', 'bronx', 'chimps', 'allan', 'manhattan', 'koff', 'theism', 'charley', 'mom']
# iw: ['w', 'urbana', 'keywords', 'usa', 'roy', 'ken', 'fax', 'hello', 'john', 'david']
# keywords for "comp.os.ms-windows.misc":
# ccw: ['winthreeone', 'ftpcicaindianaedu', 'threeone', 'wfourwg', 'wfourw', 'uuencoded', 'twoafortytwodubinskivmscsdmuedu', 'twentyfourx', 'truetype', 'speedstar']
# scw: ['of', 'twentythree', 'a', 'twentyeight', 'fortyfour', 'seventyfive', 'inreplyto', 'fiftyone', 'sixtyone', 'seventythree']
# fcw: ['windows', 'dir', 'dos', 'aliases', 'idealistic', 'robb', 'stevenson', 'file', 'bmp', 'files']
# iw: ['writes', 'md', 'cd', 'apr', 'urbana', 'twentysix', 'author', 'keywords', 'bob', 'hd']
# keywords for "sci.space":
# ccw: ['nsmcaauroraalaskaedu', 'henryzootorontoedu', 'sherzer', 'nasas', 'jpl', 'higginsfnalffnalgov', 'fraering', 'dcx', 'baalkekelvinjplnasagov', 'baalke']
# scw: ['nntppostinghost', 'the', 'thirtytwo', 'xnewsreader', 'ninetytwo', 'fortytwo', 'fiftyfive', 'sixtysix', 'sixtyfive', 'seventythree']
# fcw: ['orbit', 'comet', 'spacecraft', 'jupiter', 'jockey', 'payload', 'edwards', 'geniuses', 'payloads', 'venus']
# iw: ['md', 'mellon', 'urbana', 'email', 'twentysix', 'author', 'stephen', 'na', 'hd', 'bob']
# keywords for "talk.politics.misc":
# ccw: ['kaldis', 'crameroptilinkcom', 'petaluma', 'optilink', 'uunetpyramidoptilinkcramer', 'libwcaemoryedu', 'kaldisromulusrutgersedu', 'hennessy', 'clintongore', 'scharfy']
# scw: ['replyto', 'twentyfour', 'nntppostinghost', 'thirtytwo', 'twentyseven', 'thirtyfour', 'twentyeight', 'fiftysix', 'fiftyfive', 'twentynine']
# fcw: ['marines', 'rati', 'herbert', 'cuba', 'miniskirt', 'underwear', 'passions', 'willies', 'economies', 'discrimination']
# iw: ['email', 'md', 'myers', 'russ', 'jr', 'ltd', 'apr', 'wife', 'urbana', 'gerald']
# keywords for "comp.windows.x":
# ccw: ['xelevenrfive', 'enterpoopmitedu', 'xpertexpolcsmitedu', 'xdm', 'openlook', 'ncd', 'mwm', 'athena', 'xterminals', 'xsession']
# scw: ['of', 'and', 'twentyfour', 'the', 'thirtyone', 'thirtyfour', 'twentythree', 'eightyfour', 'thirtyeight', 'seventythree']
# fcw: ['xlib', 'widget', 'xterm', 'widgets', 'x', 'client', 'toolkits', 'contrib', 'mits', 'vue']
# iw: ['writes', 'md', 'jr', 'mellon', 'apr', 'jim', 'lee', 'stephen', 'bob', 'mike']
# keywords for "comp.graphics":
# ccw: ['wuarchivewustledu', 'utrecht', 'threedo', 'suncadcamosunbecauseca', 'situnayaibmthree', 'sevenorionoacuciedu', 'rumours', 'ninetybhamacuk', 'morleysuncadcamosunbecauseca', 'morleycamosunbecauseca']
# scw: ['of', 'and', 'a', 'ninetythree', 'the', 'to', 'articleid', 'thirtytwo', 'thirtyfive', 'thirtyseven']
# fcw: ['gif', 'dm', 'animations', 'tiff', 'graphics', 'illustrator', 'gupta', 'leonardo', 'nites', 'stu']
# iw: ['writes', 'apr', 'mike', 'na', 'bob', 'friend', 'usa', 'hello', 'scott', 'r']
# keywords for "soc.religion.christian":
# ccw: ['clh', 'jayne', 'kulikauskas', 'jodfishesilverucsindianaedu', 'jaynemmaltguildorg', 'whitsell', 'whitsebdnextworkrosehulmanedu', 'qumran', 'mielke', 'jekcunihgov']
# scw: ['twentyfour', 'thirtytwo', 'twentynine', 'oneone', 'thirtyone', 'ninetytwo', 'replyto', 'twentytwo', 'twentythree', 'twentyeight']
# fcw: ['righteousness', 'marys', 'christians', 'god', 'theology', 'kille', 'afterlife', 'jesus', 'romans', 'bible']
# iw: ['k', 'md', 'jr', 'urbana', 'gerald', 'twentysix', 'email', 'author', 'van', 'ken']

# %%
# Tokenize each sentence and compile into a single list
all_words = []
for sentence in contents:
    tokens = word_tokenize(sentence)
    all_words.extend(tokens)

# Optionally, you can convert the list to a set to remove duplicates
unique_words = set(all_words)

# %%
similar_words_dict = {}
for word in unique_words:
    synonyms = set()
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    similar_words_dict[word] = list(synonyms)

# %%
similar_words_dict
# Out:
# {'nonjewish': [],
#  'gdfive': [],
#  'belligerency': ['belligerence', 'hostilities', 'belligerency'],
#  'crown': ['crownwork',
#   'pate',
#   'pennant',
#   'peak',
#   'crown',
#   'poll',
#   'top',
#   'crest',
#   'summit',
#   'Crown',
#   'jacket',
#   'jacket_crown',
#   'cap',
#   'coronate',
#   'tip',
#   'diadem',
#   'treetop'],
#  'wolfson': [],
#  'vbthirty': [],
#  'monitor': ['admonisher',
#   'reminder',
#   'Monitor',
#   'proctor',
#   'supervise',
#   'monitor',
#   'varan',
#   'monitor_lizard',
#   'monitoring_device'],
#  'interview': ['consultation', 'question', 'audience', 'interview'],
#  'schrievers': [],
#  'sating': ['fill', 'sate', 'satiate', 'replete'],
#  'smkuslcom': [],
#  'mercifully': ['mercifully'],
#  'fixingpredating': [],
#  'implementation': ['carrying_out',
#   'effectuation',
#   'execution',
#   'implementation'],
#  'diary': ['journal', 'diary'],
#  'transgression': ['evildoing', 'transgression'],
#  'feature': ['feature_film',
#   'sport',
#   'feature_of_speech',
#   'feature',
#   'feature_article',
#   'boast',
#   'characteristic',
#   'lineament',
#   'have'],
#  'technique': ['proficiency', 'technique'],
#  'liner': ['ocean_liner', 'liner', 'line_drive', 'lining'],
#  'suranet': [],
#  'allegation': ['allegation', 'allegement'],
#  'observers': ['percipient',
#   'commentator',
#   'beholder',
#   'perceiver',
#   'observer'],
#  'intrinsic': ['intrinsic', 'intrinsical'],
#  'matt': ['lusterlessness',
#   'matted',
#   'lustrelessness',
#   'mat',
#   'matt',
#   'flatness',
#   'matte',
#   'flat'],
#  'pubpcwinthreeprogramr': [],
#  'heinlein': ['Heinlein', 'Robert_A._Heinlein', 'Robert_Anson_Heinlein'],
#  'supertrapp': [],
#  'dxftwelvepocwruedu': [],
#  'copayments': [],
#  'truck': ['truck', 'motortruck', 'hand_truck'],
#  'catalog': ['catalog', 'catalogue'],
#  'chart': ['graph', 'chart'],
#  'ninetyeightyeight': [],
#  'threefbfiftyonebsixwone': [],
#  'hajj': ['hajj', 'hadj', 'haj'],
#  'toolkit': [],
#  'ozal': [],
#  'weasels': ['weasel'],
#  'beezer': [],
#  'communizem': [],
#  'pediatrician': ['pediatrist',
#   'baby_doctor',
#   'paediatrician',
#   'pediatrician'],
#  'foreign': ['extraneous', 'alien', 'foreign', 'strange'],
#  'midjuly': [],
#  'brings': ['land',
#   'work',
#   'impart',
#   'lend',
#   'convey',
#   'wreak',
#   'institute',
#   'fetch',
#   'add',
#   'bring_in',
#   'contribute',
#   'get',
#   'play',
#   'bestow',
#   'take',
#   'bring',
#   'make_for'],
#  'vanbiesbroucks': [],
#  'relative': ['congeneric',
#   'congener',
#   'relation',
#   'comparative',
#   'proportional',
#   'congenator',
#   'relative'],
#  'infozip': [],
#  'yep': [],
#  'undisturbed': ['undisturbed'],
#  'sax': ['Adolphe_Sax', 'Sax', 'saxophone', 'sax'],
#  'quieter': ['subdued',
#   'muted',
#   'tranquil',
#   'smooth',
#   'placid',
#   'unruffled',
#   'quiet',
#   'still',
#   'hushed',
#   'restrained'],
#  'shoulda': [],
#  'sigh': ['suspire', 'suspiration', 'sigh'],
#  'riceburner': [],
#  'logout': [],
#  'seventythreethree': [],
#  'neoghbors': [],
#  'fourseventeen': [],
#  'fpccstructreturn': [],
#  'occasionally': ['on_occasion',
#   'now_and_then',
#   'at_times',
#   'occasionally',
#   'once_in_a_while',
#   'now_and_again',
#   'from_time_to_time'],
#  'conditioned': ['train',
#   'learned',
#   'in_condition',
#   'check',
#   'qualify',
#   'specify',
#   'conditioned',
#   'condition',
#   'discipline',
#   'stipulate'],
#  'info': ['info', 'information'],
#  'ubc': [],
#  'dish': ['dish_out',
#   'looker',
#   'mantrap',
#   'dishful',
#   'serve',
#   'dish',
#   'knockout',
#   'ravisher',
#   'saucer',
#   'dish_aerial',
#   'serve_up',
#   'dish_antenna',
#   'smasher',
#   'peach',
#   'lulu',
#   'dish_up',
#   'bag',
#   'beauty',
#   'sweetheart',
#   'stunner',
#   'cup_of_tea'],
#  'origin': ['pedigree',
#   'line_of_descent',
#   'stock',
#   'bloodline',
#   'blood',
#   'beginning',
#   'lineage',
#   'origin',
#   'blood_line',
#   'parentage',
#   'descent',
#   'stemma',
#   'root',
#   'rootage',
#   'extraction',
#   'ancestry',
#   'source',
#   'line',
#   'origination',
#   'inception'],
#  'eightslot': [],
#  'sixfg': [],
#  'accelerate': ['quicken', 'accelerate', 'speed', 'speed_up'],
#  'frames': ['flesh',
#   'human_body',
#   'systema_skeletale',
#   'draw_up',
#   'build',
#   'frame_of_reference',
#   'underframe',
#   'figure',
#   'material_body',
#   'physique',
#   'form',
#   'redact',
#   'couch',
#   'ensnare',
#   'cast',
#   'shape',
#   'skeleton',
#   'frame_in',
#   'soma',
#   'frame_up',
#   'bod',
#   'set_up',
#   'put',
#   'skeletal_frame',
#   'skeletal_system',
#   'physical_body',
#   'frame',
#   'anatomy',
#   'inning',
#   'chassis',
#   'framing',
#   'border',
#   'compose',
#   'entrap'],
#  'bolster': ['bolster', 'bolster_up', 'long_pillow', 'pad'],
#  'opinnions': [],
#  'cakewalk': ['cakewalk'],
#  'fiftytwoyicvajlxspbfivedtwogimcninetgtwosgyzeroabrgzerocvzpbmnlietoneyg': [],
#  'gads': ['anxiety_reaction',
#   'gad',
#   'GAD',
#   'jazz_around',
#   'generalized_anxiety_disorder',
#   'spur',
#   'gallivant'],
#  'ufiftysix': [],
#  'hanguyen': [],
#  'dumped': ['dump',
#   'plunge',
#   'ditch',
#   'deck',
#   'floor',
#   'coldcock',
#   'knock_down',
#   'underprice'],
#  'takdirde': [],
#  'fiftygee': [],
#  'devprogram': [],
#  'ports': ['porthole',
#   'larboard',
#   'port_wine',
#   'interface',
#   'embrasure',
#   'port'],
#  'scrap': ['bit',
#   'fighting',
#   'dispute',
#   'junk',
#   'trash',
#   'fight',
#   'combat',
#   'flake',
#   'fleck',
#   'chip',
#   'argufy',
#   'quarrel',
#   'rubbish',
#   'scrap',
#   'altercate'],
#  'creationism': ['creationism'],
#  'disburse': ['pay_out', 'disburse'],
#  'ashamed': ['ashamed'],
#  'vus': [],
#  'mseventysixnthreeqbydninewtwopfourzeroittsevenkb': [],
#  'pwhen': [],
#  'ing': [],
#  'publicdomain': [],
#  'barrel': ['cask', 'barrelful', 'drum', 'bbl', 'barrel', 'gun_barrel'],
#  'singula': [],
#  'phooey': [],
#  'tate': ['Tate', 'Allen_Tate', 'John_Orley_Allen_Tate'],
#  'phillies': [],
#  'xreparentwindow': [],
#  'yuppie': ['yuppie'],
#  'rt': [],
#  'unversed': ['unversed', 'unpracticed', 'unpractised'],
#  'prowess': ['art', 'artistry', 'prowess'],
#  'potentiometer': ['pot', 'potentiometer'],
#  'resonable': [],
#  'caffeine': ['caffeine', 'caffein'],
#  'pretense': ['feigning',
#   'pretending',
#   'pretension',
#   'pretence',
#   'dissembling',
#   'make-believe',
#   'guise',
#   'simulation',
#   'pretense',
#   'pretext'],
#  'ideas': ['melodic_theme',
#   'musical_theme',
#   'mind',
#   'estimate',
#   'estimation',
#   'theme',
#   'thought',
#   'approximation',
#   'idea'],
#  'sheaffernetcomcom': [],
#  'twentyfivethirty': [],
#  'xdvi': [],
#  'hemoraging': [],
#  'viciouslywhether': [],
#  'lied': ['dwell', 'lie_in', 'rest', 'lie_down', 'lied', 'lie', 'consist'],
#  'mninelthreeqthreeqzeroqthreeqeightaxaxaxaxaxax': [],
#  'certainty': ['certainty', 'sure_thing', 'foregone_conclusion'],
#  'trafficking': ['traffic'],
#  'muniz': [],
#  'hanavinhueyudeledu': [],
#  'thirtytwognvifasufledu': [],
#  'jefferson': ['Thomas_Jefferson', 'Jefferson', 'President_Jefferson'],
#  'threatening': ['minatory',
#   'sullen',
#   'jeopardize',
#   'baleful',
#   'imperil',
#   'jeopardise',
#   'sinister',
#   'threatening',
#   'minacious',
#   'heavy',
#   'menace',
#   'threaten',
#   'peril',
#   'menacing',
#   'ominous',
#   'lowering',
#   'forbidding',
#   'endanger'],
#  'representative': ['instance',
#   'voice',
#   'congressman',
#   'representative',
#   'example',
#   'congresswoman',
#   'illustration',
#   'interpreter',
#   'spokesperson'],
#  'holden': [],
#  'now': ['today',
#   'at_once',
#   'now',
#   'nowadays',
#   'straightaway',
#   'straight_off',
#   'at_present',
#   'directly',
#   'right_away',
#   'like_a_shot',
#   'immediately',
#   'instantly',
#   'forthwith'],
#  'aesthetically': ['esthetically', 'aesthetically'],
#  'solely': ['exclusively', 'solely', 'only', 'entirely', 'alone'],
#  'mags': ['magazine', 'mag'],
#  'stevefaeriechiilus': [],
#  'encyclopedia': ['cyclopedia',
#   'cyclopaedia',
#   'encyclopedia',
#   'encyclopaedia'],
#  'thirtysixthirtythree': [],
#  'cuz': [],
#  'dispute': ['dispute',
#   'gainsay',
#   'difference_of_opinion',
#   'contravention',
#   'challenge',
#   'argufy',
#   'scrap',
#   'quarrel',
#   'altercate',
#   'conflict',
#   'difference'],
#  'kinerisms': [],
#  'nontechnical': ['untechnical', 'nontechnical'],
#  'culprit': ['perpetrator', 'culprit'],
#  'swrtwonsonecclehighedu': [],
#  'onthefly': [],
#  'obdis': [],
#  'distraction': ['misdirection', 'beguilement', 'distraction'],
#  'aiming': ['train',
#   'direct',
#   'point',
#   'propose',
#   'calculate',
#   'purport',
#   'draw_a_bead_on',
#   'target',
#   'aspire',
#   'shoot_for',
#   'drive',
#   'aim',
#   'get',
#   'take',
#   'purpose',
#   'place',
#   'take_aim'],
#  'flashing': ['show_off',
#   'ostentate',
#   'scud',
#   'swank',
#   'flash',
#   'winkle',
#   'shoot',
#   'dash',
#   'blink',
#   'wink',
#   'flaunt',
#   'twinkle',
#   'scoot',
#   'flashing',
#   'dart'],
#  'voltmeter': ['voltmeter'],
#  'vantage': ['vantage', 'advantage'],
#  'contents': ['table_of_contents',
#   'depicted_object',
#   'mental_object',
#   'capacity',
#   'subject',
#   'subject_matter',
#   'content',
#   'contentedness',
#   'substance',
#   'contents',
#   'message',
#   'cognitive_content'],
#  'equator': ['equator'],
#  'poser': ['poser', 'stumper', 'sticker', 'poseur', 'toughie', 'model'],
#  'worship': ['idolize',
#   'worship',
#   'revere',
#   'adoration',
#   'hero-worship',
#   'idolise'],
#  'freetwo': [],
#  'netcomericscfiftytwoqccsixfu': [],
#  'mwwwwwizgizwonezsixeifourpmfninelzeroqeightaxaxaxaxaxaxax': [],
#  'stamped': ['stamp',
#   'stump',
#   'emboss',
#   'pigeonhole',
#   'stomp',
#   'stereotype',
#   'boss'],
#  'mark': ['mug',
#   'cross',
#   'Saint_Mark',
#   'cross_off',
#   'mark',
#   'check',
#   'Deutschmark',
#   'Gospel_According_to_Mark',
#   'fool',
#   'note',
#   'distinguish',
#   'patsy',
#   'Mark',
#   'mark_off',
#   'cross_out',
#   'score',
#   'scratch',
#   'punctuate',
#   'marking',
#   'denounce',
#   "bull's_eye",
#   'marker',
#   'check_off',
#   'commemorate',
#   'differentiate',
#   'pit',
#   'tick',
#   'notice',
#   'tick_off',
#   'target',
#   'fall_guy',
#   'sucker',
#   'stigmatise',
#   'St._Mark',
#   'chump',
#   'label',
#   'set',
#   'strike_out',
#   'stigma',
#   'home_run',
#   'print',
#   'German_mark',
#   'soft_touch',
#   'tag',
#   'pock',
#   'strike_off',
#   'bell_ringer',
#   'grade',
#   'stain',
#   'Deutsche_Mark',
#   'stigmatize',
#   'gull',
#   'nock',
#   'scar',
#   'scrape',
#   'crisscross',
#   'sign',
#   'brand'],
#  'cuil': [],
#  'timothy': ['Phleum_pratense', 'timothy', 'Timothy', "herd's_grass"],
#  'calle': [],
#  'additions': ['addition',
#   'accession',
#   'increase',
#   'plus',
#   'gain',
#   'summation',
#   'add-on',
#   'improver'],
#  'pontifical': ['overblown',
#   'papal',
#   'grandiloquent',
#   'pompous',
#   'apostolic',
#   'apostolical',
#   'episcopal',
#   'pontifical',
#   'portentous'],
#  'connectors': ['connective',
#   'connecter',
#   'connector',
#   'connexion',
#   'connection'],
#  'kellaallah': [],
#  'ssrb': [],
#  'winbnthreeeleven': [],
#  'contempt': ['despite', 'scorn', 'disrespect', 'contempt', 'disdain'],
#  'proved': ['essay',
#   'establish',
#   'evidence',
#   'demonstrate',
#   'show',
#   'raise',
#   'leaven',
#   'prove',
#   'proven',
#   'turn_up',
#   'testify',
#   'proved',
#   'try_out',
#   'test',
#   'examine',
#   'shew',
#   'try',
#   'bear_witness',
#   'rise',
#   'turn_out'],
#  'terminator': ['terminator', 'exterminator', 'eradicator'],
#  'jean': ['dungaree', 'denim', 'blue_jean', 'jean'],
#  'next': ['future',
#   'following',
#   'adjacent',
#   'succeeding',
#   'side_by_side',
#   'next'],
#  'wallops': ['whop', 'wallop', 'impact', 'wham', 'whack'],
#  'tarl': [],
#  'orbits': ['domain',
#   'eye_socket',
#   'orbit',
#   'arena',
#   'cranial_orbit',
#   'orb',
#   'ambit',
#   'compass',
#   'scope',
#   'area',
#   'field',
#   'sphere',
#   'orbital_cavity',
#   'revolve',
#   'electron_orbit',
#   'reach',
#   'celestial_orbit',
#   'range'],
#  'rd': [],
#  'soccultureus': [],
#  'thrilled': ['thrill',
#   'exhilarate',
#   'throb',
#   'thrilled',
#   'shiver',
#   'vibrate',
#   'inebriate',
#   'shudder',
#   'tickle_pink',
#   'tickle',
#   'beatify',
#   'exalt'],
#  'negligent': ['negligent'],
#  'holiday': ['holiday', 'vacation'],
#  'johna': [],
#  'fronts': ['presence',
#   'battlefront',
#   'nominal_head',
#   'strawman',
#   'straw_man',
#   'front',
#   'breast',
#   'movement',
#   'face',
#   'social_movement',
#   'look',
#   'forepart',
#   'figurehead',
#   'front_man',
#   'front_line',
#   'front_end'],
#  'dudekacsubuffaloedu': [],
#  'classroom': ['classroom', 'schoolroom'],
#  'psm': [],
#  'mahoganyone': [],
#  'use': ['utilize',
#   'exercise',
#   'usage',
#   'use',
#   'employ',
#   'consumption',
#   'purpose',
#   'manipulation',
#   'utilise',
#   'economic_consumption',
#   'habit',
#   'apply',
#   'expend',
#   'role',
#   'practice',
#   'enjoyment',
#   'utilisation',
#   'usance',
#   'utilization',
#   'function',
#   'employment',
#   'use_of_goods_and_services',
#   'habituate'],
#  'fearthe': [],
#  'pls': [],
#  'stjohns': [],
#  'hundredx': [],
#  'lawyer': ['lawyer', 'attorney'],
#  'assistants': ['helper', 'help', 'supporter', 'assistant'],
#  'mthonelrbqzcicybukozaoyscwifiveyouezqjthreeufourfh': [],
#  'referenda': ['referendum'],
#  'albicans': [],
#  'packard': [],
#  'hollowed': ['hollow_out', 'dig', 'hollow', 'core_out', 'excavate'],
#  'seniors': ['elder', 'senior'],
#  'rebuilding': ['rebuild', 'reconstruct', 'rebuilding'],
#  'wrswslackuucp': [],
#  'palazzo': [],
#  'brindamour': [],
#  'broken': ['break-dance',
#   'expose',
#   'collapse',
#   'check',
#   'broken',
#   'let_out',
#   'discover',
#   'smash',
#   'break_dance',
#   'cave_in',
#   'break_in',
#   'get_around',
#   'erupt',
#   'confused',
#   'offend',
#   'split',
#   'humiliated',
#   'disordered',
#   'fall_in',
#   'let_on',
#   'wiped_out',
#   'unwrap',
#   'die',
#   'divulge',
#   'separate',
#   'kick_downstairs',
#   'demote',
#   'soften',
#   'damp',
#   'busted',
#   'snap_off',
#   'recrudesce',
#   'discontinue',
#   'part',
#   'wear',
#   'stop',
#   'go_bad',
#   'give_away',
#   'disclose',
#   'split_up',
#   'bump',
#   'break_away',
#   'go_against',
#   'bust',
#   'fail',
#   'give',
#   'break_out',
#   'break_down',
#   'relegate',
#   'breach',
#   'violate',
#   'fall_apart',
#   'burst',
#   'bring_out',
#   'go',
#   'unkept',
#   'reveal',
#   'humbled',
#   'infract',
#   'dampen',
#   'crushed',
#   'break_off',
#   'better',
#   'develop',
#   'bankrupt',
#   'come_apart',
#   'rugged',
#   'conk_out',
#   'interrupt',
#   'transgress',
#   'get_out',
#   'low',
#   'ruin',
#   'break',
#   'founder',
#   'weaken',
#   'pause',
#   'give_way',
#   'break_up',
#   'wear_out',
#   'give_out',
#   'crack',
#   'fracture',
#   'upset',
#   'impoverished',
#   'intermit',
#   'broken_in'],
#  'crisis': ['crisis'],
#  'datadecucrengrucredu': [],
#  'instant': ['flash',
#   'clamant',
#   'heartbeat',
#   'second',
#   'instant',
#   'crying',
#   'instantaneous',
#   'exigent',
#   'insistent',
#   'moment',
#   'split_second',
#   'minute',
#   'New_York_minute',
#   'wink',
#   'blink_of_an_eye',
#   'trice',
#   'inst',
#   'twinkling',
#   'jiffy'],
#  'spina': [],
#  'capital': ['working_capital',
#   'chapiter',
#   'great',
#   'Washington',
#   'capital_letter',
#   'Capital',
#   'Das_Kapital',
#   'uppercase',
#   'cap',
#   'capital',
#   'upper-case_letter',
#   'majuscule'],
#  'open': ['surface',
#   'open_up',
#   'capable',
#   'loose',
#   'open',
#   'assailable',
#   'spread_out',
#   'give',
#   'outdoors',
#   'unfastened',
#   'open_air',
#   'candid',
#   'heart-to-heart',
#   'receptive',
#   'clear',
#   'unfold',
#   'subject',
#   'undefended',
#   'undefendable',
#   'undetermined',
#   'undecided',
#   'exposed',
#   'out-of-doors',
#   'unresolved',
#   'spread',
#   'overt',
#   'afford',
#   'opened'],
#  'deceive': ['delude', 'lead_on', 'lead_astray', 'betray', 'cozen', 'deceive'],
#  'nakhitchevan': [],
#  'xgksrequestunidataucaredu': [],
#  'skepticism': ['skepticism',
#   'agnosticism',
#   'incredulity',
#   'mental_rejection',
#   'disbelief',
#   'scepticism'],
#  'stereo': ['stereophonic',
#   'stereoscopic_picture',
#   'stereophony',
#   'stereoscopic_photograph',
#   'stereo',
#   'stereophonic_system',
#   'two-channel',
#   'stereo_system'],
#  'polluted': ['foul', 'polluted', 'contaminate', 'contaminated', 'pollute'],
#  'butane': ['butane'],
#  'speedbumps': [],
#  'jfcathenamitedu': [],
#  'borax': ['borax'],
#  'remained': ['continue', 'rest', 'stay', 'persist', 'remain', 'stay_on'],
#  'zolft': [],
#  'evaporate': ['disappear', 'melt', 'vaporise', 'vaporize', 'evaporate'],
#  'rights': ['rightfield',
#   'rightfulness',
#   'right_field',
#   'right_wing',
#   'compensate',
#   'correct',
#   'rectify',
#   'right',
#   'right_hand',
#   'redress'],
#  'carried': ['channel',
#   'dribble',
#   'stock',
#   'deport',
#   'contain',
#   'behave',
#   'run',
#   'pack',
#   'gestate',
#   'expect',
#   'impart',
#   'bear',
#   'hold',
#   'persuade',
#   'transport',
#   'take',
#   'transmit',
#   'have_a_bun_in_the_oven',
#   'extend',
#   'post',
#   'convey',
#   'stockpile',
#   'sway',
#   'comport',
#   'express',
#   'acquit',
#   'conduct',
#   'carry'],
#  'kix': [],
#  'amerika': [],
#  'utp': [],
#  'historians': ['historian', 'historiographer'],
#  'commencement': ['graduation',
#   'first',
#   'starting_time',
#   'commencement_exercise',
#   'showtime',
#   'offset',
#   'graduation_exercise',
#   'start',
#   'get-go',
#   'commencement_ceremony',
#   'outset',
#   'kickoff',
#   'commencement',
#   'beginning'],
#  'echoed': ['echo', 'ring', 'reverberate', 'repeat', 'resound', 'recall'],
#  'fouronetwo': [],
#  'ethics': ['moral_principle',
#   'ethics',
#   'morals',
#   'moral_philosophy',
#   'value_orientation',
#   'value-system',
#   'morality',
#   'ethic',
#   'ethical_code',
#   'ethical_motive'],
#  'betting': ['dissipated',
#   'count',
#   'betting',
#   'reckon',
#   'calculate',
#   'depend',
#   'look',
#   'bet',
#   'play',
#   'card-playing',
#   'wager',
#   'sporting'],
#  'majka': [],
#  'catholicprotestant': [],
#  'pin': ['trap',
#   'flag',
#   'tholepin',
#   'peg',
#   'PIN',
#   'pin_tumbler',
#   'fall',
#   'personal_identification_number',
#   'stick',
#   'oarlock',
#   'bowling_pin',
#   'PIN_number',
#   'immobilise',
#   'thole',
#   'pin',
#   'immobilize',
#   'rowlock',
#   'pivot'],
#  'prevention': ['bar', 'prevention'],
#  'beams': ['ray_of_light',
#   'shine',
#   'beam_of_light',
#   'beam',
#   'send',
#   'glow',
#   'irradiation',
#   'ray',
#   'light_beam',
#   'broadcast',
#   'radio_beam',
#   'radiate',
#   'electron_beam',
#   'shaft',
#   'shaft_of_light',
#   'balance_beam',
#   'air',
#   'transmit'],
#  'iis': ['Iraqi_Intelligence_Service',
#   'two',
#   'Iraqi_Mukhabarat',
#   '2',
#   'deuce',
#   'IIS',
#   'II'],
#  'seminar': ['seminar'],
#  'mbongoucsdedu': [],
#  'imho': [],
#  'delaying': ['hold_up', 'check', 'detain', 'delay', 'stay', 'retard'],
#  'hammer': ['pound',
#   'hammering',
#   'malleus',
#   'cock',
#   'pounding',
#   'forge',
#   'hammer',
#   'power_hammer',
#   'mallet'],
#  'galaxy': ['galax',
#   'Galax_urceolata',
#   'extragalactic_nebula',
#   'coltsfoot',
#   'beetleweed',
#   'galaxy',
#   'wandflower'],
#  'nunnally': [],
#  'interviewsstanfordedu': [],
#  'foursixmbs': [],
#  'universe': ['universe',
#   'existence',
#   'cosmos',
#   'creation',
#   'macrocosm',
#   'universe_of_discourse',
#   'population',
#   'world'],
#  'babson': [],
#  'defensemen': [],
#  'limitlook': [],
#  'navy': ['US_Navy',
#   'naval_forces',
#   'United_States_Navy',
#   'USN',
#   'navy',
#   'Navy',
#   'dark_blue',
#   'navy_blue'],
#  'vacs': ['vac'],
#  'sherwoodadobecom': [],
#  'hundredc': [],
#  'resorting': ['repair', 'recur', 'resort', 'fall_back'],
#  'unicity': [],
#  'plumbers': ['pipe_fitter', 'plumber'],
#  'eaiser': [],
#  'transplantation': ['organ_transplant',
#   'transplant',
#   'transplantation',
#   'transplanting'],
#  'hitchhikers': ['hitchhiker'],
#  'factually': ['factually'],
#  'mbxnbwmfourupleqtmfninedfninefninepnnbizonezfourninelzeroqaxaxax': [],
#  'gagoals': [],
#  'ideesdi': [],
#  'davebnrca': [],
#  'give': ['pass_on',
#   'collapse',
#   'turn_over',
#   'establish',
#   'dedicate',
#   'pay',
#   'make',
#   'reach',
#   'present',
#   'open',
#   'kick_in',
#   'have',
#   'gift',
#   'give',
#   'impart',
#   'move_over',
#   'hold',
#   'commit',
#   'generate',
#   'cave_in',
#   'feed',
#   'break',
#   'pass',
#   'grant',
#   'founder',
#   'consecrate',
#   'leave',
#   'apply',
#   'springiness',
#   'give_way',
#   'throw',
#   'return',
#   'chip_in',
#   'ease_up',
#   'devote',
#   'spring',
#   'render',
#   'hand',
#   'contribute',
#   'fall_in',
#   'sacrifice',
#   'yield',
#   'afford'],
#  'volvos': [],
#  'intently': ['intently'],
#  'violators': ['debaucher',
#   'violator',
#   'ravisher',
#   'law_offender',
#   'lawbreaker'],
#  'hear': ['discover',
#   'pick_up',
#   'listen',
#   'get_wind',
#   'see',
#   'get_a_line',
#   'try',
#   'get_word',
#   'hear',
#   'take_heed',
#   'find_out',
#   'learn'],
#  'optimize': ['optimise', 'optimize'],
#  'refuge': ['recourse', 'sanctuary', 'safety', 'resort', 'asylum', 'refuge'],
#  'intfifteenh': [],
#  'pmetzgerlehmancom': [],
#  'shalimar': [],
#  'assembly': ['assembly',
#   'assemblage',
#   'meeting_place',
#   'gathering',
#   'forum',
#   'fabrication'],
#  'fade': ['slice',
#   'fade',
#   'wither',
#   'evanesce',
#   'blow_over',
#   'pass',
#   'melt',
#   'fleet',
#   'languish',
#   'disappearance',
#   'pass_off',
#   'slicing'],
#  'mtb': [],
#  'jaffa': ['Yafo', 'Jaffa', 'Joppa'],
#  'mustangalso': [],
#  'murdered': ['mutilate',
#   'dispatch',
#   'hit',
#   'off',
#   'polish_off',
#   'murder',
#   'murdered',
#   'slay',
#   'remove',
#   'mangle',
#   'bump_off'],
#  'reservation': ['arriere_pensee',
#   'booking',
#   'reserve',
#   'reservation',
#   'mental_reservation',
#   'qualification'],
#  'vectors': ['transmitter', 'vector'],
#  'predicted': ['prognosticate',
#   'auspicate',
#   'call',
#   'presage',
#   'forebode',
#   'anticipate',
#   'omen',
#   'augur',
#   'predict',
#   'foretell',
#   'foreshadow',
#   'forecast',
#   'promise',
#   'betoken',
#   'prefigure',
#   'portend',
#   'bode'],
#  'eightysixteenfn': [],
#  'mbeightfraxaxaxaxaxaxaxaxaxax': [],
#  'compares': ['compare',
#   'equivalence',
#   'comparison',
#   'comparability',
#   'equate',
#   'liken'],
#  'twelveelevensix': [],
#  'proof': ['substantiation',
#   'cogent_evidence',
#   'proof',
#   'trial_impression',
#   'validation',
#   'test_copy',
#   'proofread'],
#  'eightyfoureightyfive': [],
#  'tenk': [],
#  'deanebinahccbrandeisedu': [],
#  'unbiased': ['unbiassed', 'indifferent', 'unbiased'],
#  'ecumenical': ['oecumenical',
#   'general',
#   'ecumenic',
#   'worldwide',
#   'ecumenical',
#   'cosmopolitan',
#   'oecumenic',
#   'universal',
#   'world-wide'],
#  'rotc': ['ROTC', 'Reserve_Officers_Training_Corps'],
#  'purchasing': ['buy', 'purchasing', 'buying', 'purchase'],
#  'retract': ['shrink_back',
#   'resile',
#   'recant',
#   'abjure',
#   'pull_back',
#   'forswear',
#   'draw_back',
#   'draw_in',
#   'retract'],
#  'deterministically': [],
#  'kulikauskasjaynemmaltguildorg': [],
#  'pedersen': [],
#  'systemsnsoftware': [],
#  'thoughts': ['view',
#   'opinion',
#   'thought_process',
#   'sentiment',
#   'thought',
#   'persuasion',
#   'mentation',
#   'idea',
#   'cerebration',
#   'intellection',
#   'thinking'],
#  'mcdowell': [],
#  'eighteennineteen': [],
#  'fiftyfive': [],
#  'wichever': [],
#  'notre': [],
#  'hundreddb': [],
#  'japanese': ['Nipponese', 'Japanese'],
#  'wrightlimsonelercnasagov': [],
#  'quirkeakosmoswccgovtnz': [],
#  'tell': ['secern',
#   'tell',
#   'evidence',
#   'assure',
#   'distinguish',
#   'order',
#   'separate',
#   'recount',
#   'William_Tell',
#   'tell_apart',
#   'recite',
#   'Tell',
#   'differentiate',
#   'enjoin',
#   'narrate',
#   'severalize',
#   'state',
#   'say',
#   'severalise',
#   'secernate'],
#  'rwftwonsonecclehighedu': [],
#  'twentyeightth': [],
#  'cfp': [],
#  'affected': ['moved',
#   'feign',
#   'affected',
#   'dissemble',
#   'involve',
#   'touch_on',
#   'sham',
#   'regard',
#   'impact',
#   'bear_upon',
#   'affect',
#   'pretend',
#   'impress',
#   'stirred',
#   'bear_on',
#   'move',
#   'unnatural',
#   'strike',
#   'touch',
#   'touched'],
#  'gland': ['secreter', 'gland', 'secretory_organ', 'secretor'],
#  'similarity': ['similarity', 'law_of_similarity'],
#  'chiefs': ['head',
#   'chief',
#   'tribal_chief',
#   'headman',
#   'top_dog',
#   'gaffer',
#   'honcho',
#   'chieftain',
#   'foreman',
#   'boss'],
#  'eossixctwoericssonse': [],
#  'mba': ['MBA', 'Master_in_Business_Administration', 'Master_in_Business'],
#  'prioritize': ['prioritise', 'prioritize'],
#  'ratbastards': [],
#  'cetera': [],
#  'conversing': ['converse', 'discourse'],
#  'backspace': ['backspace', 'backspacer', 'backspace_key'],
#  'mallorys': [],
#  'flourished': ['wave',
#   'expand',
#   'thrive',
#   'boom',
#   'fly_high',
#   'flourish',
#   'prosper',
#   'brandish'],
#  'raped': ['outrage',
#   'despoil',
#   'sacked',
#   'rap',
#   'rape',
#   'plunder',
#   'ravish',
#   'pink',
#   'dishonour',
#   'knap',
#   'ravaged',
#   'knock',
#   'spoil',
#   'violate',
#   'pillaged',
#   'assault',
#   'dishonor',
#   'tap',
#   'despoiled',
#   'raped'],
#  'naifs': ['naif'],
#  'rik': [],
#  'kouhia': [],
#  'ullage': ['ullage'],
#  'speedloader': [],
#  'ninetythreeaprfifteenthree': [],
#  'commentaries': ['commentary', 'comment'],
#  'maternal': ['enatic', 'maternal', 'enate', 'parental', 'paternal'],
#  'goyalutdallasedu': [],
#  'structures': ['social_organization',
#   'body_structure',
#   'bodily_structure',
#   'complex_body_part',
#   'anatomical_structure',
#   'construction',
#   'social_system',
#   'social_organisation',
#   'structure',
#   'social_structure'],
#  'ugly': ['unworthy',
#   'worthless',
#   'slimy',
#   'ugly',
#   'vile',
#   'horrifying',
#   'frightful',
#   'wretched',
#   'horrible',
#   'atrocious',
#   'surly',
#   'despicable'],
#  'recipient': ['recipient_role', 'receiver', 'recipient'],
#  'fourtoone': [],
#  'bulky': ['bulky'],
#  'walc': [],
#  'xelevenbased': [],
#  'readers': ['subscriber',
#   'lector',
#   'referee',
#   'reader',
#   'lecturer',
#   'reviewer',
#   'proofreader'],
#  'porn': ['pornography', 'porn', 'porno', 'erotica', 'smut'],
#  'interferred': [],
#  'seams': ['line', 'crease', 'crinkle', 'furrow', 'seam', 'wrinkle', 'bed'],
#  'pathway': ['footpath', 'tract', 'nerve_tract', 'nerve_pathway', 'pathway'],
#  'variation': ['fluctuation',
#   'sport',
#   'variation',
#   'variance',
#   'magnetic_declination',
#   'mutation',
#   'pas_seul',
#   'version',
#   'magnetic_variation',
#   'variant',
#   'edition',
#   'mutant'],
#  'radley': [],
#  'progressive': ['progressive_tense',
#   'imperfect_tense',
#   'imperfect',
#   'progressive',
#   'reformist',
#   'continuous_tense',
#   'liberal',
#   'reform-minded',
#   'liberalist'],
#  'oneqsfouraninefeightysevenbigbootewpiedu': [],
#  'abdomens': ['abdomen', 'belly', 'venter', 'stomach', 'abdominal_cavity'],
#  'monash': [],
#  'browse': ['crop',
#   'browse',
#   'surf',
#   'shop',
#   'pasture',
#   'browsing',
#   'graze',
#   'range'],
#  'nd': ['Peace_Garden_State',
#   'ND',
#   'Nd',
#   'atomic_number_60',
#   'North_Dakota',
#   'neodymium'],
#  'surgical': ['operative', 'surgical'],
#  'overload': ['overcharge', 'overload', 'surcharge', 'clog', 'overburden'],
#  'tire': ['exhaust',
#   'fag',
#   'tyre',
#   'bore',
#   'wear_down',
#   'outwear',
#   'weary',
#   'wear_upon',
#   'jade',
#   'fatigue',
#   'play_out',
#   'wear_out',
#   'tire_out',
#   'sap',
#   'pall',
#   'run_down',
#   'wear',
#   'tire',
#   'fag_out'],
#  'fifteenten': [],
#  'damage': ['price',
#   'equipment_casualty',
#   'scathe',
#   'impairment',
#   'legal_injury',
#   'wrong',
#   'harm',
#   'damage',
#   'hurt',
#   'terms'],
#  'cwinmiscgamesdialwordtxt': [],
#  'meedsevenrnfivenineryjlesevenonesfourhsixusevenfivesixnsstwohifive': [],
#  'thornwamumdedu': [],
#  'risng': [],
#  'lowe': [],
#  'fortythreeone': [],
#  'darpa': ['DARPA', 'Defense_Advanced_Research_Projects_Agency'],
#  'shereware': [],
#  'mormonspeople': [],
#  'muskingum': [],
#  'proving': ['shew',
#   'essay',
#   'test',
#   'prove',
#   'turn_up',
#   'establish',
#   'evidence',
#   'try',
#   'rise',
#   'bear_witness',
#   'demonstrate',
#   'show',
#   'testify',
#   'examine',
#   'raise',
#   'try_out',
#   'leaven',
#   'turn_out'],
#  'cdp': [],
#  'waffleiron': [],
#  'qualcomrdippoldseven': [],
#  'gehrig': ['Henry_Louis_Gehrig', 'Gehrig', 'Lou_Gehrig'],
#  'remembered': ['call_back',
#   'think',
#   'remember',
#   'think_back',
#   'call_up',
#   'retrieve',
#   'commemorate',
#   'recollect',
#   'recall',
#   'commend',
#   'think_of'],
#  'gennady': [],
#  'denied': ['traverse', 'deny', 'abnegate', 'refuse'],
#  'curves': ['slew',
#   'swerve',
#   'curve',
#   'curvature',
#   'curve_ball',
#   'bend',
#   'arch',
#   'arc',
#   'kink',
#   'curved_shape',
#   'twist',
#   'trend',
#   'sheer',
#   'veer',
#   'curl',
#   'slue',
#   'crook',
#   'breaking_ball',
#   'wind',
#   'cut',
#   'bender'],
#  'wise': ['impudent',
#   'wise_to',
#   'sassy',
#   'wise',
#   'heady',
#   'Stephen_Samuel_Wise',
#   'knowing',
#   'Isaac_Mayer_Wise',
#   'fresh',
#   'saucy',
#   'impertinent',
#   'judicious',
#   'overbold',
#   'smart',
#   'Wise'],
#  'generals': ['superior_general', 'full_general', 'general'],
#  'sternlight': [],
#  'brooksby': [],
#  'appressian': [],
#  'talon': ['talon'],
#  'terminate': ['end',
#   'can',
#   'fire',
#   'finish',
#   'give_the_axe',
#   'terminate',
#   'send_away',
#   'dismiss',
#   'sack',
#   'force_out',
#   'give_notice',
#   'displace',
#   'give_the_sack',
#   'cease',
#   'stop'],
#  'indices': ['index_finger',
#   'index_number',
#   'forefinger',
#   'exponent',
#   'index',
#   'indicator',
#   'indicant',
#   'power'],
#  'beliefs': ['opinion', 'belief', 'notion', 'impression', 'feeling'],
#  'nthreejxp': [],
#  'eightyoneritvaxiscritedu': [],
#  'antonio': [],
#  'philli': [],
#  'arlington': ['Arlington'],
#  'commonsense': ['commonsensible', 'commonsense', 'commonsensical'],
#  'kaldis': [],
#  'claiming': ['exact', 'lay_claim', 'arrogate', 'claim', 'take'],
#  'copenhagen': ['Copenhagen', 'Danish_capital', 'Kobenhavn'],
#  'vitality': ['verve',
#   'vital_force',
#   'vim',
#   'elan_vital',
#   'animation',
#   'energy',
#   'vitality',
#   'life_force'],
#  'floppyhard': [],
#  'fournew': [],
#  'inserting': ['infix',
#   'tuck',
#   'inclose',
#   'enclose',
#   'enter',
#   'stick_in',
#   'slip_in',
#   'insert',
#   'put_in',
#   'introduce',
#   'sneak_in'],
#  'christycsconcordiaca': [],
#  'dion': [],
#  'eightytwo': [],
#  'si': ['te',
#   'SI_system',
#   'si',
#   'Si',
#   'ti',
#   'International_System_of_Units',
#   'silicon',
#   'SI',
#   'atomic_number_14',
#   'International_System',
#   'Systeme_International',
#   'SI_unit',
#   "Systeme_International_d'Unites"],
#  'koylerindeki': [],
#  'ferchucsubcca': [],
#  'privatesemiprivate': [],
#  'twentyforty': [],
#  'responds': ['reply', 'respond', 'answer', 'react'],
#  'stellar': ['leading', 'star', 'prima', 'starring', 'astral', 'stellar'],
#  'chaudharyamaryaleedu': [],
#  'moscow': ['Moscow', 'Russian_capital', 'capital_of_the_Russian_Federation'],
#  'disputing': ['dispute',
#   'gainsay',
#   'challenge',
#   'argufy',
#   'quarrel',
#   'altercate',
#   'scrap'],
#  'fixing': ['sterilise',
#   'deposit',
#   'secure',
#   'prepare',
#   'fixture',
#   'cook',
#   'furbish_up',
#   'define',
#   'desexualise',
#   'make',
#   'mend',
#   'fixate',
#   'unsex',
#   'touch_on',
#   'altering',
#   'reparation',
#   'limit',
#   'neutering',
#   'desex',
#   'fastener',
#   'restore',
#   'holdfast',
#   'get',
#   'sterilize',
#   'ready',
#   'bushel',
#   'set',
#   'fastening',
#   'fasten',
#   'specify',
#   'determine',
#   'fix',
#   'repair',
#   'situate',
#   'posit',
#   'set_up',
#   'fixation',
#   'pay_back',
#   'desexualize',
#   'gear_up',
#   'pay_off',
#   'doctor',
#   'fixing',
#   'mending'],
#  'fortyfives': [],
#  'awcamconcouk': [],
#  'nobuya': [],
#  'catchers': ['catcher', 'backstop'],
#  'twobaltimore': [],
#  'zionism': ['Zionist_movement', 'Zionism'],
#  'siblings': ['sibling', 'sib'],
#  'seize': ['attach',
#   'assume',
#   'sequester',
#   'arrogate',
#   'grab',
#   'conquer',
#   'prehend',
#   'clutch',
#   'appropriate',
#   'impound',
#   'confiscate',
#   'seize',
#   'capture',
#   'take_over',
#   'usurp',
#   'get_hold_of'],
#  'talkorigins': [],
#  'twentyonekelvinjplnasagov': [],
#  'controlassembly': [],
#  'angels': ['holy_man',
#   'angel',
#   'Angel',
#   'saint',
#   'backer',
#   'holy_person',
#   'Angel_Falls'],
#  'sixteenbit': [],
#  'mdfivetwotwofournfivexnszmnine': [],
#  'subject': ['study',
#   'subjugate',
#   'dependent',
#   'capable',
#   'open',
#   'bailiwick',
#   'subject_field',
#   'content',
#   'discipline',
#   'matter',
#   'issue',
#   'case',
#   'national',
#   'subject_area',
#   'subject',
#   'topic',
#   'guinea_pig',
#   'field_of_study',
#   'theme',
#   'field',
#   'depicted_object',
#   'submit'],
#  'alomar': [],
#  'privatization': ['denationalisation',
#   'denationalization',
#   'privatization',
#   'privatisation'],
#  'meyer': [],
#  'purchases': ['buy', 'leverage', 'purchase'],
#  'sesh': [],
#  'essay': ['essay',
#   'test',
#   'prove',
#   'try',
#   'assay',
#   'examine',
#   'attempt',
#   'try_out',
#   'seek'],
#  'mznwfournythreektthreefsevenrsfivethreekreighthbteightfiveeightizajathreeusixtwounip': [],
#  'manhood': ['humanity', 'humanness', 'manhood'],
#  'thicker': ['loggerheaded',
#   'stocky',
#   'thick-skulled',
#   'thickset',
#   'compact',
#   'thick',
#   'slurred',
#   'thickheaded',
#   'wooden-headed',
#   'deep',
#   'heavyset',
#   'fatheaded',
#   'dense',
#   'duncish',
#   'chummy',
#   'boneheaded',
#   'blockheaded',
#   'buddy-buddy',
#   'duncical'],
#  'fortyseven': [],
#  'shakier': ['trembling',
#   'precarious',
#   'wonky',
#   'shaky',
#   'shivering',
#   'rickety',
#   'wobbly'],
#  'discourage': ['monish', 'admonish', 'deter', 'discourage', 'warn'],
#  'raise': ['enkindle',
#   'put_forward',
#   'salary_increase',
#   'erect',
#   'bring_up',
#   'advance',
#   'get_up',
#   'call_forth',
#   'stir',
#   'raise',
#   'evoke',
#   'leaven',
#   'hike',
#   'ascent',
#   'upgrade',
#   'prove',
#   'arouse',
#   'promote',
#   'conjure',
#   'parent',
#   'recruit',
#   'invoke',
#   'conjure_up',
#   'heighten',
#   'heave',
#   'levy',
#   'elevate',
#   'call_down',
#   'elicit',
#   'wage_hike',
#   'kick_upstairs',
#   'enhance',
#   'set_up',
#   'grow',
#   'provoke',
#   'farm',
#   'wage_increase',
#   'lift',
#   'nurture',
#   'kindle',
#   'acclivity',
#   'fire',
#   'put_up',
#   'climb',
#   'resurrect',
#   'rise',
#   'upraise',
#   'produce',
#   'rear'],
#  'hundredmph': [],
#  'fivetwentyone': [],
#  'finneganinvadernavonavymil': [],
#  'makey': [],
#  'vanda': ['vanda'],
#  'mainly': ['mainly', 'chiefly', 'primarily', 'principally', 'in_the_main'],
#  'patton': [],
#  'onefivembs': [],
#  'true': ['true_up',
#   'true',
#   'truthful',
#   'unfeigned',
#   'avowedly',
#   'straight',
#   'on-key',
#   'honest',
#   'admittedly',
#   'genuine',
#   'dependable',
#   'confessedly',
#   'reliable',
#   'dead_on_target',
#   'lawful',
#   'rightful'],
#  'lumped': ['chunk', 'lump', 'collocate'],
#  'gross': ['unadulterated',
#   'receipts',
#   'rank',
#   'everlasting',
#   'utter',
#   'crying',
#   'megascopic',
#   'arrant',
#   'thoroughgoing',
#   'pure',
#   'consummate',
#   'porcine',
#   'flagrant',
#   'glaring',
#   '144',
#   'sodding',
#   'stark',
#   'staring',
#   'gross',
#   'revenue',
#   'earthy',
#   'vulgar',
#   'egregious',
#   'complete',
#   'perfect',
#   'crude',
#   'double-dyed'],
#  'dfclarkcasandiagov': [],
#  'pomona': [],
#  'strands': ['strand',
#   'fibril',
#   'chain',
#   'Strand',
#   'filament',
#   'string',
#   'run_aground',
#   'ground',
#   'maroon'],
#  'ecthreebuhuraccrochesteredu': [],
#  'antialiasing': ['antialiasing'],
#  'corrupt': ['buy',
#   'corrupted',
#   'demoralise',
#   'demoralize',
#   'misdirect',
#   'debase',
#   'deprave',
#   'profane',
#   "grease_one's_palms",
#   'spoil',
#   'debauch',
#   'sully',
#   'cloud',
#   'bribe',
#   'tainted',
#   'defile',
#   'crooked',
#   'taint',
#   'pervert',
#   'corrupt',
#   'subvert',
#   'vitiate'],
#  'outperformed': ['exceed',
#   'surpass',
#   'surmount',
#   'outgo',
#   'outdo',
#   'outperform',
#   'outmatch',
#   'outstrip'],
#  'scum': ['trash', 'scum'],
#  'trust': ['entrust',
#   'swear',
#   'faith',
#   'hope',
#   'cartel',
#   'confidence',
#   'commit',
#   'trustingness',
#   'bank',
#   'believe',
#   'rely',
#   'combine',
#   'desire',
#   'trustfulness',
#   'confide',
#   'corporate_trust',
#   'trust',
#   'intrust',
#   'reliance'],
#  'pittnineteen': [],
#  'doelle': [],
#  'tumor': ['tumor', 'tumour', 'neoplasm'],
#  'compuserves': [],
#  'yak': ['chatter',
#   'gab',
#   'yack',
#   'yakety-yak',
#   'cackle',
#   'yak',
#   'Bos_grunniens'],
#  'conradie': [],
#  'motorsport': [],
#  'illegitimate': ['illicit',
#   'illegitimate_child',
#   'by-blow',
#   'bastard',
#   'outlaw',
#   'outlawed',
#   'unlawful',
#   'whoreson',
#   'illegitimate',
#   'love_child'],
#  'troops': ['soldiery',
#   'troops',
#   'military_personnel',
#   'troop',
#   'scout_group',
#   'scout_troop',
#   'flock',
#   'parade',
#   'promenade'],
#  'fruitfulness': ['fecundity', 'fruitfulness'],
#  'stupidity': ['imbecility', 'folly', 'betise', 'stupidity', 'foolishness'],
#  'ohsuone': [],
#  'swaps': ['trade', 'swop', 'switch', 'swap', 'barter'],
#  'ungo': [],
#  'nsmcaacadthreealaskaedu': [],
#  'persecutions': ['persecution'],
#  'natick': [],
#  'stupidthe': [],
#  'fewest': ['fewest', 'few'],
#  'fiftytwonewscolumbiaedu': [],
#  'valueadded': [],
#  'cooling': ['temperature_reduction',
#   'cool',
#   'cooling_system',
#   'chilling',
#   'cool_off',
#   'chill',
#   'cooling',
#   'cool_down'],
#  'neckrein': [],
#  'corn': ['edible_corn',
#   'corn_whiskey',
#   'corn_whisky',
#   'Zea_mays',
#   'maize',
#   'clavus',
#   'Indian_corn',
#   'corn'],
#  'slug': ['poke',
#   'stagnate',
#   'slog',
#   'type_slug',
#   'idle',
#   'lick',
#   'biff',
#   'swig',
#   'clout',
#   'laze',
#   'slug',
#   'sluggard',
#   'punch',
#   'bullet'],
#  'emptying': ['evacuation',
#   'void',
#   'voidance',
#   'abandon',
#   'discharge',
#   'evacuate',
#   'vacate',
#   'empty',
#   'emptying'],
#  'realworld': [],
#  'fifteeneight': [],
#  'projected': ['jut',
#   'visualise',
#   'figure',
#   'cast',
#   'see',
#   'envision',
#   'fancy',
#   'sticking_out',
#   'relieved',
#   'protrude',
#   'stick_out',
#   'plan',
#   'send_off',
#   'jutting',
#   'throw',
#   'contrive',
#   'externalize',
#   'projected',
#   'sticking',
#   'picture',
#   'propose',
#   'visualize',
#   'design',
#   'projecting',
#   'protruding',
#   'jut_out',
#   'externalise',
#   'image',
#   'project'],
#  'tg': [],
#  'deptrr': [],
#  'comprehend': ['dig',
#   'get_the_picture',
#   'perceive',
#   'encompass',
#   'comprehend',
#   'grok',
#   'compass',
#   'savvy',
#   'cover',
#   'grasp',
#   'embrace',
#   'apprehend'],
#  'eff': ['love',
#   'have_it_away',
#   'bonk',
#   'sleep_with',
#   'have_sex',
#   'lie_with',
#   'have_intercourse',
#   'know',
#   'do_it',
#   'have_it_off',
#   'roll_in_the_hay',
#   'bang',
#   'screw',
#   'have_a_go_at_it',
#   'make_love',
#   'bed',
#   'get_laid',
#   'make_out',
#   'sleep_together',
#   'be_intimate',
#   'fuck',
#   'eff',
#   'get_it_on',
#   'hump',
#   'jazz'],
#  'ulrichgalkitoppointde': [],
#  'freedoms': ['exemption', 'freedom'],
#  'shipyard': ['shipyard'],
#  'screwed': ['love',
#   'have_it_away',
#   'bonk',
#   'chicane',
#   'cheat',
#   'sleep_with',
#   'have_sex',
#   'chouse',
#   'lie_with',
#   'have_intercourse',
#   'drive_in',
#   'jockey',
#   'know',
#   'do_it',
#   'shaft',
#   'have_it_off',
#   'roll_in_the_hay',
#   'bang',
#   'screw',
#   'have_a_go_at_it',
#   'make_love',
#   'bed',
#   'get_laid',
#   'make_out',
#   'sleep_together',
#   'be_intimate',
#   'fuck',
#   'eff',
#   'get_it_on',
#   'hump',
#   'jazz'],
#  'adequately': ['adequately'],
#  'rose': ['climb_up',
#   'rise_up',
#   'surface',
#   'develop',
#   'spring_up',
#   'get_up',
#   'rebel',
#   'originate',
#   'uprise',
#   'wax',
#   'prove',
#   'arise',
#   'ascend',
#   'rosiness',
#   'heighten',
#   'pink_wine',
#   'rosaceous',
#   'move_up',
#   'stand_up',
#   'grow',
#   'come_up',
#   'jump',
#   'lift',
#   'mount',
#   'turn_out',
#   'climb',
#   'roseate',
#   'blush_wine',
#   'rose_wine',
#   'resurrect',
#   'rise',
#   'rose',
#   'go_up',
#   'rosebush',
#   'rear'],
#  'starrkuhubukansccedu': [],
#  'stthree': [],
#  'rummage': ['rummage', 'ransacking'],
#  'devil': ['chafe',
#   'bother',
#   'devil',
#   'annoy',
#   'Old_Nick',
#   'demon',
#   'deuce',
#   'rile',
#   'nettle',
#   'dickens',
#   'Devil',
#   'monster',
#   'irritate',
#   'the_Tempter',
#   'vex',
#   'heller',
#   'ogre',
#   'Beelzebub',
#   'Satan',
#   'fiend',
#   'gravel',
#   'rag',
#   'Prince_of_Darkness',
#   'Lucifer',
#   'daimon',
#   'get_at',
#   'hellion',
#   'daemon',
#   'get_to',
#   'nark'],
#  'hsiehipldonehaccom': [],
#  'mat': ['matt-up',
#   'lustrelessness',
#   'felt_up',
#   'mat',
#   'entangle',
#   'matte',
#   'tangle',
#   'matte_up',
#   'matting',
#   'lusterlessness',
#   'Master_of_Arts_in_Teaching',
#   'MAT',
#   'snarl',
#   'gym_mat',
#   'mat_up',
#   'matted',
#   'felt',
#   'flatness',
#   'matt',
#   'flat'],
#  'ballentine': [],
#  'happened': ['come_about',
#   'materialize',
#   'pass',
#   'befall',
#   'occur',
#   'chance',
#   'hap',
#   'encounter',
#   'take_place',
#   'go_on',
#   'fall_out',
#   'bechance',
#   'materialise',
#   'happen',
#   'find',
#   'bump',
#   'pass_off'],
#  'scheim': [],
#  'formatswe': [],
#  'incident': ['incident', 'incidental'],
#  'seaver': [],
#  'deserveless': [],
#  'hardest': ['hard',
#   'severely',
#   'arduous',
#   'gruelling',
#   'firmly',
#   'knockout',
#   'heavily',
#   'toilsome',
#   'backbreaking',
#   'operose',
#   'heavy',
#   'concentrated',
#   'grueling',
#   'intemperate',
#   'unvoiced',
#   'intemperately',
#   'strong',
#   'voiceless',
#   'tough',
#   'laborious',
#   'punishing',
#   'surd',
#   'difficult',
#   'severe'],
#  'andthree': [],
#  'vehicle': ['fomite', 'vehicle'],
#  'pals': ['chum',
#   'brother',
#   'buddy',
#   'sidekick',
#   'pal_up',
#   'pal',
#   'crony',
#   'chum_up'],
#  'fiftysixtwobdsixteendeaecsumassedu': [],
#  'eps': [],
#  'fixed': ['sterilise',
#   'secure',
#   'prepare',
#   'rigid',
#   'cook',
#   'furbish_up',
#   'define',
#   'desexualise',
#   'frozen',
#   'make',
#   'mend',
#   'fixate',
#   'unsex',
#   'limit',
#   'touch_on',
#   'desex',
#   'restore',
#   'get',
#   'sterilize',
#   'ready',
#   'bushel',
#   'set',
#   'fasten',
#   'specify',
#   'determine',
#   'fix',
#   'repair',
#   'situate',
#   'posit',
#   'set_up',
#   'fixed',
#   'pay_back',
#   'desexualize',
#   'gear_up',
#   'pay_off',
#   'doctor',
#   'deposit'],
#  'wbseventpy': [],
#  'antithetical': ['antithetical', 'antithetic'],
#  'es': ['Es',
#   'atomic_number_99',
#   'tocopherol',
#   'vitamin_E',
#   'E',
#   'due_east',
#   'east',
#   'einsteinium',
#   'eastward',
#   'e'],
#  'mazbatalari': [],
#  'mjlfoninefoeoneitisithreeunineczfortyeightfourfourgrkmkonekfourrlpeightnrm': [],
#  'protofascist': [],
#  'adjudicate': ['settle', 'adjudicate', 'try', 'resolve', 'judge', 'decide'],
#  'leights': [],
#  'kurdish': ['Kurdish'],
#  'vehemently': ['vehemently'],
#  'warming': ['thaw',
#   'warm_up',
#   'heating',
#   'calefacient',
#   'warm',
#   'thawing',
#   'warming'],
#  'lucky': ['lucky', 'golden', 'favourable', 'prosperous', 'favorable'],
#  'iris': ['flag', 'fleur-de-lis', 'iris', 'sword_lily', 'iris_diaphragm'],
#  'threefifteenthe': [],
#  'krups': [],
#  'pride': ['plume', 'pridefulness', 'superbia', 'congratulate', 'pride'],
#  'ilerlemesini': [],
#  'acme': ['acme',
#   'meridian',
#   'peak',
#   'superlative',
#   'height',
#   'pinnacle',
#   'top',
#   'vertex',
#   'summit',
#   'apex',
#   'tiptop',
#   'elevation'],
#  'inform': ['inform'],
#  'rats': ['rotter',
#   'give_away',
#   'shop',
#   'snitch',
#   'crumb',
#   'squealer',
#   'grass',
#   'lowlife',
#   'informer',
#   'stinkpot',
#   'denounce',
#   'bum',
#   'tell_on',
#   'rat',
#   'strikebreaker',
#   'blabber',
#   'so-and-so',
#   'stinker',
#   'stag',
#   'betray',
#   'scab',
#   'scum_bag',
#   'git',
#   'shit',
#   'fink',
#   'betrayer',
#   'puke',
#   'blackleg',
#   'skunk',
#   'dirty_dog'],
#  'godless': ['irreverent', 'godless'],
#  'interfered': ['interpose', 'interfere', 'step_in', 'intervene'],
#  'reaches': ['pass_on',
#   'turn_over',
#   'hit',
#   'attain',
#   'achieve',
#   'compass',
#   'make',
#   'reach_out',
#   'reaching',
#   'extend_to',
#   'stretch',
#   'range',
#   'give',
#   'arrive_at',
#   'ambit',
#   'accomplish',
#   'gain',
#   'strain',
#   'get_through',
#   'pass',
#   'get_hold_of',
#   'strive',
#   'hand',
#   'orbit',
#   'touch',
#   'contact',
#   'get_to',
#   'scope',
#   'progress_to',
#   'grasp',
#   'reach'],
#  'covering': ['cross',
#   'cover_up',
#   'spread_over',
#   'enshroud',
#   'pass_over',
#   'wrap_up',
#   'cover',
#   'plow',
#   'application',
#   'covering',
#   'breed',
#   'incubate',
#   'encompass',
#   'get_over',
#   'coating',
#   'address',
#   'embrace',
#   'traverse',
#   'natural_covering',
#   'extend',
#   'hide',
#   'masking',
#   'compensate',
#   'overcompensate',
#   'cut_through',
#   'overlay',
#   'brood',
#   'report',
#   'shroud',
#   'track',
#   'get_across',
#   'insure',
#   'hatch',
#   'continue',
#   'comprehend',
#   'underwrite',
#   'screening',
#   'treat',
#   'handle',
#   'deal',
#   'cut_across'],
#  'scorerbut': [],
#  'fortyfifteen': [],
#  'thirtyninefortythree': [],
#  'stuffs': ['ingurgitate',
#   'binge',
#   'lug',
#   'satiate',
#   'glut',
#   'gormandise',
#   'englut',
#   'shove',
#   'stuff',
#   'scarf_out',
#   'stuff_and_nonsense',
#   'poppycock',
#   'gourmandize',
#   'engorge',
#   'farce',
#   'squeeze',
#   'overeat',
#   'hooey',
#   'material',
#   'overgorge',
#   'overindulge',
#   'clobber',
#   'choke_up',
#   'block',
#   'gormandize',
#   'pig_out',
#   'thrust',
#   'gorge'],
#  'kitt': [],
#  'gunner': ['gunner', 'machine_gunner', 'cannoneer', 'artilleryman'],
#  'slavic': ['Slavonic_language', 'Slavic', 'Slavonic', 'Slavic_language'],
#  'exuberant': ['extravagant',
#   'excessive',
#   'exuberant',
#   'lush',
#   'ebullient',
#   'profuse',
#   'luxuriant',
#   'riotous',
#   'overweening',
#   'high-spirited'],
#  'though': ['though'],
#  'shined': ['beam',
#   'fall',
#   'clamber',
#   'shin',
#   'sputter',
#   'glisten',
#   'smooth',
#   'smoothen',
#   'glitter',
#   'glint',
#   'shine',
#   'shinny',
#   'skin',
#   'reflect',
#   'radiate',
#   'polish',
#   'scramble',
#   'glow',
#   'strike',
#   'gleam',
#   'struggle'],
#  'berra': ['Yogi_Berra', 'Lawrence_Peter_Berra', 'Yogi', 'Berra'],
#  'thirtytwofour': [],
#  'º': [],
#  'cutlass': ['cutlass', 'cutlas'],
#  'legacy': ['bequest', 'legacy'],
#  'maliable': [],
#  'kslenginonenosubdomainnodomain': [],
#  'antwerp': ['Antwerpen', 'Antwerp', 'Anvers'],
#  'grain': ['cereal',
#   'granulate',
#   'texture',
#   'caryopsis',
#   'metric_grain',
#   'grain',
#   'ingrain',
#   'food_grain'],
#  'inconvenient': ['inconvenient'],
#  'outputs': ['outturn',
#   'output',
#   'output_signal',
#   'turnout',
#   'yield',
#   'end_product',
#   'production'],
#  'onroad': [],
#  'lzahasacstwobuedu': [],
#  'zero': ['nothing',
#   '0',
#   'zippo',
#   'nil',
#   'cypher',
#   'nix',
#   'zip',
#   'aught',
#   'nought',
#   'zilch',
#   'goose_egg',
#   'naught',
#   'zero',
#   'nada',
#   'zero_point',
#   'zero_in',
#   'null',
#   'cipher'],
#  'wide': ['wide-eyed',
#   'wide_of_the_mark',
#   'astray',
#   'wide',
#   'across-the-board',
#   'spacious',
#   'all-embracing',
#   'encompassing',
#   'broad',
#   'panoptic',
#   'wide-cut',
#   'blanket',
#   'all-encompassing',
#   'all-inclusive',
#   'extensive',
#   'widely',
#   'full'],
#  'sulfuric': ['sulfuric', 'sulphuric'],
#  'overarching': ['overarch', 'arch_over'],
#  'slowing': ['slow_down',
#   'deceleration',
#   'retardation',
#   'slacken',
#   'slow',
#   'slowing',
#   'slow_up',
#   'slack',
#   'decelerate',
#   'retard'],
#  'allocation': ['parceling',
#   'parcelling',
#   'assignation',
#   'allotment',
#   'apportioning',
#   'allocation',
#   'storage_allocation',
#   'apportionment'],
#  'recursive': ['recursive'],
#  'þ': [],
#  'mlninetythreentzmfourzerolyfntwoesbxheightgtwolsreightcpyktad': [],
#  'sarah': ['Sarah'],
#  'basis': ['base',
#   'fundament',
#   'footing',
#   'groundwork',
#   'cornerstone',
#   'ground',
#   'basis',
#   'foundation'],
#  'infringing': ['contravene',
#   'impinge',
#   'encroach',
#   'infringe',
#   'run_afoul',
#   'conflict'],
#  'una': [],
#  'badges': ['badge'],
#  'arraingement': [],
#  'bargain': ['buy', 'steal', 'bargain', 'dicker', 'deal'],
#  'abuses': ['blackguard',
#   'maltreat',
#   'ill-treat',
#   'revilement',
#   'mistreat',
#   'clapperclaw',
#   'step',
#   'ill-usage',
#   'shout',
#   'contumely',
#   'vilification',
#   'ill-use',
#   'pervert',
#   'maltreatment',
#   'abuse',
#   'ill-treatment',
#   'insult',
#   'misuse'],
#  'rationality': ['reason', 'rationalness', 'reasonableness', 'rationality'],
#  'atypical': ['untypical', 'irregular', 'atypical'],
#  'shohkin': [],
#  'dean': ['Dean', 'James_Dean', 'James_Byron_Dean', 'doyen', 'dean'],
#  'survival': ['survival_of_the_fittest',
#   'endurance',
#   'selection',
#   'survival',
#   'natural_selection'],
#  'gravenstede': [],
#  'tempest': ['storm', 'tempest'],
#  'judys': [],
#  'gm': ['gram', 'gm', 'gramme', 'g'],
#  'grahamtphantomgatechedu': [],
#  'taxing': ['task', 'assess', 'tax', 'onerous', 'burdensome', 'taxing'],
#  'leds': ['light-emitting_diode', 'LED'],
#  'capita': ['caput', 'head'],
#  'ulowell': [],
#  'debates': ['argue',
#   'deliberate',
#   'contend',
#   'public_debate',
#   'consider',
#   'argumentation',
#   'disputation',
#   'moot',
#   'debate',
#   'fence',
#   'turn_over',
#   'argument'],
#  'acquaintance': ['conversance',
#   'friend',
#   'acquaintanceship',
#   'conversancy',
#   'familiarity',
#   'acquaintance'],
#  'mwtwofourhhnwcgbhghxhsvzonegof': [],
#  'june': ['June'],
#  'grave': ['grave_accent',
#   'dangerous',
#   'serious',
#   'sedate',
#   'engrave',
#   'inscribe',
#   'heavy',
#   'tomb',
#   'weighty',
#   'sculpt',
#   'sculpture',
#   'solemn',
#   'grievous',
#   'sober',
#   'life-threatening',
#   'severe',
#   'grave',
#   'scratch'],
#  'sebastian': [],
#  'nonneg': [],
#  'zorroastroocistempleedu': [],
#  'grease': ['filth',
#   'grime',
#   'lubricating_oil',
#   'soil',
#   'grease',
#   'dirt',
#   'grunge',
#   'stain'],
#  'epauletted': [],
#  'harrassment': [],
#  'fourteenninety': [],
#  'lodge': ['Lodge',
#   'hunting_lodge',
#   'auberge',
#   'Sir_Oliver_Lodge',
#   'order',
#   'gild',
#   'guild',
#   'social_club',
#   'hostelry',
#   'Sir_Oliver_Joseph_Lodge',
#   'wedge',
#   'charge',
#   'stick',
#   'inn',
#   'lodge',
#   'file',
#   'hostel',
#   'accommodate',
#   'society',
#   'club',
#   'deposit',
#   'indian_lodge'],
#  'harab': [],
#  'blast': ['good_time',
#   'flak',
#   'pillory',
#   'bam',
#   'attack',
#   'blow',
#   'smash',
#   'boom',
#   'eruption',
#   'knock_down',
#   'shell',
#   'flack',
#   'clap',
#   'nail',
#   'bang',
#   'savage',
#   'crucify',
#   'fire',
#   'blare',
#   'shoot',
#   'gust',
#   'blast'],
#  'determines': ['settle',
#   'check',
#   'square_up',
#   'define',
#   'find',
#   'mold',
#   'limit',
#   'shape',
#   'see',
#   'square_off',
#   'influence',
#   'decide',
#   'watch',
#   "make_up_one's_mind",
#   'set',
#   'determine',
#   'specify',
#   'fix',
#   'ascertain',
#   'learn',
#   'regulate',
#   'find_out'],
#  'lifts': ['pilfer',
#   'hook',
#   'abstract',
#   'bring_up',
# ...
#  'attributing': ['ascribe', 'assign', 'attribute', 'impute'],
#  'selfcritisism': [],
#  'pithoneqksevennuraeight': [],
#  'pulse': ['beat',
#   'pulsing',
#   'pulse',
#   'pulsation',
#   'throb',
#   'pulse_rate',
#   'impulse',
#   'heartbeat',
#   'pulsate',
#   'heart_rate'],
#  'corporate': ['embodied',
#   'collective',
#   'bodied',
#   'incarnate',
#   'incorporated',
#   'corporate',
#   'corporal'],
#  'distortions': ['deformation',
#   'torture',
#   'distorted_shape',
#   'optical_aberration',
#   'twisting',
#   'overrefinement',
#   'aberration',
#   'distortion',
#   'straining'],
#  'curcio': [],
#  'ptys': [],
#  'nowcom': [],
#  'punisher': [],
#  'phrases': ['phrase',
#   'phrasal_idiom',
#   'word',
#   'articulate',
#   'idiom',
#   'idiomatic_expression',
#   'musical_phrase',
#   'formulate',
#   'set_phrase',
#   'give_voice'],
#  'beef': ['beef',
#   'kick',
#   'squawk',
#   'bitch',
#   'grouse',
#   'crab',
#   'bellyache',
#   'holler',
#   'gripe',
#   'boeuf',
#   'beef_cattle'],
#  'barbaric': ['barbarian',
#   'barbaric',
#   'uncivilised',
#   'uncivilized',
#   'wild',
#   'savage'],
#  'calgarywinnipeg': [],
#  'aerosols': ['aerosol_bomb',
#   'spray_can',
#   'aerosol_can',
#   'aerosol_container',
#   'aerosol'],
#  'wbtwoslq': [],
#  'myntqnzhsevenwicyyfiveryothreetwoofiveqbufivejdfnineonepvbeloneha': [],
#  'jupiter': ['Jove', 'Jupiter'],
#  'prototype': ['image', 'prototype', 'epitome', 'paradigm'],
#  'selfish': ['selfish'],
#  'fourteenfourteen': [],
#  'canaanite': ['Canaanite'],
#  'windbellcorecom': [],
#  'anarchist': ['nihilist', 'syndicalist', 'anarchist'],
#  'maariv': [],
#  'turtle': ['turtleneck', 'turn_turtle', 'capsize', 'turtle', 'polo-neck'],
#  'ponder': ['contemplate',
#   'speculate',
#   'mull',
#   'chew_over',
#   'reflect',
#   'think_over',
#   'mull_over',
#   'ruminate',
#   'muse',
#   'meditate',
#   'ponder',
#   'excogitate'],
#  'hargreaves': ['James_Hargreaves', 'Hargreaves'],
#  'sixtysixeveightyoneyfourcaioneyeatwocdfourzzngqprnhonenwfourk': [],
#  'neckreining': [],
#  'barbed': ['biting',
#   'setaceous',
#   'spiny',
#   'mordacious',
#   'barbellate',
#   'briery',
#   'bristly',
#   'burry',
#   'burred',
#   'nipping',
#   'pungent',
#   'prickly',
#   'setose',
#   'briary',
#   'thorny',
#   'barbed',
#   'bristled',
#   'barb'],
#  'spoiled': ['go_bad',
#   'cross',
#   'baffle',
#   'despoil',
#   'flub',
#   'deflower',
#   'spoilt',
#   'bollix',
#   'itch',
#   'bumble',
#   'bollocks',
#   'featherbed',
#   'bollix_up',
#   'rape',
#   'plunder',
#   'pamper',
#   'botch_up',
#   'fuck_up',
#   'fluff',
#   'blow',
#   'scotch',
#   'bollocks_up',
#   'frustrate',
#   'muff',
#   'thwart',
#   'baby',
#   'spoil',
#   'fumble',
#   'louse_up',
#   'ball_up',
#   'coddle',
#   'bilk',
#   'violate',
#   'botch',
#   'queer',
#   'screw_up',
#   'bobble',
#   'cocker',
#   'foil',
#   'foul_up',
#   'cosset',
#   'corrupt',
#   'spoiled',
#   'indulge',
#   'bad',
#   'muck_up',
#   'mar',
#   'mollycoddle',
#   'mess_up',
#   'mishandle',
#   'vitiate',
#   'impair',
#   'bodge',
#   'bungle'],
#  'lantern': ['lantern'],
#  'twopfourzeroionethxxp': [],
#  'nineth': [],
#  'wmf': [],
#  'performance': ['carrying_into_action',
#   'carrying_out',
#   'execution',
#   'public_presentation',
#   'functioning',
#   'operation',
#   'performance'],
#  'svcs': [],
#  'nb': ['NB', 'N.B.', 'nota_bene', 'atomic_number_41', 'Nb', 'niobium'],
#  'naturally': ['naturally', 'of_course', 'course', 'by_nature'],
#  'ssdrelated': [],
#  'nationally': ['across_the_country',
#   'across_the_nation',
#   'nationwide',
#   'nationally'],
#  'ninetythreeaprseventeentwenty': [],
#  'fourfourteen': [],
#  'pompous': ['overblown',
#   'pompous',
#   'grandiloquent',
#   'ceremonious',
#   'pontifical',
#   'portentous'],
#  'beverly': [],
#  'scare': ['scare_away',
#   'panic_attack',
#   'scare_off',
#   'frighten_off',
#   'daunt',
#   'dash',
#   'frighten_away',
#   'fright',
#   'frighten',
#   'scare',
#   'pall',
#   'panic',
#   'affright'],
#  'rbis': ['run_batted_in', 'rbi'],
#  'marker': ['marker', 'marking', 'mark'],
#  'steelhalgnuaimitedu': [],
#  'seed': ['source',
#   'ejaculate',
#   'cum',
#   'germ',
#   'seminal_fluid',
#   'seed',
#   'come',
#   'sow',
#   'seeded_player',
#   'semen'],
#  'brazilian': ['Brazilian'],
#  'cincinnati': ['Cincinnati'],
#  'fortyonezero': [],
#  'shaun': [],
#  'favorable': ['lucky',
#   'favourable',
#   'golden',
#   'well-disposed',
#   'friendly',
#   'prosperous',
#   'favorable'],
#  'wimpy': ['wimpish', 'wimpy'],
#  'boro': [],
#  'highaltitude': [],
#  'froze': ['suspend',
#   'immobilize',
#   'freeze_down',
#   'freeze',
#   'block',
#   'immobilise',
#   'stop_dead',
#   'freeze_out'],
#  'emarshhernessunengsuncom': [],
#  'appartus': [],
#  'cock': ['sashay',
#   'peter',
#   'ruffle',
#   'cock',
#   'stopcock',
#   'prick',
#   'dick',
#   'pecker',
#   'turncock',
#   'swagger',
#   'prance',
#   'putz',
#   'shaft',
#   'hammer',
#   'strut',
#   'tittup',
#   'rooster',
#   'tool'],
#  'jay': ['Jay', 'John_Jay', 'jay'],
#  'xtninput': [],
#  'surveyed': ['review', 'appraise', 'follow', 'survey', 'surveil', 'go_over'],
#  'puny': ['puny', 'runty', 'shrimpy'],
#  'ingredients': ['factor',
#   'fixings',
#   'constituent',
#   'element',
#   'ingredient',
#   'component'],
#  'meta': [],
#  'outlines': ['draft',
#   'scheme',
#   'precis',
#   'schema',
#   'delineate',
#   'abstract',
#   'lineation',
#   'synopsis',
#   'sketch',
#   'adumbrate',
#   'limn',
#   'outline'],
#  'marshallcsugradcsvtedu': [],
#  'hal': [],
#  'mottoif': [],
#  'chunk': ['glob', 'chunk', 'ball', 'clump', 'clod', 'lump', 'collocate'],
#  'grouping': ['pigeonholing', 'aggroup', 'grouping', 'group'],
#  'co': ['Centennial_State',
#   'conscientious_objector',
#   'CO',
#   'cobalt',
#   'atomic_number_27',
#   'Colorado',
#   'carbon_monoxide',
#   'carbon_monoxide_gas',
#   'Co'],
#  'kiss': ['osculation', 'candy_kiss', 'kiss', 'buss', 'osculate', 'snog'],
#  'treked': ['trek'],
#  'treason': ['treachery',
#   'perfidy',
#   'betrayal',
#   'subversiveness',
#   'lese_majesty',
#   'treason',
#   'traitorousness',
#   'high_treason'],
#  'thirtyth': [],
#  'chromosomally': [],
#  'jensen': ['Jensen', 'Johannes_Vilhelm_Jensen'],
#  'mustard': ['mustard_greens',
#   'leaf_mustard',
#   'Indian_mustard',
#   'mustard',
#   'table_mustard'],
#  'intent': ['spirit',
#   'engrossed',
#   'intent',
#   'captive',
#   'purport',
#   'design',
#   'enwrapped',
#   'wrapped',
#   'intention',
#   'aim',
#   'absorbed',
#   'purpose'],
#  'beats': ['baffle',
#   'work_over',
#   'exhaust',
#   'pulsation',
#   'beat_out',
#   'outsmart',
#   'heartbeat',
#   'pulsate',
#   'quiver',
#   'wash_up',
#   'nonplus',
#   'tucker',
#   'vanquish',
#   'measure',
#   'beatniks',
#   'outfox',
#   'pose',
#   'trounce',
#   'circumvent',
#   'vex',
#   'thrum',
#   'mystify',
#   'cadence',
#   'perplex',
#   'get',
#   'beat_generation',
#   'tick',
#   'shell',
#   'crush',
#   'beat',
#   'pound',
#   'gravel',
#   'dumbfound',
#   'round',
#   'pulse',
#   'musical_rhythm',
#   'beat_up',
#   'flap',
#   'stick',
#   'beatnik',
#   'thump',
#   'rhythm',
#   'drum',
#   'bunk',
#   'tucker_out',
#   'scramble',
#   'overreach',
#   'flummox',
#   'outwit',
#   'meter',
#   'beats',
#   'ticktack',
#   'bewilder',
#   'amaze',
#   'metre',
#   'stupefy',
#   'puzzle',
#   'ticktock'],
#  'stopping': ['arrest',
#   'halt',
#   'check',
#   'break_off',
#   'contain',
#   'give_up',
#   'cease',
#   'barricade',
#   'lay_off',
#   'stop_over',
#   'blockade',
#   'quit',
#   'block_up',
#   'turn_back',
#   'break',
#   'hold_back',
#   'end',
#   'block_off',
#   'hold_on',
#   'fillet',
#   'finish',
#   'discontinue',
#   'bar',
#   'block',
#   'intercept',
#   'terminate',
#   'stopping',
#   'kibosh',
#   'stop'],
#  'creative': ['originative', 'creative'],
#  'sod': ['SOD',
#   'superoxide_dismutase',
#   'greensward',
#   'turf',
#   'bugger',
#   'sward',
#   'sodomist',
#   'sod',
#   'sodomite'],
#  'swiftly': ['swiftly', 'fleetly'],
#  'sspaulsonlarcnasagov': [],
#  'honored': ['observe',
#   'prestigious',
#   'respect',
#   'honored',
#   'honor',
#   'abide_by',
#   'esteemed',
#   'honour',
#   'reward'],
#  'grad': ['alumnus', 'alum', 'alumna', 'grad', 'grade', 'graduate'],
#  'sclerosis': ['sclerosis', 'induration'],
#  'seventeennine': [],
#  'producer': ['manufacturer', 'producer'],
#  'datatransfer': [],
#  'cooled': ['chill', 'cool', 'cool_down', 'cool_off'],
#  'tcl': [],
#  'descended': ['come_down',
#   'settle',
#   'derive',
#   'fall',
#   'condescend',
#   'go_down',
#   'come',
#   'deign',
#   'descend'],
#  'darkness': ['wickedness',
#   'iniquity',
#   'shadow',
#   'darkness',
#   'dark',
#   'swarthiness',
#   'duskiness'],
#  'das': ['coney', 'cony', 'hyrax', 'DA', 'district_attorney', 'das', 'dassie'],
#  'funky': ['stinking',
#   'noisome',
#   'ill-scented',
#   'foul',
#   'foetid',
#   'foul-smelling',
#   'fetid',
#   'smelly',
#   'low-down',
#   'funky'],
#  'unarmed': ['unarmed', 'unarm', 'disarm'],
#  'twelvemb': [],
#  'complexity': ['complexity', 'complexness'],
#  'threetwothree': [],
#  'jacquelin': [],
#  'complying': ['comply', 'abide_by', 'follow'],
#  'eat': ['eat_up',
#   'wipe_out',
#   'exhaust',
#   'eat_on',
#   'corrode',
#   'consume',
#   'run_through',
#   'eat',
#   'deplete',
#   'rust',
#   'use_up',
#   'feed'],
#  'billing': ['billing', 'bill', 'placard', 'charge'],
#  'ninetythreeaprtwentytwoone': [],
#  'twentytwentyeightthirtyonefortyfortythree': [],
#  'punished': ['penalise', 'penalize', 'punished', 'punish'],
#  'fostering': ['breeding',
#   'upbringing',
#   'further',
#   'nurture',
#   'fostering',
#   'raising',
#   'bringing_up',
#   'rearing',
#   'fosterage',
#   'foster'],
#  'mangoecsumdedu': [],
#  'eastren': [],
#  'bulldozed': ['bulldoze'],
#  'almost': ['near',
#   'well-nigh',
#   'virtually',
#   'almost',
#   'nearly',
#   'nigh',
#   'about',
#   'most'],
#  'possession': ['ownership',
#   'self-control',
#   'self-command',
#   'self-will',
#   'monomania',
#   'willpower',
#   'self-possession',
#   'will_power',
#   'possession'],
#  'reclamation': ['reformation', 'renewal', 'rehabilitation', 'reclamation'],
#  'missle': [],
#  'sixtyfourbit': [],
#  'wildcat': ['unauthorised',
#   'wildcat_well',
#   'unauthorized',
#   'brute',
#   'beast',
#   'wildcat',
#   'wolf',
#   'savage'],
#  'sa': ['SA', 'Storm_Troops', 'Sturmabteilung'],
#  'mccovey': [],
#  'postwar': ['postwar'],
#  'powers': ['superpower',
#   'business_leader',
#   'world_power',
#   'ability',
#   'big_businessman',
#   'baron',
#   'force',
#   'magnate',
#   'exponent',
#   'king',
#   'index',
#   'mogul',
#   'great_power',
#   'office',
#   'top_executive',
#   'tycoon',
#   'powerfulness',
#   'might',
#   'mightiness',
#   'power',
#   'major_power'],
#  'largecapacity': [],
#  'misclegal': [],
#  'attacked': ['snipe',
#   'attack',
#   'round',
#   'aggress',
#   'assail',
#   'assault',
#   'set_on',
#   'lash_out'],
#  'basics': ['BASIC',
#   'staple',
#   'basic',
#   'basic_principle',
#   'bedrock',
#   'fundamental_principle',
#   'basics',
#   'fundamentals',
#   'rudiments'],
#  'comatose': ['comatose'],
#  'lxmu': [],
#  'clamshell': ['clamshell', 'grapple'],
#  'amounts': ['quantity',
#   'number',
#   'amount',
#   'sum_of_money',
#   'add_up',
#   'come',
#   'amount_of_money',
#   'total',
#   'sum',
#   'measure'],
#  'capacit': [],
#  'viruses': ['computer_virus', 'virus'],
#  'abstracts': ['pilfer',
#   'lift',
#   'swipe',
#   'precis',
#   'hook',
#   'sneak',
#   'filch',
#   'abstract',
#   'synopsis',
#   'snarf',
#   'purloin',
#   'nobble',
#   'abstraction',
#   'pinch',
#   'outline',
#   'cabbage'],
#  'twelvefive': [],
#  'concordia': [],
#  'sez': [],
#  'licence': ['certify', 'licence', 'permit', 'license'],
#  'factsnet': [],
#  'inherently': ['inherently'],
#  'tophatone': [],
#  'bones': ['bone',
#   'get_up',
#   'osseous_tissue',
#   'bones',
#   'finger_cymbals',
#   'pearl',
#   'off-white',
#   'swot',
#   'castanets',
#   'clappers',
#   'swot_up',
#   'grind_away',
#   'bone_up',
#   'ivory',
#   'drum',
#   'cram',
#   'debone',
#   'mug_up',
#   'os'],
#  'distributed': ['pass_on',
#   'dish_out',
#   'mete_out',
#   'dole_out',
#   'pass_around',
#   'dispense',
#   'diffuse',
#   'pass_out',
#   'distributed',
#   'disseminate',
#   'deal_out',
#   'propagate',
#   'hand_out',
#   'lot',
#   'disperse',
#   'circulate',
#   'circularize',
#   'parcel_out',
#   'stagger',
#   'give_out',
#   'distribute',
#   'administer',
#   'allot',
#   'broadcast',
#   'spread',
#   'circularise',
#   'deal',
#   'shell_out'],
#  'codriver': [],
#  'triumph': ['jubilate',
#   'triumph',
#   'gloat',
#   'exuberate',
#   'wallow',
#   'victory',
#   'prevail',
#   'exult',
#   'crow',
#   'rejoice'],
#  'fruition': ['realization', 'realisation', 'fruition'],
#  'stubbornness': ['pigheadedness',
#   'self-will',
#   'obstinacy',
#   'stubbornness',
#   'obstinance',
#   'mulishness',
#   'bullheadedness'],
#  'tenyearolds': [],
#  'infoqdeckcom': [],
#  'myerscsscarolinaedu': [],
#  'bare': ['mere',
#   'simple',
#   'unembellished',
#   'spare',
#   'publicise',
#   'naked',
#   'plain',
#   'scanty',
#   'publicize',
#   'au_naturel',
#   'stripped',
#   'marginal',
#   'strip',
#   'air',
#   'bare',
#   'stark',
#   'denudate',
#   'denude',
#   'nude',
#   'unsheathed',
#   'barren',
#   'desolate',
#   'unfinished',
#   'unornamented',
#   'bleak'],
#  'verify': ['swan',
#   'aver',
#   'assert',
#   'verify',
#   'avow',
#   'swear',
#   'control',
#   'affirm'],
#  'sixtyeightunocalcom': [],
#  'reencode': [],
#  'throw': ['discombobulate',
#   'make',
#   'shed',
#   'confuse',
#   'have',
#   'cast',
#   'drop',
#   'confound',
#   'give',
#   'throw_away',
#   'bemuse',
#   'flip',
#   'cast_off',
#   'hold',
#   'hurl',
#   'bedevil',
#   'fox',
#   'fuddle',
#   'befuddle',
#   'switch',
#   'throw_off',
#   'throw',
#   'contrive',
#   'stroke',
#   'cam_stroke',
#   'bewilder',
#   'thrust',
#   'shake_off',
#   'project'],
#  'imaging': ['imaging',
#   'see',
#   'picture',
#   'visualize',
#   'envision',
#   'visualise',
#   'figure',
#   'image',
#   'imagery',
#   'imagination',
#   'tomography',
#   'fancy',
#   'mental_imagery',
#   'project'],
#  'lap': ['circuit',
#   'circle',
#   'lap',
#   'swosh',
#   'lap_up',
#   'lick',
#   'lap_covering',
#   'swish',
#   'swoosh',
#   'lave',
#   'overlap',
#   'wash'],
#  'localbus': [],
#  'curent': [],
#  'mikkotromulusmathjyufi': [],
#  'nonflammable': ['nonflammable'],
#  'expansionlust': [],
#  'ditucci': [],
#  'leaguers': [],
#  'xtgetvalueswidget': [],
#  'answered': ['answer',
#   'resolve',
#   'suffice',
#   'reply',
#   'respond',
#   'serve',
#   'do'],
#  'mtwentyoneengstratuscom': [],
#  'starman': [],
#  'techopscraycom': [],
#  'shows': ['establish',
#   'evidence',
#   'evince',
#   'display',
#   'record',
#   'demonstrate',
#   'show',
#   'present',
#   'read',
#   'prove',
#   'depict',
#   'testify',
#   'indicate',
#   'register',
#   'point',
#   'demo',
#   'shew',
#   'show_up',
#   'render',
#   'picture',
#   'usher',
#   'exhibit',
#   'bear_witness',
#   'express',
#   'designate',
#   'appearance'],
#  'pax': ['pax', 'kiss_of_peace'],
#  'invoked': ['put_forward',
#   'arouse',
#   'call_down',
#   'conjure',
#   'bring_up',
#   'call_forth',
#   'stir',
#   'invoke',
#   'evoke',
#   'conjure_up',
#   'raise',
#   'appeal'],
#  'mattone': [],
#  'rgolderhohmbledu': [],
#  'twothirtypm': [],
#  'credit': ['citation',
#   'recognition',
#   'credit_entry',
#   'course_credit',
#   'cite',
#   'reference',
#   'acknowledgment',
#   'deferred_payment',
#   'quotation',
#   'mention',
#   'accredit',
#   'credit_rating',
#   'credit'],
#  'highlow': [],
#  'hoviguxacsouiucedu': [],
#  'highspeed': [],
#  'ohio': ['OH', 'Ohio', 'Buckeye_State', 'Ohio_River'],
#  'salads': ['salad'],
#  'ninetyfivem': [],
#  'knocked': ['rap',
#   'ping',
#   'pick_apart',
#   'strike_hard',
#   'knock',
#   'bump',
#   'pink',
#   'criticise',
#   'tap',
#   'criticize'],
#  'pendulum': ['pendulum'],
#  'od': ['oculus_dexter', 'OD', 'Doctor_of_Optometry'],
#  'consent': ['go_for', 'consent', 'accept'],
#  'jerking': ['jerking',
#   'jerk',
#   'twitch',
#   'arrhythmic',
#   'flick',
#   'buck',
#   'yank',
#   'jolt',
#   'jerky',
#   'hitch',
#   'saccade'],
#  'desktop': ['background', 'desktop', 'screen_background'],
#  'egyptian': ['Egyptian'],
#  'madamme': [],
#  'buzyquadsuchicagoedu': [],
#  'straw': ['stubble',
#   'drinking_straw',
#   'pale_yellow',
#   'stalk',
#   'shuck',
#   'strew',
#   'straw',
#   'chaff',
#   'wheat',
#   'husk'],
#  'collectively': ['collectively', 'jointly', 'together_with', 'conjointly'],
#  'colonists': ['settler', 'colonist'],
#  'modernist': ['modernist'],
#  'ninetwentyone': [],
#  'garron': [],
#  'vowels': ['vowel', 'vowel_sound'],
#  'childt': [],
#  'exception': ['exception', 'exclusion', 'elision'],
#  'schwimmer': [],
#  'amino': ['amino', 'aminic', 'amino_group'],
#  'allegedly': ['allegedly'],
#  'recalls': ['hark_back',
#   'echo',
#   'call_back',
#   'think',
#   'withdraw',
#   'remember',
#   'call_in',
#   'reminiscence',
#   'callback',
#   'call_up',
#   'retrieve',
#   'recollection',
#   'return',
#   'recollect',
#   'recall',
#   'come_back'],
#  'fiftysixtwentytwo': [],
#  'utexas': [],
#  'fifteennineteenyear': [],
#  'preprocesses': [],
#  'umr': [],
#  'powerless': ['powerless'],
#  'reactions': ['reaction', 'chemical_reaction', 'response'],
#  ...}

# %%
with open('weights/en_similars_dict.pkl', 'wb') as f:
    pickle.dump(similar_words_dict, f)

# %%
TA = TextAugmenter(lang='en')
# Out:
# Language: English

# %% [markdown]
# # Random

# %%
contents[0]
# Out:
# 'from rrnpocwruedu robert r novitskey\nsubject cyclone and tempest\narticleid usenetonepskavqtu\nreplyto rrnpocwruedu robert r novitskey\norganization case western reserve university cleveland oh usa\nlines ten\nnntppostinghost thorinscwruedu\n\n\ncould someone please post any info on these systems\n\nthanks\nbob\n \n \nrobert novitskey  pursuing women is similar to banging ones head\nrrnpocwruedu    against a wallwith less opportunity for reward \n \n'

# %%
sentence = contents[0]
p = 0.1
print(' '.join(TA.aug_by_deletion(text=sentence,p=p,mode='random')))
print(' '.join(TA.aug_by_replacement(text=sentence,p=p,mode='random')))
print(' '.join(TA.aug_by_insertion(text=sentence,p=p,mode='random')))
print(' '.join(TA.aug_by_swap(text=sentence,p=p,mode='random')))
# Out:
# from rrnpocwruedu robert r novitskey subject cyclone and usenetonepskavqtu replyto rrnpocwruedu r novitskey organization case western cleveland oh usa lines ten thorinscwruedu could someone please post any info on systems thanks bob robert novitskey pursuing women is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for
# from rrnpocwruedu robert roentgen novitskey subject cyclone and storm articleid usenetonepskavqtu replyto rrnpocwruedu robert roentgen novitskey organization incase western reserve university President_Cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob robert novitskey act_on women is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# from rrnpocwruedu robert please r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please ten-spot post any Henry_Martyn_Robert info info on these systems thanks bob robert novitskey pursuing women is similar to banging ones Cleveland head rrnpocwruedu against a wallwith less opportunity for reward
# oh bob robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization case western reserve university someone from usa lines ten nntppostinghost thorinscwruedu could cleveland please post any info robert these systems thanks rrnpocwruedu against novitskey pursuing women is similar to banging ones head rrnpocwruedu on a wallwith less opportunity for reward

# %% [markdown]
# # Selective

# %%
print(' '.join(TA.aug_by_deletion(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_replacement(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_insertion(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_swap(text=sentence,p=p,mode='selective',selected_words=['comedy','election'])))
print(' '.join(TA.aug_by_selection(text=sentence, selected_words=['comedy','election'])))
# Out:
# from rrnpocwruedu robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob robert novitskey pursuing women is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# from rrnpocwruedu Robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu Robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob Robert novitskey pursuing char is similar to banging one head rrnpocwruedu against a wallwith less opportunity for reward
# from rrnpocwruedu robert r novitskey subject cyclone and tempest articleid situation usenetonepskavqtu replyto rrnpocwruedu robert r lawsuit novitskey organization case western reserve university casing cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob robert novitskey pursuing women is similar to banging ones head rrnpocwruedu dock against a wallwith less opportunity point for reward
# from rrnpocwruedu robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization women someone reserve similar cleveland oh usa lines ten nntppostinghost thorinscwruedu could western post please any info on these systems thanks bob robert novitskey to case is university pursuing banging ones head rrnpocwruedu against a wallwith less opportunity for reward

# %%
# read saved keywords
name = 'sst2'
global_kws_dict_path = f'saved_keywords/global_kws_dict_{name}.pkl'
with open(global_kws_dict_path, 'rb') as f:
    global_kws_dict = pickle.load(f)

# %%
global_kws_dict
# Out:
# {'1': {'lr': ['love',
#    'wonderful',
#    'style',
#    'powerful',
#    'wise',
#    'whose',
#    'ways',
#    'touching',
#    'solid',
#    'power',
#    'lot',
#    'sweet',
#    'summer',
#    'satisfying',
#    'pleasure',
#    'nine',
#    'man',
#    'imaginative',
#    'history',
#    'him',
#    'fare',
#    'culture',
#    'considerable',
#    'cinema',
#    'good',
#    'worthy',
#    'watchable',
#    'warmth',
#    'unexpected',
#    'surprisingly',
#    'stuart',
#    'saving',
#    'proves',
#    'occasionally',
#    'occasional',
#    'modern',
#    'manages',
#    'lovely',
#    'looks',
#    'laughs',
#    'inventive',
#    'ingenious',
#    'horrifying',
#    'honest',
#    'giving',
#    'gentle',
#    'find',
#    'fantastic',
#    'especially',
#    'enjoyable',
#    'cinematic',
#    'chance',
#    'capable',
#    'brings',
#    'atmosphere',
#    'amusing',
#    'fun',
#    'yet',
#    'yesterday',
#    'yarn',
#    'wow',
#    'works',
#    'wispy',
#    'whether',
#    'weighty',
#    'vivid',
#    'vibrant',
#    'version',
#    'verbal',
#    'unique',
#    'undeniable',
#    'twentyth',
#    'true',
#    'themselves',
#    'terrifying',
#    'tender',
#    'televised',
#    'talented',
#    'sympathetic',
#    'sweetness',
#    'surprising',
#    'succeeds',
#    'study',
#    'struggling',
#    'strange',
#    'status',
#    'star',
#    'stand',
#    'splendid',
#    'spirit',
#    'spielberg',
#    'sophisticated',
#    'smartly',
#    'sly',
#    'selfglorification',
#    'seat',
#    'season',
#    'sea',
#    'scottish',
#    'scoobydoo',
#    'sally',
#    'sad',
#    'roles',
#    'ripping',
#    'rewards',
#    'results',
#    'resonant',
#    'reruns',
#    'rendered',
#    'refreshingly',
#    'read',
#    'raphael',
#    'pure',
#    'provides',
#    'profound',
#    'pop',
#    'political',
#    'pleasant',
#    'players',
#    'pitchperfect',
#    'photographed',
#    'philadelphia',
#    'perfectly',
#    'paradiso',
#    'observation',
#    'mythic',
#    'moving',
#    'moved',
#    'morality',
#    'minor',
#    'mind',
#    'memorable',
#    'meditation',
#    'masterpiece',
#    'masterfully',
#    'masterful',
#    'manner',
#    'magic',
#    'lives',
#    'lively',
#    'layers',
#    'largerthanlife',
#    'lane',
#    'laidback',
#    'kwan',
#    'knowing',
#    'keeping',
#    'jolt',
#    'jesse',
#    'jaunt',
#    'involved',
#    'intimate',
#    'interest',
#    'inspired',
#    'influenced',
#    'imagination',
#    'images',
#    'human',
#    'honestly',
#    'hilarious',
#    'heartfelt',
#    'heart',
#    'gutwrenching',
#    'grew',
#    'gracefully',
#    'goodly',
#    'glides',
#    'gestalt',
#    'genres',
#    'gasp',
#    'gas',
#    'fulfilling',
#    'fresh',
#    'frequently',
#    'france',
#    'follow',
#    'fisher',
#    'fiascos',
#    'female',
#    'feelgood',
#    'feat',
#    'fascination',
#    'eye',
#    'exhilarating',
#    'era',
#    'entertainment',
#    'entertaining',
#    'engaged',
#    'emperor',
#    'elegance',
#    'eightynine',
#    'economical',
#    'earnest',
#    'each',
#    'directly',
#    'deserves',
#    'deportment',
#    'depiction',
#    'delicately',
#    'deeply',
#    'dazzling',
#    'creative',
#    'creates',
#    'crack',
#    'conceptual',
#    'compelling',
#    'committed',
#    'comedies',
#    'club',
#    'class',
#    'clarity',
#    'chord',
#    'check',
#    'charm',
#    'certainly',
#    'bracing',
#    'bombastic',
#    'beloved',
#    'believable',
#    'beings',
#    'beat',
#    'awarded',
#    'astonishing',
#    'artistic',
#    'anyone',
#    'antwone',
#    'adventure',
#    'accomplished',
#    'absorbing',
#    'absolutely',
#    'one',
#    'most',
#    'and',
#    'funny',
#    'well',
#    'humor',
#    'while',
#    'family',
#    'drama',
#    'zwick',
#    'younger',
#    'yearnings',
#    'yearning',
#    'wrought',
#    'writerdirectors',
#    'wound',
#    'worthwhile',
#    'worldlywise',
#    'woodman',
#    'wonderfully',
#    'won',
#    'woman',
#    'wo',
#    'wizened',
#    'witty',
#    'wistfully',
#    'wistful',
#    'wish',
#    'wisegirls',
#    'winking',
#    'window',
#    'windinthehair',
#    'wind',
#    'win',
#    'willing',
#    'wildly',
#    'why',
#    'white',
#    'whimsy',
#    'whatif',
#    'welsh',
#    'wellintentioned',
#    'welldeveloped',
#    'wellbehaved',
#    'wellbalanced',
#    'weirdly',
#    'weird',
#    'weepy',
#    'watts',
#    'wasp',
#    'washington',
#    'warrior',
#    'wanting',
#    'vulnerability',
#    'voices',
#    'vividly',
#    'vital',
#    'visually',
#    'vistas',
#    'visceral',
#    'vintage',
#    'view',
#    'verve',
#    'versus',
#    'versatile',
#    'verdict',
#    'venice',
#    'veggies',
#    'vanity',
#    'usual',
#    'urge',
#    'urban',
#    'ups',
#    'upping',
#    'uplifting',
#    'unseemly',
#    'unruly',
#    'universal',
#    'uniquely',
#    'unhinged',
#    'unhibited',
#    'unexpectedly',
#    'understands',
#    'understand',
#    'underbelly',
#    'under',
#    'unadulterated',
#    'unabashedly',
#    'type',
#    'twin',
#    'twelveyearold',
#    'truths',
#    'truffaut',
#    'truecrime',
#    'triumphs',
#    'trilogy',
#    'tremendous',
#    'treat',
#    'traveler',
#    'trap',
#    'transition',
#    'transcends',
#    'transcendence',
#    'tranquil',
#    'traditional',
#    'tradition',
#    'towering',
#    'topnotch',
#    'top',
#    'titular',
#    'tiny',
#    'timeconsuming',
#    'ticking',
#    'thumbs',
#    'throughout',
#    'threed',
#    'thoughtful',
#    'thirtythree',
#    'thanks',
#    'thankfully',
#    'technology',
#    'technical',
#    'tattoos',
#    'tasty',
#    'taste',
#    'talk',
#    'talents',
#    't',
#    'swung',
#    'swooning',
#    'swim',
#    'sweatypalmed',
#    'swallow',
#    'suspenseful',
#    'suspended',
#    'surprises',
#    'surefire',
#    'supremely',
#    'sundrenched',
#    'suits',
#    'suggest',
#    'sugar',
#    'succeeded',
#    'succeed',
#    'suburban',
#    'subtly',
#    'subtlety',
#    'subtle',
#    'subsequent',
#    'subculture',
#    'stylists',
#    'stylishly',
#    'stylish',
#    'stunning',
#    'struggles',
#    'strike',
#    'strength',
#    'strangely',
#    'straight',
#    'storyline',
#    'stoked',
#    'stitch',
#    'stirs',
#    'stirring',
#    'stimulating',
#    'stillinestimable',
#    'stickiness',
#    'stevens',
#    'steven',
#    'stepmom',
#    'step',
#    'stays',
#    'startling',
#    'starting',
#    'start',
#    'stars',
#    'stanzas',
#    'stanley',
#    'standard',
#    'stage',
#    'square',
#    'spy',
#    'sprung',
#    'spoton',
#    'sportsmen',
#    'spooky',
#    'spirits',
#    'spikes',
#    'spike',
#    'spiffy',
#    'spiderman',
#    'spell',
#    'specimen',
#    'speaks',
#    'spaces',
#    'sounding',
#    'souls',
#    'soulful',
#    'sorrow',
#    'sonny',
#    'songs',
#    'somehow',
#    'solutions',
#    'solidly',
#    'soderbergh',
#    'sobering',
#    'sneering',
#    'smiles',
#    'slightly',
#    'sleeper',
#    'skins',
#    'skilled',
#    'siren',
#    'sincerity',
#    'sincerely',
#    'sincere',
#    'since',
#    'simplistic',
#    'significance',
#    'siegel',
#    'side',
#    'sibling',
#    'showdown',
#    'showcases',
#    'shockingly',
#    'shiner',
#    'shine',
#    'sharply',
#    'sharp',
#    'shared',
#    'share',
#    'shafer',
#    'seventys',
#    'sets',
#    'setpieces',
#    'servants',
#    'sequences',
#    'sentiments',
#    'sentimentality',
#    'sensitivity',
#    'sensitive',
#    'sensational',
#    'selfexpression',
#    'secretly',
#    'seamy',
#    'scripting',
#    'scotland',
#    'scoring',
#    'scope',
#    'sci',
#    'schtick',
#    'scenario',
#    'scariest',
#    'saw',
#    'saucy',
#    'satisfies',
#    'sardonic',
#    'sarandon',
#    'sand',
#    'sanctimoniousness',
#    'salton',
#    'saga',
#    'sade',
#    'sabotage',
#    'ryan',
#    'russian',
#    'routines',
#    'romoli',
#    'roman',
#    'rohmer',
#    'rocky',
#    'rocks',
#    'roars',
#    'rivals',
#    'rising',
#    'rises',
#    'riproaring',
#    'ripening',
#    'ride',
#    'rewarding',
#    'revolutionary',
#    'revenge',
#    'revelations',
#    'reveals',
#    'revealing',
#    'reunion',
#    'retooled',
#    'retains',
#    'result',
#    'respectable',
#    'resourceful',
#    'resistance',
#    'represents',
#    'reminiscent',
#    'remarkable',
#    'remaining',
#    'relegated',
#    'relatively',
#    'reinvention',
#    'reggio',
#    'refreshed',
#    'reflected',
#    'reconciliation',
#    'recommendation',
#    'rebel',
#    'reassuring',
#    'reasonable',
#    'reap',
#    'realistic',
#    'readymade',
#    'ravishing',
#    'ravaging',
#    'rarity',
#    'rapidfire',
#    'rap',
#    'ranks',
#    'range',
#    'ramifications',
#    'rae',
#    'race',
#    'quiet',
#    'questions',
#    'qatsi',
#    'pursuing',
#    'purists',
#    'purely',
#    'punctuation',
#    'punch',
#    'puff',
#    'prowildlife',
#    'prove',
#    'proud',
#    'proposal',
#    'prophet',
#    'project',
#    'producer',
#    'process',
#    'problem',
#    'private',
#    'pristine',
#    'principles',
#    'princess',
#    'prime',
#    'pretension',
#    'press',
#    'president',
#    'presentation',
#    'presence',
#    'prefer',
#    'precisely',
#    'potential',
#    'potent',
#    'positive',
#    'portrait',
#    'popcorn',
#    'politically',
#    'police',
#    'polanski',
#    'poetry',
#    'playwriting',
#    'playlist',
#    'playfully',
#    'pipeline',
#    'pill',
#    'piercing',
#    'pie',
#    'picked',
#    'pianist',
#    'philosophical',
#    'philippe',
#    'philip',
#    'phantom',
#    'petter',
#    'pertinent',
#    'persuasive',
#    'perspective',
#    'performed',
#    'perfect',
#    'penetrating',
#    'peels',
#    'peek',
#    'peaks',
#    'path',
#    'partnership',
#    'partisans',
#    'parody',
#    'parents',
#    'parable',
#    'par',
#    'paper',
#    'paintings',
#    'outrageousness',
#    'outing',
#    'others',
#    'originality',
#    'orbit',
#    'optimism',
#    'opportunities',
#    'openness',
#    'opening',
#    'oozing',
#    'oncamera',
#    'oliver',
#    'offbeat',
#    'odd',
#    'occupational',
#    'næss',
#    'nutty',
#    'nurtured',
#    'numerous',
#    'number',
#    'nuance',
#    'novel',
#    'novak',
#    'note',
#    'notable',
#    'nostalgia',
#    'nononsense',
#    'nonjudgmental',
#    'nonexploitive',
#    'nomination',
#    'noir',
#    'noble',
#    'ninth',
#    'ninetythree',
#    'nijinsky',
#    'nickelodeonesque',
#    'nicely',
#    'newfangled',
#    'newcomers',
#    'net',
#    'needs',
#    'necessarily',
#    'neat',
#    'nearimpossible',
#    'navigate',
#    'naughty',
#    'natured',
#    'naturally',
#    'natural',
#    'native',
#    'nail',
#    'na',
#    'myth',
#    'must',
#    'mtv',
#    'movements',
#    'movement',
#    'move',
#    'motion',
#    'morvern',
#    'morrison',
#    'mood',
#    'modest',
#    'moderately',
#    'models',
#    'mob',
#    'mixture',
#    'mix',
#    'missive',
#    'miracle',
#    'mindbending',
#    'midwest',
#    'mib',
#    'metaphors',
#    'mesmerizing',
#    'mesmerised',
#    'merrily',
#    'menace',
#    'memorial',
#    'melodramatic',
#    'melodrama',
#    'mel',
#    'meddles',
#    'meaningful',
#    'maxim',
#    'maturity',
#    'mature',
#    'matters',
#    'mattered',
#    'matron',
#    'match',
#    'mariah',
#    'manage',
#    'mamet',
#    'magical',
#    'machine',
#    'lovingly',
#    'loves',
#    'loved',
#    'lothario',
#    'local',
#    'loaded',
#    'living',
#    'livestyle',
#    'littleknown',
#    'literate',
#    'lips',
#    'lingers',
#    'lingerie',
#    'lines',
#    'lilo',
#    'liked',
#    'lighthearted',
#    'light',
#    'lifechanging',
#    'lie',
#    'liberating',
#    'liar',
#    'levity',
#    'let',
#    'leonine',
#    'lend',
#    'legend',
#    'leave',
#    'learn',
#    'layered',
#    'laughoutloud',
#    'laughed',
#    'laughable',
#    'laugh',
#    'largestever',
#    'larger',
#    'large',
#    'lanes',
#    'lady',
#    'lad',
#    'klein',
#    'kinky',
#    'king',
#    'kineticallycharged',
#    'kidman',
#    'kiddie',
#    'kicking',
#    'kibbitzes',
#    'keeps',
#    'keen',
#    'jumpinyourseat',
#    'juliette',
#    'joys',
#    'jesus',
#    'jazzy',
#    'jake',
#    'jaded',
#    'jack',
#    'j',
#    'introspective',
#    'intriguing',
#    'intrigue',
#    'intoxication',
#    'intimacy',
#    'interpretation',
#    'intermittently',
#    'intentions',
#    'intense',
#    'intact',
#    'instructive',
#    'instincts',
#    'inspiring',
#    'insightfully',
#    'inquisitiveness',
#    'inoffensive',
#    'innocent',
#    'inherent',
#    'inhabit',
#    'infused',
#    'infuse',
#    'informative',
#    'information',
#    'infectious',
#    'individual',
#    'indecent',
#    'increasingly',
#    'impressive',
#    'impressionable',
#    'impossible',
#    'importance',
#    'impenetrable',
#    'immaculate',
#    'imaginable',
#    'illusion',
#    'ii',
#    'ignored',
#    'igby',
#    'iconography',
#    'iconoclastic',
#    'ian',
#    'hysteria',
#    'hybrid',
#    'huston',
#    'huskies',
#    'humming',
#    'humanly',
#    'hugescreen',
#    'huge',
#    'house',
#    'host',
#    'horrendously',
#    'hope',
#    'homage',
#    'holm',
#    'holiday',
#    'holden',
#    'hits',
#    'hitman',
#    'hitch',
#    'hip',
#    'highlighted',
#    'highconcept',
#    'heroine',
#    'hermetic',
#    'heritage',
#    'helping',
#    'helljaunt',
#    'hellbent',
#    'held',
#    'heights',
#    'heck',
#    'heaven',
#    'heartbreaking',
#    'heard',
#    'hear',
#    'head',
#    'haunting',
#    'harmless',
#    'hardwon',
#    'hanks',
#    'halfway',
#    'halfbad',
#    'gyllenhaal',
#    'gut',
#    'guffaw',
#    'grueling',
#    'growth',
#    'grow',
#    'group',
#    'grounded',
#    'gritty',
#    'gripping',
#    'greatest',
#    'grateful',
#    'graces',
#    'grace',
#    'goofball',
#    'goodness',
#    'goodnaturedly',
#    'gon',
#    'golf',
#    'golden',
#    'godfrey',
#    'goddammit',
#    'goals',
#    'gluing',
#    'glow',
#    'globe',
#    'glitter',
#    'glimpse',
#    'glass',
#    'gives',
#    'given',
#    'girlmeetsgirl',
#    'giggle',
#    'gifts',
#    'gifted',
#    'gianni',
#    'gets',
#    'genuine',
#    'gangster',
#    'games',
#    'gallic',
#    'fused',
#    'further',
#    'funniest',
#    'funloving',
#    'fruitful',
#    'frissons',
#    'friendships',
#    'friendship',
#    'frida',
#    'freshness',
#    'frenchproduced',
#    'french',
#    'freedom',
#    'franklin',
#    'frank',
#    'frames',
#    'frailty',
#    'fragile',
#    'forward',
#    'form',
#    'forget',
#    'fore',
#    'force',
#    'food',
#    'fluidity',
#    'fluid',
#    'flowery',
#    'flow',
#    'flourish',
#    'flawless',
#    'flatout',
#    'flashes',
#    'flash',
#    'flamboyant',
#    'fixating',
#    'fit',
#    'firstclass',
#    'finelooking',
#    'fine',
#    'finally',
#    'filmmaker',
#    'filmgoing',
#    'filmed',
#    'fights',
#    'fight',
#    'fiftyseven',
#    'fi',
#    'festival',
#    'fessenden',
#    'felt',
#    'features',
#    'favor',
#    'fat',
#    'fastmoving',
#    'fashion',
#    'fascinating',
#    'fantasy',
#    'fantasized',
#    'fanboy',
#    'fanatics',
#    'familyoriented',
#    'false',
#    'falling',
#    'fall',
#    'faith',
#    'fact',
#    'eyre',
#    'extraordinarily',
#    'extra',
#    'expressiveness',
#    'expressing',
#    'exploring',
#    'explores',
#    'explore',
#    'experimental',
#    'expectations',
#    'expectation',
#    'exists',
#    'existential',
#    'existed',
#    'executed',
#    'exceptional',
#    'exceedingly',
#    'examination',
#    'evil',
#    'evenings',
#    'ethnic',
#    'ethics',
#    'ethical',
#    'established',
#    'essentially',
#    'escapist',
#    'errors',
#    'eric',
#    'equal',
#    'enthusiasm',
#    'enthralling',
#    'enthrall',
#    'ensemble',
#    'enjoys',
#    ...],
#   'ls': ['three',
#    'nine',
#    'third',
#    'two',
#    'second',
#    'starting',
#    'midnight',
#    'nearly',
#    'b',
#    'half',
#    'first',
#    'than',
#    'each',
#    'less',
#    'stuart',
#    'remaining',
#    'on',
#    'date',
#    'ninth',
#    'in',
#    'zwick',
#    'writerdirectors',
#    'worldlywise',
#    'wisegirls',
#    'windinthehair',
#    'whatif',
#    'wellintentioned',
#    'welldeveloped',
#    'wellbehaved',
#    'wellbalanced',
#    'unhibited',
#    'twohourandfifteenminute',
#    'twentytwoyearold',
#    'twentyth',
#    'twelveyearold',
#    'truffaut',
#    'truecrime',
#    'to',
#    'threed',
#    'thirtythree',
#    'the',
#    'sweatypalmed',
#    'stillinestimable',
#    'spoton',
#    'spiritcrushing',
#    'spielberg',
#    'sorvino',
#    'soderbergh',
#    'siegel',
#    'shafer',
#    'seventys',
#    'selfsatisfied',
#    'selfglorification',
#    'selfexpression',
#    'scoobydoo',
#    'sarandon',
#    'salton',
#    'sade',
#    'romoli',
#    'rohmer',
#    'reggio',
#    'raphael',
#    'qatsi',
#    'prowildlife',
#    'polanski',
#    'pitchperfect',
#    'petter',
#    'partyhearty',
#    'paradiso',
#    'oncamera',
#    'of',
#    'næss',
#    'nonexploitive',
#    'ninetythree',
#    'nijinsky',
#    'nickelodeonesque',
#    'nearimpossible',
#    'morvern',
#    'mib',
#    'mesmerised',
#    'mamet',
#    'livestyle',
#    'laughoutloud',
#    'largestever',
#    'largerthanlife',
#    'kineticallycharged',
#    'kibbitzes',
#    'jumpinyourseat',
#    'juliette',
#    'igby',
#    'huston',
#    'hugescreen',
#    'highconcept',
#    'helljaunt',
#    'hardwon',
#    'halfbad',
#    'gyllenhaal',
#    'godfrey',
#    'girlmeetsgirl',
#    'gianni',
#    'frida',
#    'frenchproduced',
#    'finelooking',
#    'fiftyseven',
#    'fessenden',
#    'fastmoving',
#    'familyoriented',
#    'eyre',
#    'eightynine',
#    'eightyeight',
#    'eighteenyearold',
#    'duvall',
#    'deadon',
#    'cremaster',
#    'connectthedots',
#    'comingofage',
#    'coen',
#    'cockettes',
#    'churchwary',
#    'chabrol',
#    'campaigntrail',
#    'callar',
#    'binoche',
#    'balto',
#    'aweinspiring',
#    'auteuil',
#    'assayas',
#    'antwone',
#    'and',
#    'a',
#    'ends',
#    'final',
#    'extra',
#    'versus',
#    'last',
#    'effective',
#    'ii',
#    'set',
#    'one',
#    'halfway',
#    'every',
#    'at',
#    'j',
#    'completion',
#    'held',
#    'top',
#    'since',
#    'goes',
#    'will',
#    'jesse',
#    'equal',
#    'between',
#    'square',
#    'for',
#    'takes',
#    'just',
#    'which',
#    'least',
#    'ages',
#    'subsequent',
#    'modest',
#    'hugh',
#    'almost',
#    'sandra',
#    'alone',
#    'start',
#    'another',
#    'go',
#    'short',
#    'from',
#    'slightly',
#    'showdown',
#    'allen',
#    's',
#    'dropped',
#    'then',
#    'novak',
#    'only',
#    'mature',
#    'ryan',
#    'twin',
#    'more',
#    'stevens',
#    'mark',
#    'win',
#    'take',
#    'philadelphia',
#    'sleeper',
#    'by',
#    'net',
#    'over',
#    'worth',
#    'else',
#    'after',
#    'wo',
#    'blockbuster',
#    'special',
#    'or',
#    'through',
#    'reasonable',
#    'beat',
#    'status',
#    'ca',
#    'daniel',
#    'stays',
#    'anywhere',
#    'france',
#    'accumulated',
#    'all',
#    'would',
#    'cut',
#    'hits',
#    'beats',
#    'won',
#    'sets',
#    'off',
#    'this',
#    'mtv',
#    'same',
#    'full',
#    'opening',
#    'oliver',
#    'it',
#    'barry',
#    'eric',
#    'going',
#    'value',
#    'hold',
#    'respectable',
#    'an',
#    'jake',
#    'up',
#    'stunning',
#    'gets',
#    'number',
#    'i',
#    'stanley',
#    'realistic',
#    'betting',
#    'high',
#    'target',
#    'cost',
#    'adults',
#    'dual',
#    'moved',
#    'action',
#    'thriller',
#    'both',
#    'moderately',
#    'step',
#    'hours',
#    'tom',
#    'probably',
#    'due',
#    'sensational',
#    'rises',
#    'missing',
#    'day',
#    'class',
#    'concerned',
#    'born',
#    'balance',
#    'long',
#    'fantasy',
#    'back',
#    'share',
#    'season',
#    'him',
#    'amounts',
#    'prime',
#    'par',
#    'ups',
#    'anything',
#    'joel',
#    'golden',
#    'mariah',
#    'arc',
#    'chicago',
#    'feeling',
#    'mixture',
#    'end',
#    'range',
#    'carey',
#    'carries',
#    'bold',
#    'giving',
#    'huge',
#    'saturday',
#    'essentially',
#    'feat',
#    'chance',
#    'original',
#    'sonny',
#    't',
#    'minutes',
#    'decent',
#    'robert',
#    'its',
#    'comprise',
#    'little',
#    'emerges',
#    'bourne',
#    'solidly',
#    'shot',
#    'clock',
#    'get',
#    'time',
#    'care',
#    'be',
#    'nt',
#    'black',
#    'russian',
#    'solid',
#    'recommendation',
#    'awarded',
#    'around',
#    'usually',
#    'interest',
#    'right',
#    'epic',
#    'meaningful',
#    'under',
#    'games',
#    'was',
#    'apart',
#    'hybrid',
#    'change',
#    'actual',
#    'sure',
#    'choose',
#    'popcorn',
#    'definitive',
#    'without',
#    'down',
#    'standard',
#    'saving',
#    'race',
#    'forget',
#    'fall',
#    'committed',
#    'hollywood',
#    'match',
#    'pace',
#    'blue',
#    'ever',
#    'something',
#    'play',
#    'felt',
#    'suspended',
#    'leave',
#    'carl',
#    'pie',
#    'kiddie',
#    'no',
#    'should',
#    'magical',
#    'far',
#    'bon',
#    'turns',
#    'budget',
#    'arguably',
#    'themselves',
#    'nothing',
#    'new',
#    'is',
#    'much',
#    'consistently',
#    'younger',
#    'most',
#    'intrigue',
#    'falling',
#    'must',
#    'host',
#    'upping',
#    'flatout',
#    'baffling',
#    'eats',
#    'transition',
#    'spectacular',
#    'disney',
#    'with',
#    'could',
#    'aboveaverage',
#    'contribution',
#    'getting',
#    'deserves',
#    'maturity',
#    'fine',
#    'washington',
#    'heck',
#    'goodness',
#    'morrison',
#    'any',
#    'consume',
#    'straight',
#    'american',
#    'fare',
#    'littleknown',
#    'anyone',
#    'information',
#    'watts',
#    'larger',
#    'proposal',
#    'type',
#    'sci',
#    'wildly',
#    'ride',
#    'actionpacked',
#    'length',
#    'emotionally',
#    'televised',
#    'eat',
#    'territory',
#    'out',
#    'welsh',
#    'when',
#    'dark',
#    'watch',
#    'astonishing',
#    'assets',
#    'big',
#    'mr',
#    'achieving',
#    'diverges',
#    'crack',
#    'heist',
#    'proposes',
#    'confident',
#    'complications',
#    'sequence',
#    'willing',
#    'drastic',
#    'let',
#    'impressive',
#    'roars',
#    'phantom',
#    'delivery',
#    'hitch',
#    'comes',
#    'worthy',
#    'absolutely',
#    'feel',
#    'dazzling',
#    'force',
#    'philosophical',
#    'night',
#    'hip',
#    'philip',
#    'strike',
#    'wound',
#    'saga',
#    'king',
#    'gon',
#    'follow',
#    'curious',
#    'they',
#    'producer',
#    'applying',
#    'questions',
#    'positive',
#    'fluid',
#    'potent',
#    'cheese',
#    'gas',
#    'them',
#    'wow',
#    'can',
#    'scariest',
#    'battle',
#    'candidate',
#    'flawless',
#    'drama',
#    'performance',
#    'convincing',
#    'effort',
#    'pipeline',
#    'surefire',
#    'you',
#    'rarity',
#    'significance',
#    'doubts',
#    'peaks',
#    'forced',
#    'bar',
#    'mattered',
#    'spy',
#    'french',
#    'ripping',
#    'scotland',
#    'decade',
#    'berry',
#    'got',
#    'startling',
#    'fixating',
#    'stand',
#    'love',
#    'players',
#    'minor',
#    'scoring',
#    'sand',
#    'ranks',
#    'world',
#    'move',
#    'your',
#    'station',
#    'jesus',
#    'emerge',
#    'shine',
#    'picked',
#    'masterpiece',
#    'balk',
#    'me',
#    'succeeds',
#    'face',
#    'actually',
#    'power',
#    'think',
#    'dance',
#    'laughable',
#    'domestic',
#    'sentimental',
#    'as',
#    'better',
#    'white',
#    'puff',
#    'fight',
#    'feature',
#    'scary',
#    'wrong',
#    'touching',
#    'wanting',
#    'matters',
#    'spikes',
#    'kidman',
#    'come',
#    'he',
#    'prison',
#    'outing',
#    'goddammit',
#    'star',
#    'rare',
#    'venice',
#    'beloved',
#    'relatively',
#    'job',
#    'veggies',
#    'jack',
#    'golf',
#    'path',
#    'evenings',
#    'large',
#    'while',
#    'male',
#    'achieves',
#    'given',
#    'based',
#    'spiderman',
#    'my',
#    'frames',
#    'franklin',
#    'mel',
#    'universal',
#    'considerable',
#    'watchable',
#    'fun',
#    'na',
#    'mix',
#    'acceptable',
#    'exceptional',
#    'roman',
#    'guy',
#    'accuracy',
#    'intoxication',
#    'expectation',
#    'wise',
#    'lanes',
#    'helping',
#    'raised',
#    'tremendous',
#    'throughout',
#    'hundred',
#    'space',
#    'finally',
#    'score',
#    'performances',
#    'allows',
#    'but',
#    'recent',
#    'into',
#    'pure',
#    'confusing',
#    'further',
#    'dread',
#    'what',
#    'talent',
#    'credits',
#    'attempted',
#    'even',
#    'anteing',
#    'prove',
#    'dramatically',
#    'reasonably',
#    'japanese',
#    'itself',
#    'so',
#    'rivals',
#    'team',
#    'perfect',
#    'directly',
#    'individual',
#    'that',
#    'miracle',
#    'holm',
#    'rising',
#    'philippe',
#    'tiny',
#    'still',
#    'grueling',
#    'not',
#    'sibling',
#    'capable',
#    'being',
#    'depth',
#    'ticking',
#    'audacious',
#    'arrive',
#    'career',
#    'emotional',
#    'steven',
#    'swim',
#    'sugar',
#    'gifts',
#    'beings',
#    'thousand',
#    'firstclass',
#    'talk',
#    'gut',
#    'cleaving',
#    'whole',
#    'goodly',
#    'trouble',
#    'pop',
#    'heart',
#    'found',
#    'pretty',
#    'detailed',
#    'sharply',
#    'though',
#    'food',
#    'ramifications',
#    'assassin',
#    'about',
#    'project',
#    'spike',
#    'unexpectedly',
#    'potential',
#    'represents',
#    'ian',
#    'making',
#    'struggling',
#    'crowdpleasing',
#    'paper',
#    'errors',
#    'relegated',
#    'classic',
#    'differences',
#    'intact',
#    'bow',
#    'crimes',
#    'believing',
#    'orbit',
#    'loved',
#    'holiday',
#    'their',
#    'best',
#    'problem',
#    'satisfying',
#    'learn',
#    'breathtaking',
#    'equally',
#    'executed',
#    'harmless',
#    'stirring',
#    'effectively',
#    'small',
#    'surprising',
#    'established',
#    'punch',
#    'expectations',
#    'forward',
#    'reconciliation',
#    'affecting',
#    'myth',
#    'those',
#    'work',
#    'suspenseful',
#    'gritty',
#    'shockingly',
#    'surprisingly',
#    'light',
#    'frank',
#    'confidence',
#    'talking',
#    'projects',
#    'stores',
#    'cannon',
#    'memorable',
#    'pill',
#    'anyplace',
#    'try',
#    'prefer',
#    'struggles',
#    'tribute',
#    'depression',
#    'digital',
#    'craft',
#    'story',
#    'absorbing',
#    'form',
#    'female',
#    'intriguing',
#    'storytelling',
#    'trap',
#    'sweet',
#    'his',
#    'ante',
#    'complex',
#    'collection',
#    'enough',
#    'magic',
#    'ravaging',
#    'dangerous',
#    'honestly',
#    'stirs',
#    'loaded',
#    'motion',
#    'looks',
#    'experimental',
#    'bad',
#    'counts',
#    'revenge',
#    'entertainment',
#    'imaginable',
#    'movies',
#    'compromise',
#    'makers',
#    'edition',
#    'impossible',
#    'nobody',
#    'rap',
#    'club',
#    'girlfriend',
#    'here',
#    'lingerie',
#    'greatest',
#    'watching',
#    'tough',
#    'commentary',
#    'history',
#    'killed',
#    'do',
#    'needs',
#    'seat',
#    'acute',
#    'laugh',
#    'globe',
#    'city',
#    'lines',
#    'pianist',
#    'give',
#    'scenario',
#    'unexpected',
#    'ultimately',
#    'grew',
#    'newcomers',
#    'reap',
#    'lane',
#    'hard',
#    'terrifying',
#    'because',
#    'don',
#    'read',
#    'movie',
#    'native',
#    'feelgood',
#    'plot',
#    'proves',
#    'liar',
#    'bons',
#    'attention',
#    'mythic',
#    'saw',
#    'results',
#    'lot',
#    'word',
#    'false',
#    'kwan',
#    'horror',
#    'congrats',
#    'jolt',
#    'check',
#    'able',
#    'stars',
#    'goals',
#    'shows',
#    'honest',
#    'punctuation',
#    'has',
#    'local',
#    'yarn',
#    'riproaring',
#    'klein',
#    'flow',
#    'treat',
#    'good',
#    'election',
#    'cautionary',
#    'bicentennial',
#    'claude',
#    'turn',
#    'grounded',
#    'gutwrenching',
#    'reruns',
#    'heights',
#    'swallow',
#    'however',
#    'animated',
#    'flick',
#    'become',
#    'opportunities',
#    'perspective',
#    'offer',
#    'loves',
#    'memory',
#    'drugs',
#    'enthralling',
#    'canvas',
#    'numerous',
#    'purely',
#    'want',
#    'definition',
#    'carrying',
#    'trilogy',
#    'rich',
#    'kid',
#    'happened',
#    'see',
#    'grow',
#    'retains',
#    'fanboy',
#    'credibility',
#    'surprises',
#    'involving',
#    'may',
#    'did',
#    'window',
#    'sequences',
#    'hand',
#    'approach',
#    'glass',
#    'exists',
#    'study',
#    'alien',
#    'darker',
#    'easily',
#    'remarkable',
#    'attempt',
#    'we',
#    'definitely',
#    'avoids',
#    'fake',
#    'seen',
#    'affirming',
#    'fans',
#    'man',
#    'usual',
#    'some',
#    'thanks',
#    'angst',
#    'vintage',
#    'hysteria',
#    'clutch',
#    'awful',
#    'tender',
#    'private',
#    'does',
#    've',
#    'legend',
#    'way',
#    'well',
#    'daring',
#    'interesting',
#    'maxim',
#    'likable',
#    'changing',
#    'yet',
#    'growth',
#    'transcends',
#    'spooky',
#    'bringing',
#    'sea',
#    'adventure',
#    'inside',
#    'pale',
#    'precisely',
#    'swooning',
#    'cute',
#    'were',
#    'her',
#    'note',
#    'fantasized',
#    'specimen',
#    'make',
#    'inspiring',
#    'politically',
#    'kicking',
#    'chord',
#    'laidback',
#    'storyline',
#    'across',
#    'lilo',
#    'intermittently',
#    'speaks',
#    'believable',
#    'swung',
#    'times',
#    'never',
#    'lee',
#    'teen',
#    'video',
#    'stimulating',
#    'vulnerability',
#    'frightening',
#    'summer',
#    'courageous',
#    'innocent',
#    'done',
#    'seems',
#    'succeed',
#    'routine',
#    'too',
#    'perfectly',
#    'holden',
#    'version',
#    'impenetrable',
#    'awed',
#    'gluing',
#    'there',
#    'enjoyment',
#    'favor',
#    'boy',
#    'sides',
#    'psychological',
#    'memorial',
#    'collide',
#    'amazing',
#    'war',
#    'grace',
#    'quiet',
#    'result',
#    'revelations',
#    'certainly',
#    'enjoyed',
#    'brutally',
#    'versatile',
#    'escapist',
#    'nail',
#    'machine',
#    'moving',
#    'earnest',
#    'women',
#    'genres',
#    'strong',
#    'find',
#    'oscar',
#    'moral',
#    'captivating',
#    'book',
#    'role',
#    'knowing',
#    'if',
#    'wish',
#    'sportsmen',
#    'overly',
#    'largely',
#    'attractive',
#    'artist',
#    'talented',
#    'infused',
#    'uplifting',
#    'odd',
#    'lifechanging',
#    'accomplished',
#    'revealing',
#    'liked',
#    'heartbreaking',
#    'discovery',
#    'ambiguities',
#    'smiles',
#    'screen',
#    ...],
#   'ccw': ['nine',
#    'stuart',
#    'solid',
#    'each',
#    'him',
#    'twentyth',
#    'spielberg',
#    'selfglorification',
#    'scoobydoo',
#    'raphael',
#    'pitchperfect',
#    'paradiso',
#    'largerthanlife',
#    'eightynine',
#    'antwone',
#    'starting',
#    'one',
#    'fare',
#    'b',
#    'jesse',
#    'and',
#    'giving',
#    'chance',
#    'saving',
#    'philadelphia',
#    'remaining',
#    'date',
#    'ninth',
#    'beat',
#    'status',
#    'zwick',
#    'writerdirectors',
#    'worldlywise',
#    'wisegirls',
#    'windinthehair',
#    'whatif',
#    'wellintentioned',
#    'welldeveloped',
#    'wellbehaved',
#    'wellbalanced',
#    'unhibited',
#    'twelveyearold',
#    'truffaut',
#    'truecrime',
#    'threed',
#    'thirtythree',
#    'sweatypalmed',
#    'stillinestimable',
#    'spoton',
#    'soderbergh',
#    'siegel',
#    'shafer',
#    'seventys',
#    'selfexpression',
#    'sarandon',
#    'salton',
#    'sade',
#    'romoli',
#    'rohmer',
#    'reggio',
#    'qatsi',
#    'prowildlife',
#    'polanski',
#    'petter',
#    'oncamera',
#    'næss',
#    'nonexploitive',
#    'ninetythree',
#    'nijinsky',
#    'nickelodeonesque',
#    'nearimpossible',
#    'morvern',
#    'mib',
#    'mesmerised',
#    'mamet',
#    'livestyle',
#    'laughoutloud',
#    'largestever',
#    'kineticallycharged',
#    'kibbitzes',
#    'jumpinyourseat',
#    'juliette',
#    'igby',
#    'huston',
#    'hugescreen',
#    'highconcept',
#    'helljaunt',
#    'hardwon',
#    'halfbad',
#    'gyllenhaal',
#    'godfrey',
#    'girlmeetsgirl',
#    'gianni',
#    'frida',
#    'frenchproduced',
#    'finelooking',
#    'fiftyseven',
#    'fessenden',
#    'fastmoving',
#    'familyoriented',
#    'eyre',
#    'eightyeight',
#    'duvall',
#    'deadon',
#    'cremaster',
#    'connectthedots',
#    'comingofage',
#    'coen',
#    'cockettes',
#    'churchwary',
#    'chabrol',
#    'campaigntrail',
#    'callar',
#    'binoche',
#    'balto',
#    'aweinspiring',
#    'auteuil',
#    'france',
#    'extra',
#    'versus',
#    'worthy',
#    'ii',
#    'moved',
#    'halfway',
#    'class',
#    'j',
#    'season',
#    'completion',
#    'held',
#    'feat',
#    'top',
#    'since',
#    'equal',
#    'square',
#    'awarded',
#    'interest',
#    'ages',
#    'subsequent',
#    'committed',
#    'modest',
#    'alone',
#    'start',
#    'themselves',
#    'slightly',
#    'showdown',
#    'allen',
#    'dropped',
#    'novak',
#    'mature',
#    'ryan',
#    'twin',
#    'deserves',
#    'stevens',
#    'win',
#    'sleeper',
#    'anyone',
#    'net',
#    'televised',
#    'wo',
#    'astonishing',
#    'crack',
#    'most',
#    'absolutely',
#    'reasonable',
#    'dazzling',
#    'daniel',
#    'stays',
#    'anywhere',
#    'accumulated',
#    'hits',
#    'beats',
#    'won',
#    'sets',
#    'mtv',
#    'opening',
#    'oliver',
#    'barry',
#    'eric',
#    'respectable',
#    'jake',
#    'stunning',
#    'gets',
#    'number',
#    'stanley',
#    'realistic',
#    'betting',
#    'cost',
#    'dual',
#    'moderately',
#    'step',
#    'due',
#    'sensational',
#    'rises',
#    'concerned',
#    'born',
#    'fantasy',
#    'share',
#    'prime',
#    'par',
#    'ups',
#    'golden',
#    'mariah',
#    'arc',
#    'chicago',
#    'mixture',
#    'end',
#    'range',
#    'carey',
#    'carries',
#    'bold',
#    'huge',
#    'essentially',
#    'sonny',
#    't',
#    'comprise',
#    'emerges',
#    'bourne',
#    'solidly',
#    'clock',
#    'russian',
#    'recommendation',
#    'meaningful',
#    'under',
#    'games',
#    'apart',
#    'hybrid',
#    'change',
#    'actual',
#    'popcorn',
#    'definitive',
#    'standard',
#    'race',
#    'forget',
#    'fall',
#    'match',
#    'felt',
#    'suspended',
#    'leave',
#    'carl',
#    'pie',
#    'kiddie',
#    'magical',
#    'bon',
#    'arguably',
#    'consistently',
#    'younger',
#    'intrigue',
#    'falling',
#    'must',
#    'host',
#    'upping',
#    'flatout',
#    'baffling',
#    'eats',
#    'transition',
#    'disney',
#    'aboveaverage',
#    'contribution',
#    'maturity',
#    'fine',
#    'washington',
#    'heck',
#    'goodness',
#    'morrison',
#    'consume',
#    'straight',
#    'littleknown',
#    'information',
#    'watts',
#    'larger',
#    'proposal',
#    'type',
#    'sci',
#    'wildly',
#    'ride',
#    'actionpacked',
#    'eat',
#    'welsh',
#    'assets',
#    'achieving',
#    'diverges',
#    'confident',
#    'complications',
#    'willing',
#    'drastic',
#    'let',
#    'impressive',
#    'roars',
#    'phantom',
#    'delivery',
#    'hitch',
#    'force',
#    'philosophical',
#    'hip',
#    'philip',
#    'strike',
#    'wound'],
#   'scw': ['three',
#    'third',
#    'second',
#    'to',
#    'nearly',
#    'midnight',
#    'the',
#    'of',
#    'half',
#    'than',
#    'on',
#    'less',
#    'a',
#    'twohourandfifteenminute',
#    'twentytwoyearold',
#    'spiritcrushing',
#    'selfsatisfied',
#    'partyhearty',
#    'eighteenyearold',
#    'assayas',
#    'ends',
#    'final',
#    'sorvino',
#    'at',
#    'last',
#    'every',
#    'effective',
#    'set',
#    's',
#    'for',
#    'will',
#    'goes',
#    'between',
#    'which',
#    'takes',
#    'least',
#    'just',
#    'another',
#    'go',
#    'almost',
#    'short',
#    'from',
#    'hugh',
#    'sandra',
#    'more',
#    'or',
#    'take',
#    'mark',
#    'over',
#    'through',
#    'else',
#    'after',
#    'all',
#    'special',
#    'it',
#    'by',
#    'would',
#    'blockbuster',
#    'off',
#    'same',
#    'cut',
#    'going',
#    'value',
#    'hold',
#    'high',
#    'full',
#    'both',
#    'this',
#    'nt',
#    'target',
#    'hours',
#    'back',
#    'long',
#    'an',
#    'thriller',
#    'is',
#    'probably',
#    'tom',
#    'action',
#    'balance',
#    'be',
#    'day',
#    'amounts',
#    'missing',
#    'feeling',
#    'joel',
#    'anything',
#    'get',
#    'minutes',
#    'saturday',
#    'much',
#    'decent',
#    'robert',
#    'care',
#    'little',
#    'no',
#    'shot',
#    'nothing',
#    'hollywood',
#    'was',
#    'time',
#    'right',
#    'black',
#    'original',
#    'around',
#    'usually',
#    'down',
#    'sure',
#    'choose',
#    'something',
#    'epic',
#    'pace',
#    'blue',
#    'play',
#    'far',
#    'turns',
#    'budget',
#    'ever',
#    'should',
#    'getting',
#    'out',
#    'when',
#    'any',
#    'spectacular',
#    'length',
#    'could',
#    'territory',
#    'comes',
#    'mr',
#    'feel',
#    'heist',
#    'proposes',
#    'sequence',
#    'big',
#    'dark',
#    'night',
#    'watch'],
#   'fcw': ['wonderful',
#    'style',
#    'culture',
#    'ways',
#    'ingenious',
#    'whose',
#    'occasionally',
#    'sly',
#    'manner',
#    'amusing',
#    'modern',
#    'cinema',
#    'imaginative',
#    'pleasure',
#    'intimate',
#    'cleverness',
#    'warmth',
#    'inquisitiveness',
#    'fore',
#    'countercultural',
#    'setpieces',
#    'inventive',
#    'bourgeois',
#    'occasional',
#    'lovely',
#    'engaged',
#    'nurtured',
#    'era',
#    'depiction',
#    'involved',
#    'pretension',
#    'manages',
#    'sophisticated',
#    'sardonic',
#    'nononsense',
#    'keen',
#    'darkly',
#    'iconoclastic',
#    'atmosphere',
#    'gentle',
#    'presence',
#    'adorably',
#    'political',
#    'behold',
#    'delicately',
#    'blithe',
#    'truths',
#    'influenced',
#    'sanctimoniousness',
#    'winking',
#    'iconography',
#    'sincerity',
#    'lady',
#    'dynamism',
#    'newfangled',
#    'humor',
#    'inherent',
#    'midwest',
#    'underbelly',
#    'taste',
#    'spirit',
#    'amoral',
#    'comically',
#    'lovingly',
#    'elegance',
#    'mind',
#    'lively',
#    'costuming',
#    'gestalt',
#    'charm',
#    'commend',
#    'cultural',
#    'charms',
#    'wizened',
#    'eye',
#    'neat',
#    'topnotch',
#    'photographed',
#    'bombastic',
#    'leonine',
#    'hermetic',
#    'inhabit',
#    'wistfully',
#    'wispy',
#    'astringent',
#    'heartfelt',
#    'deportment',
#    'human',
#    'layers',
#    'splendid',
#    'antiwar',
#    'artistic',
#    'meditation',
#    'subculture',
#    'adolescent',
#    'documentarian',
#    'refreshingly',
#    'works',
#    'existential',
#    'parody',
#    'joys',
#    'thankfully',
#    'masterfully',
#    'smartly',
#    'insightfully',
#    'meddles',
#    'spell',
#    'convinces',
#    'souls',
#    'lad',
#    'vanity',
#    'huskies',
#    'cleverly',
#    'subtle',
#    'voices',
#    'lives',
#    'fiascos',
#    'fused',
#    'entertaining',
#    'strangely',
#    'vistas',
#    'subtly',
#    'background',
#    'unique',
#    'bristles',
#    'sweetness',
#    'whimsy',
#    'freshness',
#    'yearnings',
#    'traveler',
#    'frissons',
#    'wrought',
#    'intimacy',
#    'readymade',
#    'images',
#    'clichés',
#    'resonant',
#    'glimpse',
#    'hilarious',
#    'sneering',
#    'pleasant',
#    'titular',
#    'eerie',
#    'unhinged',
#    'eloquent',
#    'piercing',
#    'observation',
#    'stanzas',
#    'stylishly',
#    'offbeat',
#    'dynamics',
#    'charming',
#    'immaculate',
#    'creative',
#    'urban',
#    'resourceful',
#    'strange',
#    'anarchist',
#    'conceptual',
#    'matron',
#    'stylish',
#    'gallic',
#    'yearning',
#    'sensitivity',
#    'vibrant',
#    'uniquely',
#    'inspired',
#    'others',
#    'undeniable',
#    'brilliance',
#    'wonderfully',
#    'camerawork',
#    'lend',
#    'filmed',
#    'merrily',
#    'attuned',
#    'cheery',
#    'openness',
#    'bravery',
#    'sabotage',
#    'servants',
#    'movements',
#    'songs',
#    'characteristically',
#    'playwriting',
#    'subtlety',
#    'scripting',
#    'verve',
#    'fact',
#    'stylists',
#    'wasp',
#    'family',
#    'humanly',
#    'edifying',
#    'schtick',
#    'ripening',
#    'drumming',
#    'partisans',
#    'parable',
#    'desolate',
#    'sounding',
#    'filmgoing',
#    'spirits',
#    'ditsy',
#    'ecological',
#    'exploring',
#    'visually',
#    'fluidity',
#    'metaphors',
#    'examination',
#    'ensemble',
#    'colorful',
#    'natured',
#    'flamboyant',
#    'guffaw',
#    'charismatic',
#    'witty',
#    'president',
#    'cheerfully',
#    'demonstrates',
#    'woodman',
#    'outrageousness',
#    'nuance',
#    'missive',
#    'instructive',
#    'camera',
#    'pursuing',
#    'flowery',
#    'compulsively',
#    'dismissed',
#    'captivatingly',
#    'layered',
#    'poetry',
#    'stickiness',
#    'hear',
#    'abundant',
#    'campy',
#    'contrivances',
#    'sincere',
#    'routines',
#    'pertinent',
#    'noble',
#    'anniversary',
#    'encounters',
#    'ravishing',
#    'conceive',
#    'necessarily',
#    'beautifully',
#    'suggest',
#    'head',
#    'revolutionary',
#    'informative',
#    'grateful',
#    'calibrated',
#    'argues',
#    'degree',
#    'increasingly',
#    'characteristic',
#    'filmmaker',
#    'associated',
#    'enthusiasm',
#    'unruly',
#    'encountering',
#    'frailty',
#    'fruitful',
#    'distinct',
#    'friendships',
#    'buoyant',
#    'intentions',
#    'weirdly',
#    'reinvention',
#    'secretly',
#    'penetrating',
#    'noir',
#    'ethical',
#    'levity',
#    'lothario',
#    'funloving',
#    'brooks',
#    'clooney',
#    'bighearted',
#    'press',
#    'biting',
#    'tranquil',
#    'combines',
#    'melodramatic',
#    'sincerely',
#    'laughed',
#    'animations',
#    'technology',
#    'movement',
#    'illusion',
#    'suits',
#    'melodrama',
#    'appreciates',
#    'reassuring',
#    'diaries',
#    'expressiveness',
#    'awakening',
#    'dimension',
#    'reflected',
#    'importance',
#    'introspective',
#    'tattoos',
#    'sprung',
#    'tradition',
#    'crafted',
#    'corniest',
#    'unabashedly',
#    'oozing',
#    'appreciate',
#    'wistful',
#    'reunion',
#    'jaded',
#    'existed',
#    'literate',
#    'originality',
#    'stage',
#    'seamy',
#    'showcases',
#    'genuine',
#    'diverse',
#    'chuckles',
#    'menace',
#    'classy',
#    'delightful',
#    'transcendence',
#    'lips',
#    'technical',
#    'festival',
#    'appealing',
#    'case',
#    'spiffy',
#    'purists',
#    'glitter',
#    'unadulterated',
#    'stitch',
#    'novel',
#    'rewarding',
#    'naughty',
#    'vital',
#    'brothers',
#    'urge',
#    'gangster',
#    'brimming',
#    'sentiments',
#    'prophet',
#    'timeconsuming',
#    'desperation',
#    'gifted',
#    'exceedingly',
#    'deft',
#    'horrendously',
#    'expressing',
#    'comfort',
#    'fascinating',
#    'portrait',
#    'navigate',
#    'ethics',
#    'cartoonish',
#    'enjoys',
#    'creature',
#    'highlighted',
#    'refreshed',
#    'parents',
#    'keeps',
#    'solutions',
#    'denuded',
#    'infuse',
#    'triumphs',
#    'unseemly',
#    'chimes',
#    'sorrow',
#    'documenting'],
#   'iw': ['clever',
#    'tastelessness',
#    'elegantly',
#    'shrewd',
#    'ennui',
#    'director',
#    'callow',
#    'audience',
#    'wit',
#    'moments',
#    'such',
#    'kind',
#    'identity',
#    'hackneyed',
#    'crass',
#    'worked',
#    'utter',
#    'seem',
#    'act',
#    'indulgent',
#    'particularly',
#    'naturalistic',
#    'filmmakers',
#    'tragedy',
#    'screenplay',
#    'like',
#    'intelligent',
#    'dreams',
#    'bullock',
#    'insight',
#    'past',
#    'often',
#    'art',
#    'tragic',
#    'edge',
#    'moment',
#    'saccharine',
#    'comic',
#    'acting',
#    'told',
#    'sound',
#    'visual',
#    'concept',
#    'scene',
#    'exaggerated',
#    'intelligence',
#    'scenes',
#    'particular',
#    'charisma',
#    'suggests',
#    'actress',
#    'always',
#    'eyes',
#    'audiences',
#    'direction',
#    'narrative',
#    'real',
#    'mindless',
#    'smart',
#    'murder',
#    'quirky',
#    'mistress',
#    'excellent',
#    'endearing',
#    'addition']},
#  '0': {'lr': ['tv',
#    'lack',
#    'years',
#    'series',
#    'before',
#    'worst',
#    'tone',
#    'run',
#    'purpose',
#    'predictable',
#    'pacing',
#    'loud',
#    'forgettable',
#    'flat',
#    'feels',
#    'familiar',
#    'falls',
#    'effects',
#    'despite',
#    'bland',
#    'too',
#    'to',
#    'wilde',
#    'wasted',
#    'vampire',
#    'uneven',
#    'trying',
#    'title',
#    'tired',
#    'stupid',
#    'soap',
#    'sit',
#    'shallow',
#    'room',
#    'putting',
#    'promising',
#    'possible',
#    'plodding',
#    'opera',
#    'onto',
#    'need',
#    'merit',
#    'limp',
#    'imagine',
#    'having',
#    'hate',
#    'gags',
#    'four',
#    'formulaic',
#    'edited',
#    'dumb',
#    'crazy',
#    'contrived',
#    'commercial',
#    'combined',
#    'bore',
#    'bit',
#    'avoid',
#    'year',
#    'worse',
#    'within',
#    'whatsoever',
#    'whatever',
#    'waste',
#    'violent',
#    'unpleasant',
#    'unfunny',
#    'typical',
#    'tries',
#    'tricks',
#    'trash',
#    'total',
#    'toilethumor',
#    'terror',
#    'terrible',
#    'swan',
#    'subjects',
#    'starts',
#    'squarely',
#    'speedy',
#    'sort',
#    'snore',
#    'slip',
#    'slimed',
#    'slapstick',
#    'situations',
#    'situation',
#    'simpleminded',
#    'similar',
#    'silly',
#    'several',
#    'sequel',
#    'selfconscious',
#    'rowling',
#    'responsible',
#    'resonance',
#    'remake',
#    'relentlessly',
#    'recycled',
#    'reality',
#    'raw',
#    'quirks',
#    'promisingly',
#    'possibilities',
#    'poorly',
#    'pieces',
#    'phony',
#    'period',
#    'pack',
#    'obscure',
#    'numbers',
#    'name',
#    'murphy',
#    'morning',
#    'money',
#    'misconceived',
#    'mess',
#    'merely',
#    'meat',
#    'meandering',
#    'martha',
#    'low',
#    'loose',
#    'listless',
#    'letdown',
#    'landing',
#    'know',
#    'jokes',
#    'joke',
#    'irritating',
#    'incoherence',
#    'important',
#    'ideas',
#    'humorless',
#    'hotels',
#    'home',
#    'hollow',
#    'highly',
#    'heroes',
#    'heavyhanded',
#    'hastily',
#    'hartley',
#    'harry',
#    'had',
#    'girls',
#    'funnier',
#    'five',
#    'firstrate',
#    'finds',
#    'few',
#    'eight',
#    'ego',
#    'efforts',
#    'editing',
#    'ears',
#    'duds',
#    'dubbed',
#    'drew',
#    'drag',
#    'dough',
#    'dive',
#    'disaster',
#    'difficult',
#    'damage',
#    'confused',
#    'clumsy',
#    'close',
#    'cheap',
#    'bother',
#    'boring',
#    'becomes',
#    'badly',
#    'artificial',
#    'appears',
#    'animation',
#    'already',
#    'again',
#    'adaptation',
#    'abuse',
#    'absurdity',
#    'abandon',
#    'as',
#    'your',
#    'bad',
#    'the',
#    'of',
#    'that',
#    'into',
#    'special',
#    'hours',
#    'on',
#    'zemeckis',
#    'yourself',
#    'york',
#    'yielded',
#    'yes',
#    'yelling',
#    'yard',
#    'writerproducerdirector',
#    'writerdirector',
#    'wrists',
#    'wrap',
#    'wore',
#    'wobbly',
#    'willingness',
#    'wholly',
#    'where',
#    'western',
#    'wellacted',
#    'week',
#    'wedgie',
#    'wearisome',
#    'waterlogged',
#    'water',
#    'wasting',
#    'warn',
#    'warmovie',
#    'warmed',
#    'wall',
#    'walk',
#    'waiting',
#    'waited',
#    'wait',
#    'vu',
#    'visions',
#    'villainess',
#    'viewing',
#    'viewer',
#    'victim',
#    'vehicle',
#    'various',
#    'vaporize',
#    'vacuous',
#    'vacant',
#    'usher',
#    'used',
#    'use',
#    'unwieldy',
#    'unusual',
#    'unsurprising',
#    'unnecessary',
#    'unnamed',
#    'unleashes',
#    'ungainly',
#    'unfulfilling',
#    'unfortunately',
#    'unfortunate',
#    'unfocused',
#    'unfaithful',
#    'underrehearsed',
#    'underestimated',
#    'undercuts',
#    'unconvincing',
#    'uncommitted',
#    'uncinematic',
#    'unbelievable',
#    'ultimate',
#    'uglylooking',
#    'ugly',
#    'ugliness',
#    'ugh',
#    'twentyfourandunders',
#    'tvmovie',
#    'tvinsider',
#    'trite',
#    'tripe',
#    'trifle',
#    'tried',
#    'treatment',
#    'treading',
#    'translation',
#    'trace',
#    'tornatore',
#    'topical',
#    'tool',
#    'tooconscientious',
#    'tommy',
#    'tiresome',
#    'tiniest',
#    'timing',
#    'ticket',
#    'throwntogether',
#    'threehour',
#    'thoughtlessly',
#    'thirtys',
#    'thirdperson',
#    'thin',
#    'thematic',
#    'thecash',
#    'theater',
#    'text',
#    'test',
#    'terribly',
#    'tenyear',
#    'tendentious',
#    'telling',
#    'teensleaze',
#    'teendriven',
#    'tedious',
#    'techgeeks',
#    'tearing',
#    'tear',
#    'taxicab',
#    'tart',
#    'targeted',
#    'taking',
#    'tactics',
#    'synergistic',
#    'sympathy',
#    'swordandsorcery',
#    'swill',
#    'swear',
#    'sustain',
#    'survive',
#    'surrounding',
#    'surprise',
#    'supposed',
#    'superior',
#    'superficial',
#    'summercamp',
#    'sugarman',
#    'suffers',
#    'sudden',
#    'successor',
#    'substitutable',
#    'subplots',
#    'subject',
#    'styles',
#    'stupefying',
#    'stuffy',
#    'stuff',
#    'structure',
#    'stronger',
#    'strained',
#    'straddles',
#    'stories',
#    'stopandstart',
#    'stomach',
#    'stolid',
#    'stinks',
#    'stilted',
#    'stifles',
#    'stewart',
#    'stereotypical',
#    'stereotype',
#    'stealing',
#    'startled',
#    'starring',
#    'stare',
#    'standoffish',
#    'stalking',
#    'stains',
#    'stagy',
#    'squint',
#    'squeeze',
#    'spousal',
#    'sport',
#    'spookiness',
#    'spoof',
#    'spliced',
#    'spiritual',
#    'spend',
#    'spectacularly',
#    'span',
#    'soundtrack',
#    'sorority',
#    'soontobeforgettable',
#    'soon',
#    'someone',
#    'soliloquies',
#    'snow',
#    'snl',
#    'sneaky',
#    'snaillike',
#    'smugly',
#    'smacks',
#    'sluggish',
#    'sloppily',
#    'slomo',
#    'slice',
#    'slc',
#    'slapping',
#    'slapped',
#    'slack',
#    'skill',
#    'sketchy',
#    'sketchiest',
#    'sixtys',
#    'sitcom',
#    'sinks',
#    'singleminded',
#    'simpering',
#    'silver',
#    'sillified',
#    'silbersteins',
#    'signs',
#    'signpost',
#    'sign',
#    'sight',
#    'sidewalks',
#    'shtick',
#    'shrek',
#    'showcase',
#    'show',
#    'shoot',
#    'ship',
#    'she',
#    'sharing',
#    'shame',
#    'sexy',
#    'sex',
#    'setups',
#    'serviceability',
#    'serve',
#    'serious',
#    'serials',
#    'sequels',
#    'sentiment',
#    'sentence',
#    'send',
#    'seller',
#    'selfindulgent',
#    'selfimportant',
#    'selfconsciously',
#    'selfcongratulation',
#    'selfawareness',
#    'segment',
#    'seemed',
#    'section',
#    'secrets',
#    'secret',
#    'search',
#    'scrutiny',
#    'scripts',
#    'screening',
#    'scifi',
#    'scientific',
#    'school',
#    'scalds',
#    'saying',
#    'saved',
#    'satire',
#    'sanctimony',
#    'said',
#    'sadly',
#    'sabotaged',
#    'running',
#    'rubbo',
#    'round',
#    'rote',
#    'rooting',
#    'romanticcomedy',
#    'romanek',
#    'roberto',
#    'road',
#    'ritchie',
#    'ripoff',
#    'ridiculous',
#    'rhythms',
#    'rhythm',
#    'rhetoric',
#    'rewritten',
#    'return',
#    'retread',
#    'retooling',
#    'rest',
#    'resolutely',
#    'resentment',
#    'rescue',
#    'reputation',
#    'repulsive',
#    'reportedly',
#    'repetitive',
#    'repeated',
#    'rent',
#    'remotely',
#    'remember',
#    'relic',
#    'relationship',
#    'reign',
#    'regrets',
#    'reeks',
#    'redundancy',
#    'redundancies',
#    'recovering',
#    'reason',
#    'reams',
#    'rank',
#    'ramblings',
#    'rambling',
#    'rally',
#    'raise',
#    'quickly',
#    'questionable',
#    'quest',
#    'pushes',
#    'push',
#    'purposes',
#    'punk',
#    'pump',
#    'pulse',
#    'pulpy',
#    'pulled',
#    'puddle',
#    'proving',
#    'proved',
#    'protestors',
#    'promised',
#    'prom',
#    'progression',
#    'program',
#    'product',
#    'producers',
#    'produce',
#    'proceeds',
#    'proceedings',
#    'problems',
#    'prince',
#    'primitive',
#    'pretentious',
#    'pretends',
#    'presented',
#    'prejudice',
#    'precredit',
#    'precious',
#    'potter',
#    'potentially',
#    'pot',
#    'possibly',
#    'posing',
#    'pore',
#    'poor',
#    'pool',
#    'pomposity',
#    'politics',
#    'pointless',
#    'plotting',
#    'plotted',
#    'playstation',
#    'playdoh',
#    'plans',
#    'pitfalls',
#    'pink',
#    'pilot',
#    'piece',
#    'pick',
#    'phoneyfeeling',
# ...
#    'elsewhere',
#    'ungainly',
#    'hole',
#    'styles',
#    'pulled',
#    'hated',
#    'reallife',
#    'needless',
#    'comprehend',
#    'responsible',
#    'more',
#    'spliced',
#    'moralistic',
#    'inevitable',
#    'year',
#    'edge',
#    'blood',
#    'childlike',
#    'actually',
#    'some',
#    'stare',
#    'unnecessary',
#    'set',
#    'neither',
#    'hamfisted',
#    'handy',
#    'graceless',
#    'mistaken',
#    'downbeat',
#    'poorly',
#    'synergistic',
#    'commiserating',
#    'everyone',
#    'lacks',
#    'girl',
#    'quite',
#    'better',
#    'exhibitionism',
#    'begins',
#    'stalking',
#    'guy',
#    'backdrops',
#    'potter',
#    'various',
#    'oldfashioned',
#    'covered',
#    'seller',
#    'interesting',
#    'vampire',
#    'relentlessly',
#    'italian',
#    'old',
#    'plot',
#    'promising',
#    'sign',
#    'soap',
#    'watching',
#    'strong',
#    'deaths',
#    'going',
#    'terror',
#    'cares',
#    'slice',
#    'cloaks',
#    'impact',
#    'need',
#    'than',
#    'very',
#    'you',
#    'argentine',
#    'recycled',
#    'overly',
#    'clunky',
#    'vacant',
#    'proved',
#    'chan',
#    'earlier',
#    'secret',
#    'effort',
#    'station',
#    'best',
#    'dupe',
#    'sight',
#    'choke',
#    'late',
#    'face',
#    'casting',
#    'happened',
#    'daytime',
#    'inadvertent',
#    'potentially',
#    'endearing',
#    'within',
#    'viewer',
#    'filmmaking',
#    'ill',
#    'imitation',
#    'pump',
#    'critiquing',
#    'bludgeoning',
#    'pot',
#    'marvelous',
#    'glib',
#    'hold',
#    'hallucinogenic',
#    'them',
#    'pore',
#    'such',
#    'had',
#    'leaky',
#    'complete',
#    'reason',
#    'believability',
#    'fire',
#    'swear',
#    'simply',
#    'sheer',
#    'believe',
#    'obnoxious',
#    'romance',
#    'sudden',
#    'death',
#    'send',
#    'although',
#    'insult',
#    'inside',
#    'contrived',
#    'unpleasant',
#    'nobody',
#    'assassin',
#    'what',
#    'along',
#    'special',
#    'great',
#    'storytelling',
#    'cheesiest',
#    'well',
#    'beach',
#    'action',
#    'incessant',
#    'resonance',
#    'lump',
#    'bland',
#    'bitter',
#    'possibilities',
#    'villainess',
#    'repulsive',
#    'standoffish',
#    'sides',
#    'instantly',
#    'empathy',
#    'otherwise',
#    'retooling',
#    'phones',
#    'uncinematic',
#    'reign',
#    'determined',
#    'adaptation',
#    'close',
#    'they',
#    'entirely',
#    'highways',
#    'unfortunately',
#    'produce',
#    'banal',
#    'care',
#    'many',
#    'tripe',
#    'ticket',
#    'bits',
#    'brooding',
#    'kiss',
#    'however',
#    'equally',
#    'picture',
#    'come',
#    'accent',
#    'stale',
#    'pick',
#    'never',
#    'here',
#    'college',
#    'charisma',
#    'bright',
#    'heist',
#    'straddles',
#    'abuse',
#    'duplicate',
#    'quirky',
#    'his',
#    'expense',
#    'hackneyed',
#    'joke',
#    'together',
#    'cue',
#    'afterschool',
#    'featuring',
#    'pushes',
#    'goofy',
#    'allows',
#    'rest',
#    'setups',
#    'adopt',
#    'prom',
#    'babies',
#    'week',
#    'sure',
#    'dismiss',
#    'body',
#    'saying',
#    'motifs',
#    'foolish',
#    'us',
#    'particularly',
#    'push',
#    'apparent',
#    'irritating',
#    'subjects',
#    'punk',
#    'there',
#    'memory',
#    'mankind',
#    'emulates',
#    'often',
#    'junk',
#    'moral',
#    'any',
#    'are',
#    'drugs',
#    'creeping',
#    'landing',
#    'insurance',
#    'fails',
#    'exploit',
#    'ducts',
#    'exasperated',
#    'wasting',
#    'life',
#    'delivered',
#    'decay',
#    'made',
#    'business',
#    'phony',
#    'tear',
#    'maudlin',
#    'meat',
#    'unfortunate',
#    'simpering',
#    'supposed',
#    'behavior',
#    'begin',
#    'canadian',
#    'attract',
#    'mistress',
#    'naturalistic',
#    'hundred',
#    'sustain',
#    'real',
#    'crass',
#    'badly',
#    'entire',
#    'hollow',
#    'historical',
#    'cliches',
#    'rhythms',
#    'dreams',
#    'team',
#    'stuff',
#    'your',
#    'tale',
#    'murderer',
#    'thrills',
#    'possible',
#    'stories',
#    'interplay',
#    'soliloquies',
#    'teens',
#    'contest',
#    'quirks',
#    'longwinded',
#    'girlish',
#    'squeeze',
#    'mugging',
#    'analysis',
#    'screen',
#    'captions',
#    'choose',
#    'can',
#    'humanity',
#    'smart',
#    'big',
#    'deliver',
#    'involving',
#    'myself',
#    'taxicab',
#    'chemistry',
#    'go',
#    'brutally',
#    'broad',
#    'arbitrarily',
#    'emotionally',
#    'durable',
#    'ones',
#    'tricks',
#    'actress',
#    'much',
#    'sketchiest',
#    'else',
#    'redundancies',
#    'wrists',
#    'own',
#    'command',
#    'promised',
#    'painfully',
#    'egregious',
#    'stilted',
#    'stores',
#    'finds',
#    'indication',
#    'particular',
#    'ingredients',
#    'rich',
#    'baked',
#    'even',
#    'stagy',
#    'dealing',
#    'dragonfly',
#    'eyes',
#    'crush',
#    'precious',
#    'imagine',
#    'turns',
#    'passion',
#    'tiniest',
#    'truth',
#    'flaw',
#    'formulaic',
#    'grinds',
#    'stereotypical',
#    'realism',
#    'survive',
#    'soundtrack',
#    'goes',
#    'pretends',
#    'fun',
#    'frustration',
#    'damage',
#    'reeks',
#    'rent',
#    'energy',
#    'acid',
#    'western',
#    'hand',
#    'he',
#    'ring',
#    'performances',
#    'segment',
#    'likable',
#    'pastiche',
#    ...],
#   'ccw': ['forgettable',
#    'series',
#    'lack',
#    'flat',
#    'before',
#    'combined',
#    'run',
#    'four',
#    'despite',
#    'worst',
#    'limp',
#    'effects',
#    'stupid',
#    'total',
#    'predictable',
#    'shallow',
#    'wilde',
#    'bit',
#    'eight',
#    'drew',
#    'too',
#    'murphy',
#    'crazy',
#    'wasted',
#    'low',
#    'hate',
#    'five',
#    'home',
#    'tired',
#    'dumb',
#    'plodding',
#    'onto',
#    'commercial',
#    'trying',
#    'starts',
#    'martha',
#    'tries',
#    'listless',
#    'period',
#    'simpleminded',
#    'bother',
#    'harry',
#    'terrible',
#    'ac',
#    'jk',
#    'duds',
#    'hoffman',
#    'similar',
#    'know',
#    'silly',
#    'whatsoever',
#    'defeated',
#    'confused',
#    'promisingly',
#    'loose',
#    'numbers',
#    'violent',
#    'bad',
#    'raw',
#    'foul',
#    'fahrenheit',
#    'typical',
#    'boring',
#    'ugh',
#    'situations',
#    'yielded',
#    'cheap',
#    'worse',
#    'editing',
#    'snl',
#    'artificial',
#    'shrek',
#    'deja',
#    'amy',
#    'hewitt',
#    'olivier',
#    'tommy',
#    'ivan',
#    'hal',
#    'm',
#    'hopkins',
#    'sluggish',
#    'roberto',
#    'yard',
#    'inconsistent',
#    'playstation',
#    'mira',
#    'bottom',
#    'matthew',
#    'uncommitted',
#    'unbelievable',
#    'eddie',
#    'line',
#    'except',
#    'kills',
#    'loss',
#    'span',
#    'questionable',
#    'yes',
#    'muy',
#    'mitch',
#    'madonna',
#    'jfk',
#    'stifles',
#    'mild',
#    'edward',
#    'pointless',
#    'stewart',
#    'insultingly',
#    'misfire',
#    'ms',
#    'ritchie',
#    'enigma',
#    'credit',
#    'edit',
#    'hey',
#    'disappointingly',
#    'loco',
#    'christmas',
#    'left',
#    'elizabeth',
#    'lots',
#    'on',
#    'insignificant',
#    'flop',
#    'ending',
#    'irrelevant',
#    'wait',
#    'vu',
#    'desperate',
#    'scalds',
#    'poor',
#    'cold',
#    'inexcusable',
#    'bounces',
#    'hmmm',
#    'lost',
#    'fax',
#    'davis',
#    'lame',
#    'unconvincing',
#    'john',
#    'mostly',
#    'activate',
#    'round',
#    'shoot',
#    'equation',
#    'harsh',
#    'ugly',
#    'serviceability',
#    'stinks',
#    'strained',
#    'blanks',
#    'regrets',
#    'near',
#    'unfulfilling',
#    'labored',
#    'sinks',
#    'criticizing',
#    'return',
#    'hero',
#    'fraction',
#    'guess',
#    'rally',
#    'judd',
#    'away',
#    'rooting',
#    'mean',
#    'sneaky',
#    'blame',
#    'knock',
#    'beyond',
#    'freezers',
#    'intentionally',
#    'eleven',
#    'london',
#    'remember',
#    'conspiracy',
#    'wore',
#    'lousy',
#    'ai',
#    'frustrating',
#    'waited',
#    'quest',
#    'dirty',
#    'elicit',
#    'ridiculous',
#    'inconsequential',
#    'awfully',
#    'faltering',
#    'flops',
#    'longest',
#    'glimmer',
#    'grounding',
#    'moron',
#    'disjointed',
#    'clue',
#    'nights',
#    'treatment',
#    'stupefying',
#    'unleashes',
#    'insulting',
#    'hammers',
#    'stealing',
#    'guilty',
#    'either',
#    'agent',
#    'exception',
#    'followed',
#    'recovering',
#    'collateral',
#    'disgusting',
#    'suffers',
#    'dey',
#    'crossed',
#    'awkwardly',
#    'nuts',
#    'bound',
#    'mildly',
#    'repeated',
#    'instead',
#    'murky',
#    'wobbly',
#    'cliche',
#    'deadly',
#    'onehour',
#    'arbitrary',
#    'defined',
#    'incredibly',
#    'hour',
#    'amok',
#    'denial',
#    'cell',
#    'warmed',
#    'endings',
#    'terribly',
#    'york',
#    'overused',
#    'hurley',
#    'sketchy',
#    'oprah',
#    'depressing',
#    'waiting',
#    'endurance',
#    'tried',
#    'ordinary',
#    'exactly',
#    'clash',
#    'section',
#    'deserve',
#    'wearisome',
#    'equations',
#    'pink',
#    'sympathy',
#    'box',
#    'road',
#    'hurry',
#    'failure',
#    'phone',
#    'matrix',
#    'vehicle',
#    'easy',
#    'water',
#    'loads',
#    'resolutely',
#    'hours',
#    'devoid',
#    'repetitive',
#    'messenger',
#    'misery',
#    'noticeable',
#    'purposes',
#    'gamut',
#    'faster',
#    'snow',
#    'franchise',
#    'rank',
#    'enjoy',
#    'lick',
#    'passe',
#    'biscuit',
#    'meanspirited',
#    'arty',
#    'underestimated',
#    'crossroads',
#    'cliché',
#    'grab',
#    'ignore',
#    'break',
#    'awe',
#    'beneath',
#    'overlong'],
#   'scw': ['score',
#    'half',
#    'minutes',
#    'three',
#    'sandra',
#    'third',
#    'i',
#    'joel',
#    'pace',
#    'just',
#    'two',
#    'final',
#    'robert',
#    'only',
#    'saturday',
#    'got',
#    'from',
#    'down',
#    'missing',
#    'in',
#    'shot',
#    'balance',
#    'pathetic',
#    'decent',
#    'target',
#    'first',
#    'hugh',
#    'while',
#    'midnight',
#    'sequence',
#    'spectacular',
#    'mark',
#    'cute',
#    'rare',
#    'then',
#    'up',
#    'almost',
#    'play',
#    'without',
#    'tom',
#    'blue',
#    'with',
#    'about',
#    'pale',
#    'excellent',
#    'last',
#    'full',
#    'good',
#    'ca',
#    'little',
#    'mr',
#    'really',
#    'lee',
#    'crimes',
#    'fans',
#    'keep',
#    'attempt',
#    'oscar',
#    'pretty',
#    'offer',
#    'night',
#    'think',
#    'look',
#    'looking',
#    'their',
#    'scary',
#    'trouble',
#    'career',
#    'offers',
#    'dark',
#    'prison',
#    'largely',
#    'anything',
#    'cut',
#    'performance',
#    've',
#    'far',
#    'sentimental',
#    'seen',
#    'right',
#    'girlfriend',
#    'usually',
#    'american',
#    'word',
#    'murder',
#    'uses',
#    'wrong',
#    'watch',
#    'over',
#    'killed',
#    'somewhat',
#    'across',
#    'length',
#    'words',
#    'cinematography',
#    'thriller',
#    'found',
#    'term'],
#   'fcw': ['familiar',
#    'loud',
#    'becomes',
#    'slimed',
#    'to',
#    'gags',
#    'opera',
#    'sit',
#    'merit',
#    'ego',
#    'hasbeen',
#    'pomposity',
#    'booths',
#    'appears',
#    'hastily',
#    'highly',
#    'pieces',
#    'money',
#    'reality',
#    'name',
#    'that',
#    'forces',
#    'names',
#    'absurdity',
#    'already',
#    'assembled',
#    'country',
#    'dubbed',
#    'sort',
#    'bravado',
#    'famed',
#    'toilethumor',
#    'rowling',
#    'hartley',
#    'firstrate',
#    'snore',
#    'swill',
#    'perhaps',
#    'ideas',
#    'selfconscious',
#    'funnier',
#    'material',
#    'efforts',
#    'important',
#    'ears',
#    'overbearing',
#    'compendium',
#    'former',
#    'ought',
#    'busy',
#    'reputation',
#    'unnamed',
#    'gentlemen',
#    'chatter',
#    'sanctimony',
#    'chamber',
#    'forcefully',
#    'mouthpieces',
#    'as',
#    'legendary',
#    'cadavers',
#    'elements',
#    'brash',
#    'soon',
#    'parking',
#    'ambition',
#    'party',
#    'concoctions',
#    'disintegrates',
#    'disintegrating',
#    'serve',
#    'protestors',
#    'approached',
#    'the',
#    'of',
#    'wedgie',
#    'shtick',
#    'national',
#    'unwieldy',
#    'breasts',
#    'decorating',
#    'ship',
#    'appointed',
#    'law',
#    'boardwalk',
#    'fellow',
#    'satire',
#    'reams',
#    'demented',
#    'anticipation',
#    'ambitious',
#    'program',
#    'list',
#    'bears',
#    'buzz',
#    'guide',
#    'irreparable',
#    'spend',
#    'contraption',
#    'events',
#    'antifeminist',
#    'intrusive',
#    'labors',
#    'hokum',
#    'indoctrinated',
#    'anger',
#    'distracting',
#    'comedian',
#    'where',
#    'thoughtlessly',
#    'possibly',
#    'biopic',
#    'she',
#    'episode',
#    'caper',
#    'channeling',
#    'heavyweights',
#    'impulse',
#    'abiding',
#    'signpost',
#    'subplots',
#    'imagery',
#    'theater',
#    'engage',
#    'endeavors',
#    'ease',
#    'presented',
#    'agenda',
#    'said',
#    'scripts',
#    'frightfest',
#    'resentment',
#    'ugliness',
#    'handle',
#    'harm',
#    'cocktail',
#    'stains',
#    'tendentious',
#    'pulpy',
#    'sentiment',
#    'intervention',
#    'stuffy',
#    'dentist',
#    'aesthetic',
#    'sitcom',
#    'brain',
#    'successor',
#    'piece',
#    'parrots',
#    'happens',
#    'remotely',
#    'zemeckis',
#    'writerproducerdirector',
#    'writerdirector',
#    'wellacted',
#    'warmovie',
#    'underrehearsed',
#    'uglylooking',
#    'twentyfourandunders',
#    'tvmovie',
#    'tvinsider',
#    'tornatore',
#    'tooconscientious',
#    'throwntogether',
#    'thirtys',
#    'thirdperson',
#    'thecash',
#    'tenyear',
#    'teensleaze',
#    'teendriven',
#    'techgeeks',
#    'swordandsorcery',
#    'summercamp',
#    'sugarman',
#    'stopandstart',
#    'soontobeforgettable',
#    'snaillike',
#    'slomo',
#    'slc',
#    'sixtys',
#    'sillified',
#    'silbersteins',
#    'selfindulgent',
#    'selfimportant',
#    'selfconsciously',
#    'selfcongratulation',
#    'selfawareness',
#    'rubbo',
#    'romanticcomedy',
#    'romanek',
#    'precredit',
#    'playdoh',
#    'phoneyfeeling',
#    'periodperfect',
#    'pasolini',
#    'overlyfamiliar',
#    'outbadact',
#    'nowcliched',
#    'notsofunny',
#    'nosurprise',
#    'ninetyfiveminute',
#    'newagey',
#    'marivaux',
#    'lugosi',
#    'lowerclass',
#    'lipnonsynching',
#    'liman',
#    'lifeatarm',
#    'leblanc',
#    'kathie',
#    'italicizes',
#    'industrialmodel',
#    'imponderably',
#    'imagemongering',
#    'illfitting',
#    'hatinhand',
#    'halfstep',
#    'halfbaked',
#    'halfassed',
#    'godard',
#    'gifford',
#    'gangstercrime',
#    'fourthrate',
#    'fortys',
#    'fortyeight',
#    'fiftyone',
#    'fiftyfive',
#    'eightyearold',
#    'eastwood',
#    'dumbeddown',
#    'doublepistoled',
#    'doingitfor',
#    'deniro',
#    'deathdefying',
#    'cellophanepop',
#    'caddyshack',
#    'bythenumbers',
#    'bruckheimeresque',
#    'benigni',
#    'barrymore',
#    'barnburningly',
#    'ballisticpyrotechnic',
#    'anticatholic',
#    'agesold',
#    'narcissism',
#    'advised',
#    'stolid',
#    'invention',
#    'company',
#    'ramblings',
#    'improvised',
#    'producers',
#    'person',
#    'scientific',
#    'drivel',
#    'coherent',
#    'hardsell',
#    'castrated',
#    'treading',
#    'noisy',
#    'spiritual',
#    'thematic',
#    'devolves',
#    'conquer',
#    'choices',
#    'cathartic',
#    'structure',
#    'authentic',
#    'message',
#    'performing',
#    'secrets',
#    'overplayed',
#    'heed',
#    'artifice',
#    'overworked',
#    'grand',
#    'kitsch',
#    'sadly',
#    'usher',
#    'details',
#    'cheesier',
#    'spoof',
#    'desire',
#    'accompanied',
#    'ladies',
#    'dates',
#    'proceedings',
#    'innovation',
#    'demographic',
#    'prejudice',
#    'pitfalls',
#    'tearing',
#    'exploitation',
#    'ensues',
#    'proceeds',
#    'lionize',
#    'lectured'],
#   'iw': ['and',
#    'one',
#    'ennui',
#    'humor',
#    'work',
#    'most',
#    'world',
#    'independent',
#    'act',
#    'might',
#    'films',
#    'identity',
#    'drama',
#    'music',
#    'shrewd',
#    'once',
#    'who',
#    'ever',
#    'thoroughly',
#    'space',
#    'persona',
#    'undoubtedly',
#    'has',
#    'intelligence',
#    'scenes',
#    'elegantly',
#    'scene',
#    'may',
#    'an',
#    'part',
#    'working',
#    'this',
#    'new',
#    'engaging',
#    'directed',
#    'acting',
#    'shows',
#    'should',
#    'insight',
#    'premise',
#    'seems',
#    'done',
#    'attention',
#    'direction',
#    'also',
#    'was',
#    'makers',
#    'narrative',
#    'actors',
#    'could',
#    'family',
#    'itself',
#    'written',
#    'belly',
#    'created',
#    'young',
#    'sorvino',
#    'cast',
#    'documentary',
#    'addition',
#    'visual',
#    'reasonably',
#    'truly',
#    'suggests',
#    'her',
#    'male',
#    'intelligent',
#    'quality',
#    'by',
#    'makes',
#    'callow',
#    'twohourandfifteenminute',
#    'twentytwoyearold',
#    'spiritcrushing',
#    'selfsatisfied',
#    'partyhearty',
#    'eighteenyearold',
#    'assayas',
#    'our',
#    'worked',
#    'help',
#    'filmmakers',
#    'raised',
#    'movie',
#    'easily',
#    'kong',
#    'grant',
#    'comic',
#    'bible',
#    'make',
#    'budget',
#    'performers',
#    'tragic',
#    'audience',
#    'directors',
#    'approach',
#    'take',
#    'saccharine',
#    'women',
#    'tribute',
#    'structured',
#    'wit',
#    'comedy']}}

# %%
punc_list = [w for w in ',.，。!?！？;；、']

# %%
for key in global_kws_dict:
    print(key)
# Out:
# 1
# 0

# %%
for key in global_kws_dict:
    print(key)
    kws = global_kws_dict[key]
    print(' '.join(TA.aug_by_deletion(sentence, p, 'selective', print_info=True,
                    selected_words=kws['scw']+kws['fcw']+kws['iw'])))  # except ccw
    print(' '.join(TA.aug_by_replacement(sentence, p, 'selective', print_info=True,
                    selected_words=kws['scw']+kws['fcw']+kws['iw'])))  # except ccw
    print(' '.join(TA.aug_by_insertion(sentence, p, 'selective', print_info=True,
                    selected_words=kws['ccw']+kws['scw']+kws['iw'])))  # except ccw
    print(' '.join(TA.aug_by_selection(sentence, print_info=True,
                        selected_words=kws['ccw']+punc_list)))
# Out:
# 1
# deletion info: ['from', 'robert', 'case', 'could', 'any']
# rrnpocwruedu r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu someone please post info on these systems thanks bob robert novitskey pursuing women is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# replacement info: [('head', 'forefront'), ('a', 'deoxyadenosine_monophosphate'), ('on', 'on'), ('less', 'LE'), ('robert', 'Henry_M._Robert')]
# from rrnpocwruedu Henry_M._Robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu Henry_M._Robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob Henry_M._Robert novitskey pursuing women is similar to banging ones forefront rrnpocwruedu against deoxyadenosine_monophosphate wallwith LE opportunity for reward
# insertion info: [('', ''), ('is', 'make_up'), ('', ''), ('', ''), ('robert', 'Robert')]
# make_up from Robert rrnpocwruedu robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob robert novitskey pursuing women is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# selection info: and
# and
# 0
# deletion info: ['from', 'robert', 'and', 'could', 'women']
# rrnpocwruedu r novitskey subject cyclone tempest articleid usenetonepskavqtu replyto rrnpocwruedu robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu someone please post any info on these systems thanks bob robert novitskey pursuing is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# replacement info: [('robert', 'Robert'), ('women', 'woman')]
# from rrnpocwruedu Robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto rrnpocwruedu Robert r novitskey organization case western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob Robert novitskey pursuing woman is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# insertion info: [('robert', 'Henry_M._Robert'), ('', ''), ('similar', 'exchangeable'), ('on', 'along'), ('', '')]
# from rrnpocwruedu robert r novitskey subject cyclone and tempest articleid usenetonepskavqtu replyto exchangeable rrnpocwruedu robert r novitskey organization case Henry_M._Robert along western reserve university cleveland oh usa lines ten nntppostinghost thorinscwruedu could someone please post any info on these systems thanks bob robert novitskey pursuing women is similar to banging ones head rrnpocwruedu against a wallwith less opportunity for reward
# selection info: on
# selection info: similar
# on similar
